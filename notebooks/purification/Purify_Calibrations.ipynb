# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
import analysis.lib.purification.purify_ssro as pu_ssro;reload(pu_ssro)
# %matplotlib inline
# Out:
# d:\measuring\data
# reloaded
# d:\measuring\data
# reloaded
# d:\measuring\data
# reloaded
# d:\measuring\data

# %% [markdown]
# ## Repump speed

# %%
### to be written // imported from Qmemory

# %% [markdown]
# ## average repump time Z

# %%
reload(pu_ssro)
pu_ssro.average_repump_time(contains = '_Z', do_fit = True, fixed = [])
# Out:
# reloaded
# d:\measuring\data
# Converged with chi squared  0.0209013382953
# degrees of freedom, dof  22
# RMS of residuals (i.e. sqrt(chisq/dof))  0.030823056818
# Reduced chisq (i.e. variance of residuals)  0.000950060831605
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.091189 +/-   0.023613
#  1 A              0.718744 +/-   0.022757
#  2 x0             0.249959 +/-   0.004218
#  3 sigma          0.211159 +/-   0.009260
#
# correlation matrix:
#                a         A         x0        sigma
#          a  1.000000
#          A -0.837762  1.000000
#         x0 -0.063683  0.058386  1.000000
#      sigma -0.884997  0.592777  0.047443  1.000000

# %% [markdown]
# ## average repump time XY

# %%
reload(pu_ssro)
pu_ssro.average_repump_time(contains = '_X', do_fit = True, fixed = [])
# Out:
# reloaded
# d:\measuring\data
# Converged with chi squared  0.0204842742996
# degrees of freedom, dof  22
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0305139865841
# Reduced chisq (i.e. variance of residuals)  0.000931103377255
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.501942 +/-   0.043686
#  1 A              0.243013 +/-   0.039915
#  2 x0             0.315499 +/-   0.013704
#  3 sigma          0.253228 +/-   0.048205
#
# correlation matrix:
#                a         A         x0        sigma
#          a  1.000000
#          A -0.958442  1.000000
#         x0  0.044994 -0.045381  1.000000
#      sigma -0.952345  0.860726 -0.037563  1.000000

# %% [markdown]
# ## Number of repetitions

# %%
reload(pu_ssro)
# pu_ssro.number_of_repetitions(contains = '_X', do_fit = True, show_guess = False, fit_n = 1,fit_f = 1e-10, fixed = [0,2,4,5,6])
pu_ssro.number_of_repetitions(contains = '_Z', do_fit = True, show_guess = False, fit_T =3000,fit_n = 1, fit_f = 1e-10, fixed = [0,2,4,5,6], older_than = None)
# Out:
# reloaded
# d:\measuring\data
# Converged with chi squared  0.00719138989008
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0235198604949
# Reduced chisq (i.e. variance of residuals)  0.000553183837698
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A              0.911274 +/-   0.011831
#  1 T           2865.668541 +/- 936.718463
#
# correlation matrix:
#                A         T
#          A  1.000000
#          T -0.847308  1.000000

# %% [markdown]
# ## El to C swap

# %%
reload(pu_ssro)
pu_ssro.el_to_c_swap(input_el=['X','mX','Y','mY','Z','mZ'])
# Out:
# reloaded
# d:\measuring\data
# this is the timestamp  20160707\165349
#                              X                 Y                 Z
# --------------------------------------------------------------------------------------------------
#                X |    -0.07 +/- 0.04    -0.17 +/- 0.04     0.91 +/- 0.02
# --------------------------------------------------------------------------------------------------
#               mX |    -0.01 +/- 0.04      0.2 +/- 0.04    -0.94 +/- 0.02
# --------------------------------------------------------------------------------------------------
#                Y |    -0.05 +/- 0.04     0.96 +/- 0.02     0.21 +/- 0.04
# --------------------------------------------------------------------------------------------------
#               mY |     0.02 +/- 0.04    -0.95 +/- 0.02    -0.14 +/- 0.04
# --------------------------------------------------------------------------------------------------
#                Z |    -0.96 +/- 0.02    -0.01 +/- 0.04     0.31 +/- 0.04
# --------------------------------------------------------------------------------------------------
#               mZ |     0.33 +/- 0.04    -0.77 +/- 0.03    -0.36 +/- 0.04

# %% [markdown]
# ## Calibrate LDE phase

# %%
reload(pu_ssro)
pu_ssro.calibrate_LDE_phase(contains = 'LDE_phase', do_fit = True,fixed = [1],show_guess = False, phi0 = 180, freq = 1./20, older_than = None)
# Out:
# reloaded
# d:\measuring\data
# Converged with chi squared  0.00460643895449
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0226235839446
# Reduced chisq (i.e. variance of residuals)  0.000511826550499
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.065195 +/-   0.000105
#  1 A              0.956882 +/-   0.017336
#  2 phi          183.229585 +/-   1.119935
#  3 t            421.719001 +/- 120.101307
#
# correlation matrix:
#                f         A         phi       t
#          f  1.000000
#          A -0.141611  1.000000
#        phi -0.864192  0.144446  1.000000
#          t  0.150240 -0.839264 -0.139853  1.000000
#
# This is the phase detuning 8
# Acquired phase per repetition (compensating for phase_detuning=) 15.470 +/- 0.038
# phase offset  183.23

# %% [markdown]
# ## Calibrate feedback phase

# %%
reload(pu_ssro)
pu_ssro.calibrate_LDE_phase(contains = 'phase',do_fit = True,fixed = [],show_guess = False, phi0=240,freq = 10/360.)
# Out:
# reloaded
# d:\measuring\data
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-6c65ec7d1ca8> in <module>()
#       1 reload(pu_ssro)
# ----> 2 pu_ssro.calibrate_LDE_phase(contains = 'phase',do_fit = True,fixed = [],show_guess = False, phi0=240,freq = 10/360.)
#
# d:/measuring\analysis\lib\purification\purify_ssro.pyc in calibrate_LDE_phase(contains, do_fit, **kw)
#     353         ro_array = ['positive','negative']
#     354         # print ro_array
# --> 355         x,y,y_u = get_pos_neg_data(a,adwindata_str = 'X_',ro_array = ro_array,**kw)
#     356         ylabel = 'X'
#     357
#
# d:/measuring\analysis\lib\purification\purify_ssro.pyc in get_pos_neg_data(a, adwindata_str, ro_array, **kw)
#      92         for i,ro in enumerate(ro_array):
#      93                 a.get_sweep_pts()
# ---> 94                 a.get_readout_results(name = adwindata_str+ro,CR_after_check=CR_after_check)
#      95                 a.get_electron_ROC(ssro_calib_folder)
#      96
#
# d:/measuring\analysis\lib\m2\ssro\mbi.pyc in get_readout_results(self, name, CR_after_check)
#      31         self.result_corrected = False
#      32
# ---> 33         adwingrp = self.adwingrp(name)
#      34         self.adgrp = adwingrp
#      35
#
# d:/measuring\analysis\lib\m2\m2.pyc in adwingrp(self, name)
#      48                 logging.error("More than one measurement. Please give a name")
#      49                 return False
# ---> 50         return self.g[adwingrpname]
#      51
#      52     def analysis_h5data(self, name='analysis'):
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper (C:\pisi\tmp\h5py-2.4.0-2\work\h5py-2.4.0\h5py\_objects.c:2463)()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper (C:\pisi\tmp\h5py-2.4.0-2\work\h5py-2.4.0\h5py\_objects.c:2420)()
#
# C:\Canopy\User\lib\site-packages\h5py\_hl\group.pyc in __getitem__(self, name)
#     158                 raise ValueError("Invalid HDF5 object reference")
#     159         else:
# --> 160             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     161
#     162         otype = h5i.get_type(oid)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper (C:\pisi\tmp\h5py-2.4.0-2\work\h5py-2.4.0\h5py\_objects.c:2463)()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper (C:\pisi\tmp\h5py-2.4.0-2\work\h5py-2.4.0\h5py\_objects.c:2420)()
#
# h5py\h5o.pyx in h5py.h5o.open (C:\pisi\tmp\h5py-2.4.0-2\work\h5py-2.4.0\h5py\h5o.c:3373)()
#
# KeyError: "Unable to open object (Object 'x_positive' doesn't exist)"

# %% [markdown]
# ## Check phase offset after LDE2

# %%
reload(pu_ssro)
pu_ssro.phase_offset_after_LDE() ### tomographic measurement
# Out:
# reloaded
# d:\measuring\data
# this is the timestamp  20160711\151812
#                  X                 Y                 Z
# -------------------------------------------------------------------------
#      0.29 +/- 0.04     0.21 +/- 0.04     0.76 +/- 0.03

# %%
reload(pu_ssro)
tomo_basis = 'Z'
pu_ssro.calibrate_LDE_phase(contains = '_phase_offset_after_LDE_'+tomo_basis,tomo_basis = tomo_basis,
                            do_fit = True,fixed = [0,4],decay = 1e5,
                            show_guess = False, phi0=240,freq = 1/360.)
# Out:
# reloaded
# d:\measuring\data
# Converged with chi squared  0.0434724095749
# degrees of freedom, dof  12
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0601888760313
# Reduced chisq (i.e. variance of residuals)  0.00362270079791
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.044196 +/-   0.016183
#  1 A             -0.887856 +/-   0.021339
#  2 phi          178.442555 +/-   1.532764
#
# correlation matrix:
#                a         A         phi
#          a  1.000000
#          A  0.008672  1.000000
#        phi  0.278804  0.005275  1.000000
#
# no phase detuning found

# %% [markdown]
# # Full sequence local with rotation to Z

# %%
reload(pu_ssro)
tomo_basis = 'Z'
pu_ssro.calibrate_LDE_phase(contains = 'full_sequence_local_'+tomo_basis,tomo_basis = tomo_basis,
                            do_fit = True,fixed = [0,1],decay = 300,
                            show_guess = False, phi0=0,freq = 1/360)
# Out:
# reloaded
# d:\measuring\data
# Converged with chi squared  0.0323448843869
# degrees of freedom, dof  7
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0679757145572
# Reduced chisq (i.e. variance of residuals)  0.00462069776956
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A              1.031646 +/-        nan
#  1 phi        619582.552339 +/-        nan
#  2 t            138.492861 +/-   0.000000
#
# correlation matrix:
#                A         phi       t
#          A -1.000000
#        phi -1.000000 -1.000000
#          t      -inf      -inf       nan
#
# This is the phase detuning 0
# no phase detuning found
# d:/measuring\analysis\lib\fitting\fit.py:200: RuntimeWarning: divide by zero encountered in double_scalars
#   sqrt(result['cov'][i,i] * result['cov'][j,j]),)
# d:/measuring\analysis\lib\fitting\fit.py:200: RuntimeWarning: invalid value encountered in double_scalars
#   sqrt(result['cov'][i,i] * result['cov'][j,j]),)
