# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
from analysis.scripts.laser_scan import laserscan_2d; reload(laserscan_2d)
# %matplotlib inline

# %%
reload(laserscan_2d)

filename = 'LaserScansYellowRepump_LT4_Red'

laserscan_2d.plot_freq_against_index(contains=filename, plot_range = [40.0,55.3])
laserscan_2d.plot_overlaid(contains=filename, compensate_drift = False,fit =True,show_indiv = True)

# %%
reload(laserscan_2d)
laserscan_2d.spectral_diffusion(contains=filename, plot_range = [55.10,55.25], count_filter = 0.1e6)

# %%
laserscan_2d.plot_single(contains=filename, ind = 2,fit =False)

# %%
print filename
