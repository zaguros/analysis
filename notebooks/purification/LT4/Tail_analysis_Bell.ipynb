# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
# %matplotlib inline

folder=tb.latest_data('tail')
#folder=tb.latest_data('Bell_tail', folder=r'P:/BellDataLt4')
# folder=tb.data_from_time('20160329/173959')
#folder=r'D:\measuring\data\20141008\122309_Bell_tail_sweep_tail_lt4_hans_sil1_PSB'
name = 'ssro'
psb=False
TH_or_HH = 'TH'
if psb:
    a = pqsequence.TailAnalysis(folder, hdf5_mode='r')#, pq_folder='bs_remote')
else:
    a = pqsequence.TailAnalysis(folder, hdf5_mode='r')#, pq_folder='bs_remote')
#a.fix_sweep_pts('Pulse Amplitude', 'eom_pulse_amplitude')
a.get_sweep_pts()
#a.sweep_pts = a.g.attrs['aom_amplitude']
a.get_sweep_idxs(noof_syncs_per_sweep_pt=250)
a.get_readout_results(name)
if psb:
    if a.g.attrs['general_sweep_name']=='eom_off_amplitude':
        print 'sweeping EOM off voltage'
        a.get_tail_vs_sweep(0,5369,17, pq_binsize_ns=1, hist_binsize_ns=1.,verbose=True)
    else:
        if TH_or_HH == 'TH':
            a.get_tail_vs_sweep(0,5410,135, pq_binsize_ns=1, hist_binsize_ns=1.,verbose=True)
        else:
            print 'HH'
            a.get_tail_vs_sweep(0,5400e3,145e3, pq_binsize_ns=1, hist_binsize_ns=100.,verbose=True)
    
else:
    if TH_or_HH == 'TH':
        #a.get_tail_vs_sweep(0,5425.5,100, pq_binsize_ns=1e-3, hist_binsize_ns=1.,verbose=True)
        a.get_tail_vs_sweep(1,5420.85,50, pq_binsize_ns=1, hist_binsize_ns=1.,verbose=True)
    else:
        a.get_tail_vs_sweep(1,5470e3,30e3, pq_binsize_ns=1, hist_binsize_ns=1e3,verbose=True)
        

print 'Sweep tail.  from : {}\{} '.format(tb.timestamp_from_datetime(tb.get_datetime_from_folder(folder))[:8]\
                                                 ,tb.timestamp_from_datetime(tb.get_datetime_from_folder(folder))[8:])    
print 'optimum aom voltage : {:.3f}'.format(a.g.attrs['general_sweep_pts'][np.argmax(a.tail_cts_per_sweep_idx)]),\
    'with tail counts: {:.0f}e-4 counts/shot'.format(np.max(a.tail_cts_per_sweep_idx)*1e4)

print a.g.attrs['general_sweep_pts']
# Out:
# d:\measuring\data
# total_photons in channel 1 : 1879
# total_photons in window: 669
# total_sweeps in window: 669
# total ph in window with sweep element 0: 44
# div factor: 250000
# Sweep tail.  from : 20160526\180729
# optimum aom voltage : 0.431 with tail counts: 5e-4 counts/shot
# [ 0.25924194  0.31152543  0.35401533  0.39300159  0.43122966  0.47056788
#   0.51283385]

# %%
save=True
a.plot_tail_cts_vs_sweep(save=save, channels=1)
a.plot_tail_hists_vs_sweep(save=save)
a.plot_tail_hist_integated(save=save, log_plot=True)
a.plot_tail_hist_all(save=save, log_plot=1, offset=0, indices=[np.argmax(a.tail_cts_per_sweep_idx)])

# %%
from analysis.lib.fitting import fit, common, rabi
ax=a.plot_tail_cts_vs_sweep(save=False, ret='ax')
x=a.g.attrs['general_sweep_pts']
y=a.tail_cts_per_sweep_idx
ff = common.fit_parabole
#o + A * (x-c)**2
#['g_o', 'g_A', 'g_c']
args = [0,np.max(y), x[np.argmin(y)]]
print args
fitres = fit.fit1d(x, y, ff, *args, fixed = [],
                   do_print = True, ret = True)
plot_pts=100
x_p=np.linspace(min(x),max(x),plot_pts)
if fitres['success']:
    f_p = fitres['fitfunc'](x_p)*1e4
    ax.plot(x_p,f_p)
# Out:
# [0, 1.1999999999999999e-06, 0.80000000000000004]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-173-921082708b11> in <module>()
#       9 print args
#      10 fitres = fit.fit1d(x, y, ff, *args, fixed = [],
# ---> 11                    do_print = True, ret = True)
#      12 plot_pts=100
#      13 x_p=np.linspace(min(x),max(x),plot_pts)
#
# d:/measuring\analysis\lib\fitting\fit.pyc in fit1d(x, y, fitmethod, *arg, **kw)
#      87
#      88     # do the fit and process
# ---> 89     p1, cov, info, mesg, success = optimize.leastsq(f, p, full_output=True, maxfev=len(x)*100)
#      90     if not success or cov == None: # FIXME: find a better solution!!!
#      91         success = False
#
# C:\Canopy\User\lib\site-packages\scipy\optimize\minpack.pyc in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     372     m = shape[0]
#     373     if n > m:
# --> 374         raise TypeError('Improper input: N=%s must not exceed M=%s' % (n, m))
#     375     if epsfcn is None:
#     376         epsfcn = finfo(dtype).eps
#
# TypeError: Improper input: N=3 must not exceed M=1

# %%
from analysis.lib.fitting import fit, common, rabi
from analysis.lib.tools import plot
fig, ax = plt.subplots(1,1, figsize=(4.5,4))
fs=zeros(a.sweep_length)
taus = zeros(a.sweep_length)
for i in range(a.sweep_length):
    x=a.tail_hist_b[:-1]        
    y=a.tail_hist_h[i]
    fit_result = fit.fit1d(x, y, rabi.fit_rabi_damped_exp_with_offset, 
            1/5.,1000,0,10., x[0], ret = True, color = 'r', linewidth = 2.0)
    fs[i] = fit_result['params_dict']['f']
    taus[i] = fit_result['params_dict']['tau']
    plot.plot_fit1d(fit_result, np.linspace(x[0],x[-1],201), ax=ax,
        plot_data=True, print_info=False)
fig, ax = plt.subplots(1,1, figsize=(4.5,4))
#print taus, fs
ax.plot(a.sweep_pts, fs)
fig, ax = plt.subplots(1,1, figsize=(4.5,4))
ax.plot(a.sweep_pts, taus)
# Out:
# d:/measuring\analysis\lib\fitting\rabi.py:105: RuntimeWarning: overflow encountered in exp
#   return a() + A() * exp(-(x-x0())/tau()) * cos(2*pi*( f()*(x-x0())))

# %%
a.get_cr_results(name)
a.plot_cr_vs_sweep()

# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
#folder=tb.latest_data('Bell')
folder=tb.data_from_time('20141012023031')
#folder=r'D:\measuring\data\20140519\192030_Bell_lt3_tailS_The111no2_SIL1_Ey_+11deg'
name = 'ssro'
a = pqsequence.TailAnalysis(folder, hdf5_mode='r', pq_folder='bs_remote')
a.reps=200000
a.plot_histogram(0, start=5.350e6, length=1000000, hist_binsize=1000, save=False)
# Out:
# d:\measuring\data
# h5filepath: X:\data\20141012\023024_Bell_BS_TPQI_run_5\023024_Bell_BS_TPQI_run_5.hdf5
# Total clicks: 26626

# %%
from analysis.lib.pq import pq_tools
reload(pq_tools)
# Out:
# <module 'analysis.lib.pq.pq_tools' from 'd:/measuring\analysis\lib\pq\pq_tools.pyc'>

# %%
fltr0=pq_tools.filter_synctimes(a.pqf, 5371.5e3, 5397e3,15,600e3)
fltr1=pq_tools.filter_synctimes(a.pqf, 5374e3, 5399.5e3,15,600e3)
cs=pq_tools.get_coincidences(a.pqf, fltr0, fltr1)
dts_ns = cs[:,0]*1e-3
len(cs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-4aabc018fc21> in <module>()
#       1 fltr0=pq_tools.filter_synctimes(a.pqf, 5371.5e3, 5397e3,15,600e3)
#       2 fltr1=pq_tools.filter_synctimes(a.pqf, 5374e3, 5399.5e3,15,600e3)
# ----> 3 cs=pq_tools.get_coincidences(a.pqf, fltr0, fltr1)
#       4 dts_ns = cs[:,0]*1e-3
#       5 len(cs)
#
# d:\measuring\analysis\lib\pq\pq_tools.pyc in get_coincidences(pqf, index, fltr0, fltr1, force_coincidence_evaluation, save)
#     323
#     324
# --> 325     if has_analysis_data(pqf, 'coincidences') and not force_coincidence_evaluation:
#     326         c, c_attrs = get_analysis_data(pqf, 'coincidences')
#     327         return c
#
# d:\measuring\analysis\lib\pq\pq_tools.pyc in has_analysis_data(pqf, name, analysisgrp, subgroup)
#     773 def has_analysis_data(pqf, name, analysisgrp = 'analysis', subgroup=None):
#     774
# --> 775     agrp = pqf.require_group(analysisgrp + ('/' + subgroup if subgroup!=None else ''))
#     776     if name in agrp.keys():
#     777         return True
#
# C:\Canopy\User\lib\site-packages\h5py\_hl\group.pyc in require_group(self, name)
#     137         """
#     138         if not name in self:
# --> 139             return self.create_group(name)
#     140         grp = self[name]
#     141         if not isinstance(grp, Group):
#
# C:\Canopy\User\lib\site-packages\h5py\_hl\group.pyc in create_group(self, name)
#      39         """
#      40         name, lcpl = self._e(name, lcpl=True)
# ---> 41         gid = h5g.create(self.id, name, lcpl=lcpl)
#      42         return Group(gid)
#      43
#
# C:\Canopy\User\lib\site-packages\h5py\h5g.pyd in h5py.h5g.create (h5py\h5g.c:2523)()
#
# ValueError: Unable to create group (No write intent on file)

# %%
binsize=10
G2_BINEDGES = arange(-19000,19000,binsize)
#G2_BINEDGES = np.hstack((arange(-700,-500,binsize),arange(-100,100,binsize),arange(500,700,binsize)))
#print G2_BINEDGES
figure(figsize=(20,5))
b_=hist(dts_ns, bins=G2_BINEDGES)

# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
folder=tb.latest_data('Bell')
folder=tb.data_from_time('20140710153945')
a = sequence.SequenceAnalysis(folder)
a.get_cr_results(name)
a.get_sweep_pts()
a.plot_cr_vs_sweep()
a.finish()

# %%
from analysis.lib.fitting import fit, common
from analysis.lib.tools import plot
fig, ax = plt.subplots(1,1, figsize=(4.5,4))
fs=np.zeros(a.sweep_length)
taus = np.zeros(a.sweep_length)
for i in range(a.sweep_length):
    x=a.tail_hist_b[:-1]        
    y=a.tail_hist_h[i]
    p0, fitfunc, fitfunc_str = common.fit_general_exponential(0.,300,5427.,2., 2.)
#     ax.plot(np.linspace(x[0],x[-1],201), fitfunc(np.linspace(x[0],x[-1],201)), ':', lw=2)
    fit_result = fit.fit1d(x, y, None, p0=p0, fitfunc=fitfunc, 
            ret = True, color = 'r', linewidth = 2.0,fixed=[4],do_print=True)
    
    plot.plot_fit1d(fit_result, np.linspace(x[0],x[-1],201), ax=ax,
        plot_data=True, print_info=True)
#     fs[i] = fit_result['params_dict']['f']
#     taus[i] = fit_result['params_dict']['tau']
# fig, ax = plt.subplots(1,1, figsize=(4.5,4))
# #print taus, fs
# ax.plot(a.sweep_pts, fs)
# fig, ax = plt.subplots(1,1, figsize=(4.5,4))
# ax.plot(a.sweep_pts, taus)
# Out:
# Converged with chi squared  2.5843380949
# degrees of freedom, dof  27
# RMS of residuals (i.e. sqrt(chisq/dof))  0.309380390033
# Reduced chisq (i.e. variance of residuals)  0.095716225737
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.141446 +/-   0.073668
#  1 A             -0.180073 +/-   0.171715
#  2 x0          5430.174360 +/-   3.709591
#  3 T              4.713829 +/-   6.285561
#
# correlation matrix:
#                a         A         x0        T
#          a  1.000000
#          A -0.341272  1.000000
#         x0 -0.033615  0.113095  1.000000
#          T  0.368512  0.399595  0.225398  1.000000

# %%
624-166
