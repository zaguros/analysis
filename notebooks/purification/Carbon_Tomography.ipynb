# %%
import sys
sys.path.append(r'D:/measuring')
import numpy as np
sys.path.append(r'D:/measuring/analysis')
# %matplotlib inline
from analysis.scripts.QEC import Two_Qubit_Tomography as Tomo2

# %% [markdown]
# # Tomographies General

# %% [markdown]
# ###  Single measurement

# %%
reload(Tomo2)
tstamp = '20160412_121041'
# Tomo2.BarPlotTomo(timestamp = tstamp, ssro_calib_timestamp = None)
# tstamp = '20160327_094555'
Tomo2.BarPlotTomo(tag = '092236')
# Tomo2.BarPlotTomo(tag = 'negative_1_swap')
# Tomo2.BarPlotTomo(tag = '_Pippinnegative_1_MBI')

# for el_state in ['Y']:#,'mX','Y','mY','Z','mZ']:
#     Tomo2.BarPlotTomo(tag = '_elState' + str(el_state))
# Out:
# [  1  41  81 121 161 201 241 281 321 361 401 441 481 521 561 601 641 681
#  721 761]

# %% [markdown]
# ### Contrast measurement

# %%
reload(Tomo2)

init_method = 'both'
carbons = [1]

for c in carbons:
    if init_method == 'both' or init_method == 'MBI':
        Tomo2.BarPlotTomoContrast(tag = '_' + str(c) + '_MBI', older_than = None)
        
    if init_method == 'both' or init_method == 'swap':
        Tomo2.BarPlotTomoContrast(tag = '_' + str(c) + '_swap', older_than = None)    
    

        

# Tomo2.BarPlotTomoContrast(tag = '_elStatemY_swapRO_True')
# Tomo2.BarPlotTomoContrast(tag = '_Tomo_Y_elState_X_C1')

# Tomo2.BarPlotTomoContrast(tag = '_1_MBI')
# Tomo2.BarPlotTomoContrast(tag = '_Tomo_X_C5')
# Tomo2.BarPlotTomoContrast(tag = '_statemX_Tomo_XY_C25')
# Tomo2.BarPlotTomoContrast(tag = '_statemX_Tomo_YY_C25')
# Tomo2.BarPlotTomoContrast(tag = '_statemX_Tomo_YX_C25')
# Tomo2.BarPlotTomoContrast(tag = '_5_MBI')

# Tomo2.BarPlotTomoContrast(tag = '_1_swap')
# Tomo2.BarPlotTomoContrast(tag = '_2_swap')
# Tomo2.BarPlotTomoContrast(tag = '_8_swap')
# Tomo2.BarPlotTomoContrast(tag = '_multiC_MBI_')

# mpl.rcParams['axes.linewidth']=2
# Tomo2.BarPlotTomoContrastFull_mult_msmts(older_than='20150423_010040')
# Out:
# test
# d:\measuring\data\20160424\180922_probabablistic_MBE_Tomography_Pippinpositive_1_MBI
# test
# d:\measuring\data\20160424\180839_probabablistic_MBE_Tomography_Pippinpositive_1_swap

# %%
reload(Tomo2)
carbons = [1]
for c in carbons:
    Tomo2.CompleteTomo(folder_tag = 'Pippin', 
                       older_than = None, 
                       newer_than = None,
                       return_num = 1,
                       return_newest_or_oldest = 'Oldest',
                       plot_fit = False)
# Out:
# number of folders: 9537
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-b14f2de17e3c> in <module>()
#       7                        return_num = 1,
#       8                        return_newest_or_oldest = 'Oldest',
# ----> 9                        plot_fit = False)
#
# D:/measuring\analysis\scripts\QEC\Two_Qubit_Tomography.pyc in CompleteTomo(timestamp, state, measurement_name, folder_tag, ssro_calib_timestamp, save, older_than, newer_than, return_num, return_newest_or_oldest, plot_fit)
#     244                                 save = False,
#     245                                 plot_fit = False,
# --> 246 				return_data = True)
#     247
#     248                         x_labels.extend(list(x_labels_t))
#
# D:/measuring\analysis\scripts\QEC\Two_Qubit_Tomography.pyc in BarPlotTomoContrast(timestamps, tag, measurement_name, folder_name, ssro_calib_timestamp, save, plot_fit, return_data, older_than)
#     131
#     132         ### Combine data
# --> 133         y = (y_a - y_b)/2.
#     134         y_err =  1./2*(y_err_a**2 + y_err_b**2)**0.5
#     135
#
# ValueError: operands could not be broadcast together with shapes (2,) (3,)
