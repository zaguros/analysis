# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
from analysis.scripts.laser_scan import laserscan_2d; reload(laserscan_2d)
# %matplotlib inline
# Out:
# d:\measuring\data

# %%
reload(laserscan_2d)

filename = 'LaserScansYellowRepump_LT4_Red'

laserscan_2d.plot_freq_against_index(contains=filename, plot_range = [55.0,55.3])
laserscan_2d.plot_overlaid(contains=filename, compensate_drift = False,fit =True,show_indiv = False)
# Out:
# Converged with chi squared  12583632143.9
# degrees of freedom, dof  97
# RMS of residuals (i.e. sqrt(chisq/dof))  11389.8273223
# Reduced chisq (i.e. variance of residuals)  129728166.432
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a          -3331.503034 +/- 1325.951434
#  1 A          17834.525057 +/- 370.626406
#  2 x0            55.168198 +/-   0.000242
#  3 gamma          0.024245 +/-   0.000699
#
# correlation matrix:
#                a         A         x0        gamma
#          a  1.000000
#          A -0.518841  1.000000
#         x0  0.067283 -0.140784  1.000000
#      gamma -0.378924  0.750124 -0.355926  1.000000

# %%
reload(laserscan_2d)
laserscan_2d.spectral_diffusion(contains=filename, plot_range = [55.10,55.25], count_filter = 0.1e6)
# Out:
# Mean overlap  0.985785101597

# %%
laserscan_2d.plot_single(contains=filename, ind = 2,fit =True)
# Out:
# Converged with chi squared  887279193.253
# degrees of freedom, dof  1164
# RMS of residuals (i.e. sqrt(chisq/dof))  873.079233607
# Reduced chisq (i.e. variance of residuals)  762267.348156
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a            739.660825 +/-  30.698992
#  1 A            525.278083 +/-  10.057523
#  2 x0            55.255917 +/-   0.000272
#  3 gamma          0.031757 +/-   0.000828
#
# correlation matrix:
#                a         A         x0        gamma
#          a  1.000000
#          A -0.554272  1.000000
#         x0  0.047147 -0.091804  1.000000
#      gamma -0.404572  0.750142 -0.245654  1.000000
