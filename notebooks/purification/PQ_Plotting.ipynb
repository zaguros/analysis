# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
# %matplotlib inline

folder=tb.latest_data('140310')
a = pqsequence.TailAnalysis(folder, hdf5_mode='r')
# Out:
# d:\measuring\data

# %%
pq_plots.plot_photon_hist(a.pqf,start =0,  length =7000, hist_binsize = 1, save = False, log=False)
# Out:
# (<matplotlib.figure.Figure at 0xe4de250>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0xcf35b70>,
#   <matplotlib.axes._subplots.AxesSubplot at 0xe69a9f0>))

# %%
pq_plots.plot_photon_hist(a.pqf,start =0,  length =7000, hist_binsize = 1, save = False, log=False)
# Out:
# (<matplotlib.figure.Figure at 0xe298db0>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x9f830b0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0xe77d0b0>))
