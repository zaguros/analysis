# %% [markdown]
# ## General fits for MBI type data

# %%
import sys
import numpy as np

sys.path.append(r'D:/measuring')
sys.path.append(r'D:/measuring/analysis')

from analysis.scripts.mbi import mbi_data_general_fits as fits; reload(fits)
# %matplotlib inline
# Out:
# d:\measuring\data
# reloaded
# reloaded
# reloaded

# %%
reload(fits)
Result = fits.exp_sin(timestamp=None, contains = 'Pippin',
                      offset=[0.5], amplitude = [.5], center = [0], decay_constant = [500], 
                      exp_power = [1],
                      frequency = [1.5/200.], phase =[0], 
                      fixed = [2,4],
                      ylim = None,
                      plot_fit = False, do_print = True, show_guess = False)
Result[0]['params_dict']['f']*360
# Out:
# reloaded
# 1
# starting fit.fit1d
# d:\measuring\data\20160712\105655_purifcation slave_Pippin_SIL2_ADwin_phase_compensation
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-179394b754d3> in <module>()
#       7                       ylim = None,
#       8                       plot_fit = False, do_print = True, show_guess = False)
# ----> 9 Result[0]['params_dict']['f']*360
#
# TypeError: 'int' object has no attribute '__getitem__'

# %%
print 0.006935*360
print 0.000049*360
# Out:
# 2.4966
# 0.01764

# %%
344.6+1.2+17.55
# Out:
# 363.35

# %% [markdown]
# ### Two frequencies

# %%
reload(fits)
Result = fits.exp_sin(timestamp=None, contains = '174838',
                      offset=[0.5], amplitude = [0.6]*2, center = [0]*2, decay_constant = [10]*2, exp_power = [2]*2,
                      frequency = [446e3,460e3], phase=[0,0],#[1/(750e-9),1/(750e-9)-1/(1e-6)], phase =[0]*2, 
                      fixed = [0,2,3,4],
                      ylim = None,
                      plot_fit = True, do_print = True, show_guess = False)
# (offset[0],amplitude[0],decay_constant[0],amplitude[0],
# frequency[0],  phase[0], amplitude[1], frequency[1],  phase[1])
# Out:
# reloaded
# Converged with chi squared  0.0555004159037
# degrees of freedom, dof  53
# RMS of residuals (i.e. sqrt(chisq/dof))  0.032360124514
# Reduced chisq (i.e. variance of residuals)  0.00104717765856
#
# fitted parameters at minimum, with 68% C.I.:
#  0 C             -0.443624 +/-   0.028638
#  1 phi_a         33.906692 +/-   3.418857
#  2 B              0.589204 +/-   0.038416
#  3 f_b        467094.200850 +/- 1085.526761
#  4 phi_b          3.310096 +/-   9.210838
#
# correlation matrix:
#                C         phi_a     B         f_b       phi_b
#          C  1.000000
#      phi_a  0.428652  1.000000
#          B  0.684711  0.145464  1.000000
#        f_b  0.680506  0.608097  0.422199  1.000000
#      phi_b -0.686974 -0.530247 -0.441296 -0.955234  1.000000
#
# d:\measuring\data\20160614\174838_CarbonRamsey_Pippin_SIL1
