# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')

# %%
tail.tail_cts_per_shot_txt_file(r'D:\measuring\data\20140314', '1446_Tail_Ey_20000reps.txt', 71, 50, 20000, 250, save_suffix='', bin_size=1., fit_tail=True, save=True, tail_mode=0)
# Out:
# 8744.0
# a = -5.25
# A = 182.10 pm 3.21 ns
# tau = 15.88 pm 0.84 ns
# Tail counts per shot =  5.63 E-4

# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
folder=tb.latest_data('Bell')
#folder=tb.data_from_time('20140321101456')
#folder=r'D:\measuring\data\20140519\192030_Bell_lt3_tailS_The111no2_SIL1_Ey_+11deg'
name = 'ssro'
a = pqsequence.TailAnalysis(folder, hdf5_mode='r', pq_folder='bs_remote')
#a.fix_sweep_pts('Pulse Amplitude', 'eom_pulse_amplitude')
a.get_sweep_pts()
a.get_sweep_idxs(noof_syncs_per_sweep_pt=250)
a.sweep_pts=np.sqrt(a.sweep_pts)
a.sweep_name='Sqrt(AOM power)'
a.get_readout_results(name)
a.get_tail_vs_sweep(1,5398,100, pq_binsize_ns=1., hist_binsize_ns=1.0,verbose=True)
# Out:
# total_photons in channel 1 : 20447
# total_photons in window: 15123
# total_sweeps in window: 15123
# total ph in window with sweep element 0: 622
# div factor: 2500000

# %%
save=False
a.plot_tail_cts_vs_sweep(save=save)
a.plot_tail_hists_vs_sweep(save=save)
a.plot_tail_hist_integated(save=save, log_plot=True)
a.plot_tail_hist_all(save=save, log_plot=True, offset=0, indices=[-3])

# %%
xx=a.tail_hist_b[:-1]
 yy=a.tail_hist_h[8]

# %%
semilogy(xx,yy)

# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
#folder=tb.latest_data('PQPulsarMeasurement')
folder = r'D:\measuring\data\20140501\104043_PQMeasurement_test'
name = 'ssro'
a = pqsequence.PQSequenceAnalysis(folder, hdf5_mode='r')
#a.fix_sweep_pts('Pulse Amplitude', 'eom_pulse_amplitude')
a.get_sweep_pts()
a.get_readout_results(name)
#get_tail_vs_sweep(self, syncs_per_sweep, channel, start, tail_length, pq_binsize=1e-3, hist_binsize=0.2):#ns
a.get_tail_vs_sweep(250,0,240,50,pq_binsize=1, hist_binsize=1.0)
#a.get_tail_vs_sweep(250,1,200,100, pq_binsize=1, hist_binsize=1.0)

# %%
save=True
a.plot_tail_cts_vs_sweep(save=save)
a.plot_tail_hists_vs_sweep(save=save)
a.plot_tail_hist_integated(save=save, log_plot=True)
a.plot_tail_hist_all(save=save, log_plot=False, offset=200)

# %%
6.0/310*100
# Out:
# 1.935483870967742

# %%
11./1200*100
# Out:
# 0.9166666666666666

# %%
cos(6./180*np.pi)*0.9*(0.98)**4
# Out:
# 0.74302541787554277

# %%
2**25
# Out:
# 33554432
