# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')

# %%
nvlevels.get_ES_ExEy(63.4,68.6)

# %%
ssro.ssrocalib(plot_photon_ms0=True)

# %% [markdown]
# # Standard Spin measurements

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# d:\measuring\data\20141015\172345_PulsarDarkESR_FM_Gretel_sil10
# d:\measuring\data\20141015\171849_AdwinSSRO_SSROCalibration_Gretel_sil10
# fitting with 0 splittings
# Converged with chi squared  0.0166778423318
# degrees of freedom, dof  48
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0186401461523
# Reduced chisq (i.e. variance of residuals)  0.000347455048579
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.995919 +/-   0.002845
#  1 A              0.303574 +/-   0.013278
#  2 sigma          0.000004 +/-   0.000000
#  3 x0             2.845437 +/-   0.000000
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.151517  1.000000
#      sigma  0.256611 -0.512717  1.000000
#         x0  0.000000  0.008032 -0.006801  1.000000
#
# ############################
# Population left  0.76638815288
# Population middle  3.26935817011e-06
# Population right  0.233608577761
# #############################
# f0

# %%
execfile(r'D:\measuring\analysis\scripts\espin\electron_rabi_analysis.py')

# %% [markdown]
# # MBI Electron spin measurements

# %%
execfile(r'D:\measuring\analysis\scripts\mbi\mbi_dark_esr_analysis.py')
# Out:
# ############################
# Population left  0.0681690140845
# Population middle  0.0805633802817
# Population right  0.851267605634
# #############################
# Non-initialized population:  0.145882912899
# Electron initialization:   1.04485959067

# %% [markdown]
# #

# %%
# Out:
# 33.3333333333
# 31.0945273632

# %%
spctr_data=np.loadtxt(r'D:\measuring\data\20140912\095544_LaserScansGreenRepump_Gretel_SIL10_LT1_Red\095544_LaserScansGreenRepump_Gretel_SIL10_LT1_Red_noheader.dat')

print shape(spctr_data)
print 42583/32.
print spctr_data[:,3]
frq=[]
cnts=[]
j=0


for i in spctr_data[:,3]:
    
    if spctr_data[j,3]==2:
        frq.append(spctr_data[j,1])
        cnts.append(spctr_data[j,2])
    j+=1
plt.plot(frq,cnts)
plt.xlim([57,59])
carray=np.array(cnts)
carray.max()
cnts.index(carray.max())
carray[921]
print frq[cnts.index(carray.max())]
# Out:
# (42583, 5)
# 1330.71875
# [  0.   0.   0. ...,  31.  31.  31.]
# 68.6515884399

# %%
carray=np.array(cnts)
carray.max()
cnts.index(carray.max())
carray[921]
print frq[cnts.index(carray.max())]
# Out:
# 68.7850418091

# %%
j=0
scan_nr=0
plt.clf()
frq=[]
cnts=[]

for i in spctr_data[:,3]:
    
    if spctr_data[j,3]==scan_nr:
        frq.append(spctr_data[j,1])
        if(spctr_data[j,2]>2000):
            cnt_rate=2000
        else:
            cnt_rate=spctr_data[j,2]
        cnts.append(cnt_rate+scan_nr*3000)
    else:
        scan_nr+=1    
        plt.plot(frq,cnts)
        print frq[200:205]
        frq=[]
        cnts=[]
    j+=1

plt.xlim(55,80)
plt.xlabel('Laser frequency detuning (GHz) ')
# Out:
# [49.785312652590001, 49.785312652590001, 49.850280761720001, 49.850280761720001, 49.850280761720001]
# [49.70115661621, 49.70115661621, 49.72728729248, 49.762935638430001, 49.762935638430001]
# [49.648281097409999, 49.648281097409999, 49.68952178955, 49.68952178955, 49.712677001949999]
# [49.566875457759998, 49.566875457759998, 49.606075286870002, 49.629806518549998, 49.650188446039998]
# [49.702304840090001, 49.742782592769998, 49.742782592769998, 49.768077850339999, 49.805381774899999]
# [49.579105377200001, 49.579105377200001, 49.618663787839999, 49.618663787839999, 49.67914199829]
# [49.615650176999999, 49.651054382319998, 49.67705154419, 49.697105407709998, 49.697105407709998]
# [49.734951019290001, 49.734951019290001, 49.797298431400002, 49.797298431400002, 49.819648742680002]
# [49.609741210940001, 49.650562286380001, 49.650562286380001, 49.6909866333, 49.71475982666]
# [49.684703826899998, 49.706535339360002, 49.706535339360002, 49.747741699220001, 49.747741699220001]
# [49.731369018549998, 49.753757476810001, 49.792694091800001, 49.792694091800001, 49.83666229248]
# [49.614212036129999, 49.614212036129999, 49.653587341310001, 49.677013397220001, 49.677013397220001]
# [49.631538391109999, 49.67225265503, 49.695724487299998, 49.695724487299998, 49.735359191889998]
# [49.706554412839999, 49.706554412839999, 49.735843658450001, 49.768032073969998, 49.768032073969998]
# [49.732604980470001, 49.774089813229999, 49.774089813229999, 49.7943649292, 49.835006713870001]
# [49.77448272705, 49.795150756840002, 49.817607879640001, 49.817607879640001, 49.859161376949999]
# [49.62303161621, 49.66216659546, 49.66216659546, 49.683731079099999, 49.724227905269998]
# [49.7144241333, 49.7144241333, 49.753959655759999, 49.774272918699999, 49.774272918699999]
# [49.728275299069999, 49.751945495610002, 49.773902893070002, 49.773902893070002, 49.81067276001]
# [49.771713256840002, 49.771713256840002, 49.806491851810001, 49.83373260498, 49.83373260498]
# [49.767127990719999, 49.806381225590002, 49.806381225590002, 49.828903198239999, 49.87041091919]
# [49.821125030520001, 49.821125030520001, 49.841663360600002, 49.881240844730002, 49.881240844730002]
# [49.675662994379998, 49.705646514889999, 49.720207214360002, 49.720207214360002, 49.75965499878]
# [49.702419281010002, 49.702419281010002, 49.742084503169998, 49.742084503169998, 49.768371582029999]
# [49.694889068599998, 49.735416412349998, 49.765880584720001, 49.78063583374, 49.814800262449999]
# [49.70799255371, 49.70799255371, 49.74118423462, 49.74118423462, 49.77502822876]
# [49.695011138920002, 49.695011138920002, 49.734928131099998, 49.757244110110001, 49.757244110110001]
# [49.760105133060001, 49.79621887207, 49.79621887207, 49.82939529419, 49.858367919919999]
# [49.770755767819999, 49.807628631589999, 49.807628631589999, 49.840106964109999, 49.869617462160001]
# [49.787349700930001, 49.787349700930001, 49.805507659909999, 49.832496643070002, 49.85083770752]
# [49.819847106929998, 49.819847106929998, 49.83794784546, 49.864124298100002, 49.864124298100002]

# %%
j=0
scan_nr=0
plt.clf()
frq=[]
cnts=[]
for i in spctr_data[:,3]:
    
    if spctr_data[j,3]==2:
        frq.append(spctr_data[j,1])
        cnt_rate=spctr_data[j,2]
        cnts.append(cnt_rate)
    j+=1
plt.plot(frq,cnts)
plt.xlim([55,78])
plt.ylim(0,500)
# Out:
# (0, 500)

# %%
from analysis.lib import fitting
from analysis.lib.m2.ssro import sequence
from analysis.lib.tools import toolbox
from analysis.lib.fitting import fit,esr
from analysis.lib.tools import plot

ssro_calib_folder = toolbox.latest_data(contains='AdwinSSRO_SSROCalibration') 
print ssro_calib_folder
folder = toolbox.latest_data('Multiple')
a = sequence.SequenceAnalysis(folder)
a.get_sweep_pts()
a.get_readout_results('ssro')
a.get_electron_ROC(ssro_calib_folder=ssro_calib_folder)
fig, ax = plt.subplots(1,1)
a.plot_result_vs_sweepparam(ret=True, name='ssro', ax=ax)
# Out:
# d:\measuring\data\20141010\111638_AdwinSSRO_SSROCalibration_Gretel_sil10

# %%
execfile (r'D:\measuring\analysis\scripts\magnetometry\magnetometry_calibration.py')
# Out:
# d:\measuring\data\20141015\153113_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_manyreps_28_
# d:\measuring\data\20141015\113131_AdwinSSRO_SSROCalibration_Gretel_sil10
# x  [ 1280.   640.   320.   160.    80.    40.    20.]
# y [ 7.91384474  0.5192352   0.81870537  7.8677724   1.0721032   0.84174153
#   7.84473624]
# a <analysis.lib.m2.ssro.sequence.SequenceAnalysis instance at 0x2C4236C0>
# Converged with chi squared
#  142.112208346
# degrees of freedom, dof  4
# RMS of residuals (i.e. sqrt(chisq/dof))  5.96054125785
# Reduced chisq (i.e. variance of residuals)  35.5280520866
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f             -0.000518 +/- 25021.293645
#  1 A             -0.000000 +/-   2.600883
#  2 phi         -313.314869 +/- 5402820830.826860
#
# correlation matrix:
#                f         A         phi
#          f  1.000000
#          A -0.574513  1.000000
#        phi  0.732600 -0.614252  1.000000
# d:/measuring\analysis\lib\m2\ssro\sequence.py:75: RuntimeWarning: invalid value encountered in sqrt
#   self.u_normalized_ssro = (self.normalized_ssro*(1.-self.normalized_ssro)/(float(self.reps/n_points)))**0.5

# %% [markdown]
# # Magnetometry

# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
execfile (r'D:\measuring\analysis\scripts\magnetometry\adaptive_magnetometry_analysis.py')
# Out:
# d:\measuring\data\20141015\155316_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_0_
# d:\measuring\data\20141015\155340_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_1_
# d:\measuring\data\20141015\155441_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_2_
# d:\measuring\data\20141015\155524_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_3_
# d:\measuring\data\20141015\155709_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_4_
# d:\measuring\data\20141015\155756_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_5_
# d:\measuring\data\20141015\155836_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_6_
# d:\measuring\data\20141015\155937_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_7_
# d:\measuring\data\20141015\160010_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_8_
# d:\measuring\data\20141015\160044_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_9_
# d:\measuring\data\20141015\160127_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_10_
# d:\measuring\data\20141015\160203_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_11_
# d:\measuring\data\20141015\160254_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_12_
# d:\measuring\data\20141015\160342_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_13_
# d:\measuring\data\20141015\160432_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_14_
# d:\measuring\data\20141015\160522_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_15_
# d:\measuring\data\20141015\160612_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_16_
# d:\measuring\data\20141015\160710_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_17_
# d:\measuring\data\20141015\160738_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_18_
# d:\measuring\data\20141015\160826_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_19_
# d:\measuring\data\20141015\160857_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_20_
# d:\measuring\data\20141015\160921_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_21_
# d:\measuring\data\20141015\160953_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_22_
# d:\measuring\data\20141015\161029_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_23_
# d:\measuring\data\20141015\161102_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_24_
# d:\measuring\data\20141015\161144_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_25_
# d:\measuring\data\20141015\161228_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_26_
# d:\measuring\data\20141015\161312_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_27_
# d:\measuring\data\20141015\161351_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_28_
# d:\measuring\data\20141015\161524_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_29_
# d:\measuring\data\20141015\161616_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_30_
# d:\measuring\data\20141015\161658_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_31_
# d:\measuring\data\20141015\161733_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_32_
# d:\measuring\data\20141015\161805_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_33_
# d:\measuring\data\20141015\161834_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_34_
# d:\measuring\data\20141015\161937_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_35_
# d:\measuring\data\20141015\162021_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_36_
# d:\measuring\data\20141015\162110_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_37_
# d:\measuring\data\20141015\162144_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_38_
# d:\measuring\data\20141015\162255_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_39_
# d:\measuring\data\20141015\155316_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_0_
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [7 1 2 7 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [0]
# (*) [6 1 1 7 1 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [1]
# (*) [7 1 0 7 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [2]
# (*) [7 0 4 1 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [3]
# (*) [7 2 1 6 2 3 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [4]
# (*) [7 1 2 5 1 0 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [5]
# (*) [7 0 4 1 0 0 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [6]
# (*) [7 2 3 7 3 5 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [7]
# (*) [7 1 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [8]
# (*) [7 1 1 7 2 3 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [9]
# (*) [6 3 1 7 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [10]
# (*) [7 0 1 5 2 0 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [11]
# (*) [5 2 4 0 0 1 5]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [12]
# (*) [7 4 7 7 0 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [13]
# (*) [7 3 2 7 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [14]
# (*) [7 3 3 7 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [15]
# (*) [7 1 2 6 3 1 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [16]
# (*) [7 2 1 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [17]
# (*) [7 2 2 7 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [18]
# (*) [7 1 3 6 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [19]
# (*) [7 2 1 7 2 1 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [20]
# (*) [7 2 0 7 3 3 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [21]
# (*) [7 1 0 7 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [22]
# (*) [7 3 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [23]
# (*) [7 0 3 7 1 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [24]
# (*) [7 2 1 7 1 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [25]
# (*) [7 2 2 7 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [26]
# (*) [7 0 3 7 1 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [27]
# (*) [7 3 1 7 3 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [28]
# (*) [7 2 5 1 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [29]
# (*) [7 2 3 7 3 2 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [30]
# (*) [7 2 1 7 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [31]
# (*) [7 2 6 1 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [32]
# (*) [6 1 1 7 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [33]
# (*) [7 1 1 7 1 5 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [34]
# (*) [7 1 1 7 1 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [35]
# (*) [7 0 0 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [36]
# (*) [6 1 1 7 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [37]
# (*) [6 2 1 7 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [38]
# (*) [6 2 1 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [39]
# (*) [6 1 2 7 1 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [40]
# (*) [7 2 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [41]
# (*) [7 1 1 7 1 3 4]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [42]
# (*) [6 1 6 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [43]
# (*) [7 1 1 5 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [44]
# (*) [7 1 1 7 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [45]
# (*) [7 2 2 6 1 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [46]
# (*) [4 4 7 7 2 1 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [47]
# (*) [7 3 3 7 3 1 5]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [48]
# (*) [7 3 1 7 2 1 6]  -
# 1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [49]
# --------------------------------------------
# 0
#  5.78467886595
# d:\measuring\data\20141015\155340_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_1_
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [7 1 1 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [0]
# (*) [7 2 2 7 3 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [1]
# (*) [7 4 7 7 2 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [2]
# (*) [7 0 3 6 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [3]
# (*) [7 2 2 6 5 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [4]
# (*) [6 2 1 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [5]
# (*) [6 3 3 7 3 1 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [6]
# (*) [6 2 3 7 1 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [7]
# (*) [7 2 2 6 2 2 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [8]
# (*) [6 0 0 7 1 2 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [9]
# (*) [7 2 3 7 4 0 7]  -  2  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [10, 40]
# (*) [6 2 0 7 3 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [11]
# (*) [7 0 1 7 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [12]
# (*) [7 3 2 7 1 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [13]
# (*) [7 2 0 6 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [14]
# (*) [7 1 0 6 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [15]
# (*) [7 4 7 7 0 1 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [16]
# (*) [6 3 1 7 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [17]
# (*) [5 2 1 6 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [18]
# (*) [7 4 7 7 1 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [19]
# (*) [7 1 1 7 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [20]
# (*) [7 1 2 6 4 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [21]
# (*) [7 1 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [22]
# (*) [7 1 0 7 3 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [23]
# (*) [7 3 2 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [24]
# (*) [7 3 2 7 2 3 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [25]
# (*) [7 3 4 3 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [26]
# (*) [7 1 0 7 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [27]
# (*) [7 1 0 7 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [28]
# (*) [7 1 2 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [29]
# (*) [7 2 3 7 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [30]
# (*) [7 1 0 7 4 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [31]
# (*) [7 1 4 1 0 2 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [32]
# (*) [7 4 7 7 0 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [33]
# (*) [6 1 2 7 4 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [34]
# (*) [7 1 3 6 5 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [35]
# (*) [7 4 7 7 0 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [36]
# (*) [7 2 2 7 5 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [37]
# (*) [7 2 3 7 3 2 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [38]
# (*) [7 0 2 7 0 3 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [39]
# (*) [6 4 7 7 2 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [41]
# (*) [7 1 2 7 5 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [42]
# (*) [6 1 5 0 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [43]
# (*) [7 1 4 0 0 2 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [44]
# (*) [6 3 1 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [45]
# (*) [6 4 7 7 2 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [46]
# (*) [7 0 3 7 3 2 5]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]
#   deg
#      at indexes:  [47]
# (*) [6 1 2 7 1 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [48]
# (*) [6 1 1 7 6 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [49]
# --------------------------------------------
# 1
#  4.01006707405
# d:\measuring\data\20141015\155441_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_2_
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [7 1 2 7 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [0]
# (*) [7 5 7 7 0 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [1]
# (*) [6 1 4 1 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [2]
# (*) [6 1 3 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [3]
# (*) [7 1 4 3 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [4]
# (*) [7 2 1 6 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [5]
# (*) [7 3 3 6 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [6]
# (*) [7 3 5 0 0 2 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [7]
# (*) [7 3 1 6 2 5 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [8]
# (*) [5 2 2 7 2 3 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [9]
# (*) [7 3 3 6 3 1 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [10]
# (*) [7 1 2 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [11]
# (*) [7 3 0 7 3 5 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [12]
# (*) [7 2 1 7 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [13]
# (*) [6 0 2 7 6 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [14]
# (*) [7 2 4 1 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [15]
# (*) [6 3 3 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [16]
# (*) [5 0 3 6 1 3 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [17]
# (*) [7 2 1 7 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [18]
# (*) [7 4 7 7 0 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [19]
# (*) [7 1 4 1 0 2 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [20]
# (*) [6 1 2 7 0 2 5]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [21]
# (*) [6 3 1 5 3 5 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [22]
# (*) [6 1 4 0 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [23]
# (*) [7 3 1 6 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [24]
# (*) [7 1 2 5 5 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [25]
# (*) [7 1 1 7 3 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [26]
# (*) [7 1 1 7 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [27]
# (*) [7 0 1 7 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [28]
# (*) [7 2 3 6 3 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [29]
# (*) [7 0 2 7 1 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [30]
# (*) [7 2 2 5 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [31]
# (*) [7 0 4 0 0 0 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [32]
# (*) [7 1 1 7 3 3 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [33]
# (*) [6 4 7 7 0 1 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [34]
# (*) [7 0 2 7 1 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [35]
# (*) [7 2 2 7 0 2 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [36]
# (*) [6 2 2 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [37]
# (*) [7 3 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [38]
# (*) [6 3 2 7 1 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [39]
# (*) [6 3 2 5 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [40]
# (*) [4 3 1 7 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [41]
# (*) [7 4 7 7 2 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [42]
# (*) [7 1 2 7 1 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [43]
# (*) [6 3 3 7 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [44]
# (*) [7 1 2 6 5 0 7]
#   -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [45]
# (*) [7 4 7 7 0 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [46]
# (*) [6 1 2 6 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [47]
# (*) [7 1 2 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [48]
# (*) [7 0 2 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [49]
# --------------------------------------------
# 2
#  5.11853099178
# d:\measuring\data\20141015\155524_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_3_
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [5 2 2 7 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [0]
# (*) [7 2 1 7 5 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [1]
# (*) [7 1 3 7 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [2]
# (*) [7 2 2 7 1 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [3]
# (*) [7 2 3 6 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [4]
# (*) [7 3 3 7 2 2 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [5]
# (*) [5 3 4 0 0 1 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [6]
# (*) [7 2 1 6 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [7]
# (*) [7 2 2 5 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [8]
# (*) [6 1 2 7 6 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [9]
# (*) [7 0 1 6 3 1 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [10]
# (*) [6 2 2 7 1 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [11]
# (*) [7 1 2 7 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [12]
# (*) [7 1 2 5 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [13]
# (*) [7 2 2 6 2 1 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [14]
# (*) [6 2 4 0 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [15]
# (*) [6 2 2 6 2 3 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [16]
# (*) [6 1 4 3 0 0 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [17]
# (*) [7 1 2 6 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [18]
# (*) [7 0 1 7 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [19]
# (*) [7 2 2 7 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [20]
# (*) [5 2 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [21]
# (*) [7 2 2 5 3 7 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [22]
# (*) [7 1 4 0 0 1 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [23]
# (*) [6 3 3 6 1 2 5]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [24]
# (*) [7 1 3 5 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [25]
# (*) [7 3 2 7 3 2 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [26]
# (*) [7 1 2 7 0 2 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [27]
# (*) [7 2 3 7 1 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [28]
# (*) [7 0 1 6 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [29]
# (*) [7 2 2 7 1 2 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [30]
# (*) [7 3 0 6 6 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [31]
# (*) [7 4 7 7 1 4 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [32]
# (*) [7 0 1 7 7 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [33]
# (*) [7 4 7 7 0 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [34]
# (*) [6 1 1 7 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [35]
# (*) [7 1 2 7 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [36]
# (*) [4 4 7 7 1 0 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [37]
# (*) [5 3 3 7 5 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [38]
# (*) [7 2 2 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [39]
# (*) [7 2 2 6 1 3 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [40]
# (*) [7 2 2 6 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [41]
# (*) [5 2 4 0 0 1 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [42]
# (*) [7 3 2 5 3 2 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [43]
# (*) [6 3 4 0 0 2 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [44]
# (*) [7 2 0 3 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.   10.    5.    2.]  deg
#      at indexes:  [45]
# (*) [7 1 0 5 4 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [46]
# (*) [6 3 1 7 3 3 6]
#   -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [47]
# (*) [6 1 3 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [48]
# (*) [7 2 3 6 1 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [49]
# --------------------------------------------
# 3
#  4.56173658243
# d:\measuring\data\20141015\155709_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_4_
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [7 1 3 7 4 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [0]
# (*) [7 1 2 5 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [1]
# (*) [7 3 5 0 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [2]
# (*) [7 1 1 6 5 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [3]
# (*) [7 1 2 7 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [4]
# (*) [7 2 1 7 1 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [5]
# (*) [7 2 2 7 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [6]
# (*) [7 5 7 7 0 1 7]  -  2  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [7, 43]
# (*) [6 1 0 7 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [8]
# (*) [6 3 2 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [9]
# (*) [6 1 3 6 3 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [10]
# (*) [7 4 7 7 2 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [11]
# (*) [6 2 5 0 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [12]
# (*) [7 1 3 6 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [13]
# (*) [7 1 1 7 1 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [14]
# (*) [4 0 1 7 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [15]
# (*) [7 1 2 7 5 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [16]
# (*) [7 3 1 7 1 5 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [17]
# (*) [7 1 4 1 1 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [18]
# (*) [5 0 3 7 1 2 5]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [19]
# (*) [6 3 4 1 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [20]
# (*) [6 1 2 6 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [21]
# (*) [7 3 3 6 5 1 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [22]
# (*) [7 3 3 6 1 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [23]
# (*) [6 2 1 7 2 3 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [24]
# (*) [7 4 7 7 0 1 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [25]
# (*) [7 2 2 5 3 1 6]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [26]
# (*) [7 0 0 7 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [27]
# (*) [6 2 2 7 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [28]
# (*) [7 2 3 7 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [29]
# (*) [7 2 3 7 3 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [30]
# (*) [7 1 1 7 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [31]
# (*) [6 0 1 7 1 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [32]
# (*) [7 3 3 7 2 3 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [33]
# (*) [7 2 3 6 1 0 5]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [34]
# (*) [7 3 2 7 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [35]
# (*) [6 3 2 7 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [36]
# (*) [7 3 1 6 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [37]
# (*) [7 3 4 0 0 3 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [38]
# (*) [7 3 4 1 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [39]
# (*) [7 2 2 6 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [40]
# (*) [7 3 2 5 2 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [41]
# (*) [7 1 2 7 3 5 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [42]
# (*) [7 2 3 7 3 5 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [44]
# (*) [7 3 2 6 5 0 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [45]
# (*) [7 4 7 7 1 4 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [46]
# (*) [7 4 7 7 2 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [47]
# (*) [7 2 3 7 5 0 7]
#   -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [48]
# (*) [7 1 1 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [49]
# --------------------------------------------
# 4
#  4.68521632789
# d:\measuring\data\20141015\155756_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_5_
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [7 3 3 7 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [0]
# (*) [5 4 7 7 1 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [1]
# (*) [7 2 1 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [2]
# (*) [7 4 7 7 0 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [3]
# (*) [2 7 7 7 3 0 5]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.  326.  343.]  deg
#      at indexes:  [4]
# (*) [6 3 2 7 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [5]
# (*) [6 4 7 7 0 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [6]
# (*) [7 5 7 7 1 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [7]
# (*) [7 4 7 7 2 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [8]
# (*) [7 2 3 4 3 3 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [9]
# (*) [6 3 2 5 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [10]
# (*) [7 0 3 6 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [11]
# (*) [7 4 7 7 0 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [12]
# (*) [7 1 5 1 0 2 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [13]
# (*) [7 2 3 6 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [14]
# (*) [7 1 2 7 4 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [15]
# (*) [7 3 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [16]
# (*) [6 3 2 7 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [17]
# (*) [7 2 3 7 1 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [18]
# (*) [6 4 7 7 1 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [19]
# (*) [7 2 3 7 3 3 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [20]
# (*) [7 5 7 7 0 2 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [21]
# (*) [5 3 2 7 1 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [22]
# (*) [7 1 1 6 2 2 5]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [23]
# (*) [6 2 1 6 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [24]
# (*) [7 1 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [25]
# (*) [7 2 2 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [26]
# (*) [6 1 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [27]
# (*) [7 0 2 6 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [28]
# (*) [7 3 4 0 0 4 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.   82.]  deg
#      at indexes:  [29]
# (*) [6 3 4 1 1 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [30]
# (*) [7 1 2 6 4 1 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [31]
# (*) [6 1 2 7 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [32]
# (*) [6 2 3 7 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [33]
# (*) [6 1 1 6 5 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [34]
# (*) [7 5 7 7 2 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [35]
# (*) [7 3 1 6 3 3 4]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [36]
# (*) [7 4 7 7 0 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [37]
# (*) [5 2 3 6 7 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [38]
# (*) [7 3 3 5 3 5 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [39]
# (*) [6 2 2 4 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [40]
# (*) [6 2 0 6 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [41]
# (*) [7 2 3 6 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [42]
# (*) [7 3 5 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [43]
# (*) [7 4 7 7 2 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [44]
# (*) [7 1 4 0 0 1 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [45]
# (*) [7 3 2 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [46]
# (*) [7 6 7 7 1 1 7]
#   -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [47]
# (*) [7 2 4 1 0 1 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [48]
# (*) [6 2 3 6 3 2 5]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [49]
# --------------------------------------------
# 5
#  4.67987736727
# d:\measuring\data\20141015\155836_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_6_
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [6 4 7 7 0 3 5]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [0]
# (*) [7 1 1 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [1]
# (*) [7 3 3 6 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [2]
# (*) [6 3 1 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [3]
# (*) [7 3 2 6 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [4]
# (*) [7 2 3 5 6 0 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.   50.   24.]  deg
#      at indexes:  [5]
# (*) [6 2 2 7 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [6]
# (*) [6 4 7 7 2 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [7]
# (*) [7 3 2 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [8]
# (*) [6 2 3 7 3 5 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.   69.]  deg
#      at indexes:  [9]
# (*) [7 3 2 6 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [10]
# (*) [7 2 1 3 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.   10.    5.    2.]  deg
#      at indexes:  [11]
# (*) [7 2 3 6 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [12]
# (*) [7 1 2 7 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [13]
# (*) [7 1 4 0 0 1 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [14]
# (*) [7 1 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [15]
# (*) [6 2 4 0 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [16]
# (*) [7 1 3 7 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [17]
# (*) [6 4 7 7 0 1 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [18]
# (*) [7 2 1 7 2 3 5]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [19]
# (*) [7 3 1 7 3 5 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [20]
# (*) [6 2 2 7 2 1 5]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [21]
# (*) [6 3 3 6 1 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [22]
# (*) [6 2 3 6 2 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [23]
# (*) [7 3 3 6 1 2 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [24]
# (*) [7 0 5 0 0 3 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [25]
# (*) [6 2 1 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [26]
# (*) [7 3 5 0 0 0 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [27]
# (*) [7 3 3 7 2 2 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [28]
# (*) [7 2 1 6 1 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [29]
# (*) [7 2 3 7 2 3 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [30]
# (*) [7 0 3 7 4 1 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [31]
# (*) [7 3 5 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [32]
# (*) [7 2 2 7 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [33]
# (*) [6 1 2 7 3 3 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.  320.  340.]  deg
#      at indexes:  [34]
# (*) [7 1 2 7 2 5 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [35]
# (*) [7 4 7 7 2 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [36]
# (*) [6 2 2 7 3 1 6]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [37]
# (*) [7 3 4 0 0 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [38]
# (*) [6 2 3 7 5 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [39]
# (*) [6 1 3 7 2 3 5]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.  340.]  deg
#      at indexes:  [40]
# (*) [6 4 7 7 2 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [41]
# (*) [6 1 3 7 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.   21.  280.  320.   69.]  deg
#      at indexes:  [42]
# (*) [6 3 4 0 0 0 7]  -  2  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [43, 45]
# (*) [5 2 4 0 0 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [44]
# (*) [7 4 7 7 0 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [46]
# (*) [7 4 7 7 1 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [47]
# (*) [7 1 4 0 0 1 7]
#   -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [48]
# (*) [7 1 4 0 1 2 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [49]
# --------------------------------------------
# 6
#  5.64970947633
# d:\measuring\data\20141015\155937_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_7_
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [7 2 1 7 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [0]
# (*) [7 4 7 7 3 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [1]
# (*) [7 3 0 6 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.   22.  280.   50.   24.]  deg
#      at indexes:  [2]
# ...
#      at indexes:  [10]
# (*) [4 5 7 7 3 3 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [11]
# (*) [5 7 7 7 2 3 3]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [12]
# (*) [3 7 7 7 2 7 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.  326.   72.]  deg
#      at indexes:  [13]
# (*) [4 7 7 7 4 0 7]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.   62.   31.]  deg
#      at indexes:  [14]
# (*) [3 7 7 6 2 4 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.  326.   72.]  deg
#      at indexes:  [15]
# (*) [5 5 7 7 3 4 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [16]
# (*) [3 7 7 7 2 5 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.  326.   72.]  deg
#      at indexes:  [17]
# (*) [2 7 7 7 6 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [18]
# (*) [4 2 5 1 2 4 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.   82.]  deg
#      at indexes:  [19]
# (*) [5 6 7 7 1 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [20]
# (*) [5 7 7 7 3 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [21]
# (*) [2 7 7 7 4 0 6]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [22]
# (*) [2 7 7 7 4 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [23]
# (*) [5 4 7 7 2 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [24]
# (*) [6 5 7 7 6 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [25]
# (*) [6 6 7 7 1 4 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [26]
# (*) [6 7 7 7 3 6 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [27]
# (*) [3 7 6 7 2 5 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.  326.   72.]  deg
#      at indexes:  [28]
# (*) [3 7 7 7 4 1 7]  -  2  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [29, 48]
# (*) [5 5 7 7 4 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [30]
# (*) [5 4 7 7 1 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [31]
# (*) [4 5 7 7 4 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [32]
# (*) [6 7 7 7 1 4 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [34]
# (*) [3 7 7 7 3 3 5]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.  326.  343.]  deg
#      at indexes:  [35]
# (*) [5 6 7 7 2 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [36]
# (*) [4 6 7 7 3 3 3]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.  331.  346.]  deg
#      at indexes:  [37]
# (*) [4 6 7 7 4 0 7]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.   62.   31.]  deg
#      at indexes:  [38]
# (*) [6 3 5 0 1 1 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [39]
# (*) [5 4 7 7 6 0 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [41]
# (*) [4 6 7 7 3 2 6]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.  331.  346.]  deg
#      at indexes:  [42]
# (*) [3 7 7 6 6 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [43]
# (*) [4 6 7 7 2 5 7]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.  331.   76.]  deg
#      at indexes:  [44]
# (*) [6 7 7 6 4 1 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [45]
# (*) [2 7 7 6 5 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [46]
# (*) [5 4 7 7 4 1 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [47]
# (*) [4 6 7 7 3 4 7]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.  331.   76.]  deg
#      at indexes:  [49]
# --------------------------------------------
# 37
#  6.12909589833
# d:\measuring\data\20141015\162144_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_38_
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [4 6 7 7 3 4 7]  -  2  times --- phases:  [ 359.   90.  314.   66.  304.  331.   76.]  deg
#      at indexes:  [0, 37]
# (*) [5 5 7 7 2 4 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [1]
# (*) [5 3 6 0 0 3 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [2]
# (*) [3 7 7 7 3 5 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.  326.   72.]  deg
#      at indexes:  [3]
# (*) [6 3 5 1 3 2 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [4]
# (*) [5 7 7 7 2 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [5]
# (*) [3 7 7 6 4 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [6]
# (*) [5 6 7 7 3 3 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [7]
# (*) [5 1 5 1 3 1 6]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [8]
# (*) [5 4 7 7 2 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [9]
# (*) [5 6 7 7 2 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [10]
# (*) [6 6 7 7 2 4 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [11]
# (*) [2 7 7 6 3 4 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.  326.   72.]  deg
#      at indexes:  [12]
# (*) [3 7 7 6 5 1 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [13]
# (*) [5 3 7 0 0 3 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [14]
# (*) [6 5 7 7 3 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [15]
# (*) [1 7 7 6 6 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [16]
# (*) [3 7 7 7 6 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [17]
# (*) [6 2 7 0 3 4 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.   82.]  deg
#      at indexes:  [18]
# (*) [1 7 7 6 7 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [19]
# (*) [4 4 7 7 5 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [20]
# (*) [2 7 6 7 1 5 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.  326.   72.]  deg
#      at indexes:  [21]
# (*) [3 7 7 7 4 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [22]
# (*) [4 5 7 7 5 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [23]
# (*) [4 5 6 7 3 5 7]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.  331.   76.]  deg
#      at indexes:  [24]
# (*) [4 5 7 7 3 2 7]  -  2  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [25, 46]
# (*) [6 4 7 7 5 0 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [26]
# (*) [6 3 6 0 2 2 5]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [27]
# (*) [4 5 7 7 3 2 5]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [28]
# (*) [3 7 7 6 5 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [29]
# (*) [6 7 7 7 3 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [30]
# (*) [1 7 7 6 6 1 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [31]
# (*) [2 7 7 6 4 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [32]
# (*) [2 7 7 6 3 2 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.  326.  343.]  deg
#      at indexes:  [33]
# (*) [3 7 7 5 4 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [34]
# (*) [6 4 7 7 1 1 4]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [35]
# (*) [3 7 7 6 5 0 6]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [36]
# (*) [4 5 7 7 3 3 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [38]
# (*) [7 7 7 7 3 3 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [39]
# (*) [3 7 7 7 5 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [40]
# (*) [4 5 7 6 4 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [41]
# (*) [5 4 7 7 1 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [42]
# (*) [2 7 6 7 3 2 5]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.  326.  343.]  deg
#      at indexes:  [43]
# (*) [7 3 6 0 0 3 5]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [44]
# (*) [4 5 7 7 4 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [45]
# (*) [4 3 5 0 4 0 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.   73.   36.]  deg
#      at indexes:  [47]
# (*) [3 7 6 7 5 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [48]
# (*) [3 7 7 5 5 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [49]
# --------------------------------------------
# 38
#  5.54428325883
# d:\measuring\data\20141015\162255_adptv_estimation_det=-22.1875MHz_N=7_M=7_majReps=5_majThr=1CR40gr_pos_manyreps_39_
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [4 5 7 7 4 0 7]  -  2  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [0, 45]
# (*) [4 5 7 7 3 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [1]
# (*) [4 6 7 7 4 0 7]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.   62.   31.]  deg
#      at indexes:  [2]
# (*) [3 7 7 6 7 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [3]
# (*) [5 5 7 7 1 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [4]
# (*) [2 7 7 7 5 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [5]
# (*) [5 4 7 6 3 6 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [6]
# (*) [3 7 6 7 5 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [7]
# (*) [3 7 6 5 4 0 6]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [8]
# (*) [5 4 7 7 1 4 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [9]
# (*) [5 4 7 7 3 3 5]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [10]
# (*) [3 7 7 7 5 0 7]  -  2  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [11, 16]
# (*) [5 5 7 7 2 3 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [12]
# (*) [4 6 7 7 6 0 7]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.   62.   31.]  deg
#      at indexes:  [13]
# (*) [2 7 6 7 7 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [14]
# (*) [3 7 6 3 0 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.   22.   11.    5.]  deg
#      at indexes:  [15]
# (*) [5 5 7 7 3 7 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [17]
# (*) [5 5 7 6 3 4 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [18]
# (*) [4 5 7 7 2 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [19]
# (*) [4 5 7 6 5 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [20]
# (*) [4 5 7 7 2 4 7]  -  2  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [21, 37]
# (*) [5 6 7 7 1 6 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [22]
# (*) [4 6 7 7 3 5 7]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.  331.   76.]  deg
#      at indexes:  [23]
# (*) [6 4 7 7 3 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [24]
# (*) [5 3 6 0 1 4 7]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.   82.]  deg
#      at indexes:  [25]
# (*) [3 7 7 6 4 0 7]  -  2  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [26, 44]
# (*) [5 5 7 7 3 5 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [27]
# (*) [5 5 7 7 3 3 3]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [28]
# (*) [5 7 7 7 3 6 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [29]
# (*) [6 6 7 6 3 1 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [30]
# (*) [5 5 7 7 5 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [31]
# (*) [5 5 7 6 3 3 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [32]
# (*) [3 7 6 6 5 1 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [33]
# (*) [5 6 7 6 4 2 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [34]
# (*) [1 7 6 7 6 1 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [35]
# (*) [4 5 7 7 5 0 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.   62.   31.]  deg
#      at indexes:  [36]
# (*) [4 6 7 6 2 3 5]  -  1  times --- phases:  [ 359.   90.  314.   66.  304.  331.  346.]  deg
#      at indexes:  [38]
# (*) [6 5 7 7 3 6 7]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.   76.]  deg
#      at indexes:  [39]
# (*) [2 7 7 6 2 4 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.  326.   72.]  deg
#      at indexes:  [40]
# (*) [2 7 7 6 4 0 7]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [41]
# (*) [4 3 4 0 1 3 5]  -  1  times --- phases:  [ 359.   90.   45.  292.  325.  342.  351.]  deg
#      at indexes:  [42]
# (*) [5 7 7 7 3 3 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [43]
# (*) [5 4 7 7 1 1 6]  -  1  times --- phases:  [ 359.   90.  314.   67.  304.  331.  346.]  deg
#      at indexes:  [46]
# (*) [2 7 5 6 5 0 6]  -  1  times --- phases:  [ 359.  359.  269.   45.  291.   56.   28.]  deg
#      at indexes:  [47]
# (*) [2 7 7 5 4 0 6]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.   56.   28.]  deg
#      at indexes:  [48]
# (*) [2 7 7 6 3 3 5]  -  1  times --- phases:  [ 359.  359.  269.   45.  293.  326.  343.]  deg
#      at indexes:  [49]
# --------------------------------------------
# 39
#  5.60607489352

# %%
plt.figure()
plt.plot (np.array(error))
plt.plot (np.array(error),'ob')
plt.ylabel ('std [MHz]')
plt.xlabel ('instance nr')
plt.show()

# %% [markdown]
# Magnetometry simulations

# %%
B = [-10.8193,-10.708,-10.3888,-10.0499,-10.2066,-10.14,-10.003]
err = [0.6121,1.18025,0.7301,1.6123,0.608,0.613,1.35]
plt.plot (B, err,'o')

# %%
execfile (r'D:\measuring\analysis\scripts\magnetometry\adaptive_magnetometry_simulations.py')
# Out:
# --------------------------------------------
# Simulating Cappellaro protocol (table-based)
# --------------------------------------------
# - N = 7, M = 5
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# [ 4.  0.  0.  5.  0.  0.  5.]  - X 19 - phases:  [  0.  90.  45.  22. -79. -39. -20.]  - pos:  [     1.      6.     12.     48.   1344.   2640.  10416.]
# [ 5.  0.  0.  5.  0.  0.  5.]  - X 169 - phases:  [  0.  90.  45.  23. -79. -39. -20.]  - pos:  [     1.      7.     13.     49.   1345.   2641.  10417.]
# [ 3.  0.  0.  5.  0.  0.  5.]  - X 1 - phases:  [  0.  90.  45.  22. -79. -39. -20.]  - pos:  [     1.      7.     13.     49.   1345.   2641.  10417.]
# [ 5.  1.  0.  5.  0.  0.  5.]  - X 3 - phases:  [  0.  90.  45.  23. -79. -39. -20.]  - pos:  [     1.      7.     13.     49.   1345.   2641.  10417.]
# [ 5.  0.  0.  5.  1.  0.  5.]  - X 2 - phases:  [  0.  90.  45.  23. -79. -39. -20.]  - pos:  [     1.      7.     13.     49.   1345.   2641.  10417.]
# [ 4.  0.  1.  5.  0.  0.  5.]  - X 1 - phases:  [  0.  90.  45.  23. -79. -39. -20.]  - pos:  [     1.      7.     13.     49.   1345.   2641.  10417.]
# [ 5.  0.  1.  5.  0.  0.  5.]  - X 1 - phases:  [  0.  90.  45.  23. -79. -39. -20.]  - pos:  [     1.      5.     11.     47.   1343.   2639.  10415.]
# [ 5.  0.  0.  5.  0.  0.  4.]  - X 2 - phases:  [  0.  90.  45.  23. -79. -39. -20.]  - pos:  [     1.      6.     12.     48.   1344.   2640.  10416.]
# [ 4.  0.  0.  5.  0.  0.  4.]  - X 1 - phases:  [  0.  90.  45.  22. -79. -39. -20.]  - pos:  [     1.      7.     13.     49.   1345.   2641.  10417.]
# [ 5.  0.  0.  4.  0.  0.  5.]  - X 1 - phases:  [  0.  90.  45.  23. -79. -39. -20.]  - pos:  [     1.      7.     13.     49.   1345.   2641.  10417.]
# --------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-458-94c6f99dd564> in <module>()
# ----> 1 execfile (r'D:\measuring\analysis\scripts\magnetometry\adaptive_magnetometry_simulations.py')
#
# D:\measuring\analysis\scripts\magnetometry\adaptive_magnetometry_simulations.py in <module>()
#      68
#      69
# ---> 70 simulate_cappellaro()
#      71
#
# D:\measuring\analysis\scripts\magnetometry\adaptive_magnetometry_simulations.py in simulate_cappellaro()
#      40         s.print_table_positions()
#      41
# ---> 42         beta, p, err = s.mean_square_error(set_value=set_magnetic_field, do_plot=True)
#      43
#      44         s.sim_cappellaro_majority()
#
# ValueError: too many values to unpack

# %% [markdown]
# # Generate adaptive table

# %%
#do=float(raw_input('Do you really want to generate table?'))
#if do==1:
execfile (r'D:\measuring\analysis\scripts\magnetometry\generate_adaptive_table.py')
# Out:
# ******* Generating ADAPTIVE TABLE *********
#
# ##### N = 1 --- M = 5
# Total length array:  2
# ##### N = 2 --- M = 5
# Total length array:  8
# ##### N = 3 --- M = 5
# Total length array:  44
# ##### N = 4 --- M = 5
# Total length array:  260
# ##### N = 5 --- M = 5
# Total length array:  1556
# ##### N = 6 --- M = 5
# Total length array:  9332
# ##### N = 7 --- M = 5
# Total length array:  55988
# ##### N = 1 --- M = 3
# Total length array:  2
# ##### N = 2 --- M = 3
# Total length array:  6
# ##### N = 3 --- M = 3
# Total length array:  22
# ##### N = 4 --- M = 3
# Total length array:  86
# ##### N = 5 --- M = 3
# Total length array:  342
# ##### N = 6 --- M = 3
# Total length array:  1366
# ##### N = 7 --- M = 3
# Total length array:  5462
# ##### N = 1 --- M = 1
# Total length array:  2
# ##### N = 2 --- M = 1
# Total length array:  4
# ##### N = 3 --- M = 1
# Total length array:  8
# ##### N = 4 --- M = 1
# Total length array:  16
# ##### N = 5 --- M = 1
# Total length array:  32
# ##### N = 6 --- M = 1
# Total length array:  64
# ##### N = 7 --- M = 1
# Total length array:  128
# **** DONE!

# %%
for i in enumerate([1,2]):
    print i
# Out:
# (0, 1)
# (1, 2)

# %%
import numpy as np

def griddata(x, y, z, binsize=0.01, retbin=True, retloc=True):
    """
    Place unevenly spaced 2D data on a grid by 2D binning (nearest
    neighbor interpolation).
    
    Parameters
    ----------
    x : ndarray (1D)
        The idependent data x-axis of the grid.
    y : ndarray (1D)
        The idependent data y-axis of the grid.
    z : ndarray (1D)
        The dependent data in the form z = f(x,y).
    binsize : scalar, optional
        The full width and height of each bin on the grid.  If each
        bin is a cube, then this is the x and y dimension.  This is
        the step in both directions, x and y. Defaults to 0.01.
    retbin : boolean, optional
        Function returns `bins` variable (see below for description)
        if set to True.  Defaults to True.
    retloc : boolean, optional
        Function returns `wherebins` variable (see below for description)
        if set to True.  Defaults to True.
   
    Returns
    -------
    grid : ndarray (2D)
        The evenly gridded data.  The value of each cell is the median
        value of the contents of the bin.
    bins : ndarray (2D)
        A grid the same shape as `grid`, except the value of each cell
        is the number of points in that bin.  Returns only if
        `retbin` is set to True.
    wherebin : list (2D)
        A 2D list the same shape as `grid` and `bins` where each cell
        contains the indicies of `z` which contain the values stored
        in the particular bin.

    Revisions
    ---------
    2010-07-11  ccampo  Initial version
    """
    # get extrema values.
    xmin, xmax = x.min(), x.max()
    ymin, ymax = y.min(), y.max()

    # make coordinate arrays.
    xi      = np.arange(xmin, xmax+binsize, binsize)
    yi      = np.arange(ymin, ymax+binsize, binsize)
    xi, yi = np.meshgrid(xi,yi)

    # make the grid.
    grid           = np.zeros(xi.shape, dtype=x.dtype)
    nrow, ncol = grid.shape
    if retbin: bins = np.copy(grid)

    # create list in same shape as grid to store indices
    if retloc:
        wherebin = np.copy(grid)
        wherebin = wherebin.tolist()

    # fill in the grid.
    for row in range(nrow):
        for col in range(ncol):
            xc = xi[row, col]    # x coordinate.
            yc = yi[row, col]    # y coordinate.

            # find the position that xc and yc correspond to.
            posx = np.abs(x - xc)
            posy = np.abs(y - yc)
            ibin = np.logical_and(posx < binsize/2., posy < binsize/2.)
            ind  = np.where(ibin == True)[0]

            # fill the bin.
            bin = z[ibin]
            if retloc: wherebin[row][col] = ind
            if retbin: bins[row, col] = bin.size
            if bin.size != 0:
                binval         = np.median(bin)
                grid[row, col] = binval
            else:
                grid[row, col] = np.nan   # fill empty bins with nans.

    # return the grid
    if retbin:
        if retloc:
            return grid, bins, wherebin
        else:
            return grid, bins
    else:
        if retloc:
            return grid, wherebin
        else:
            return grid

# %%
print type(x)
print type(uniform(-2,2,npts))
# Out:
# <type 'numpy.ndarray'>
# <type 'numpy.ndarray'>

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import numpy.ma as ma
from numpy.random import uniform, seed
# make up some randomly distributed data
spctr_data=np.loadtxt(r'D:\measuring\data\20140912\095544_LaserScansGreenRepump_Gretel_SIL10_LT1_Red\095544_LaserScansGreenRepump_Gretel_SIL10_LT1_Red_noheader.dat')
#spctr_data=np.loadtxt(r'D:\measuring\data\20140913\125708_LaserScansGreenRepump_Gretel_SIL10_LT1_Red_Yellow/125708_LaserScansGreenRepump_Gretel_SIL10_LT1_Red_Yellow_noheader.dat')
seed(1234)
npts = 200
plt.clf()
x = spctr_data[:,1]
y = spctr_data[:,3]
zraw = spctr_data[:,2]
z=np.zeros(len(zraw))
print spctr_data[:,2].max()
print zraw.min()
z_max=10000
j=0
for i in zraw:
    if i > z_max:
        z[j]=z_max
    else:
        z[j]=zraw[j]
    j+=1    

print z.max()
print z.min()
# define grid.
xi = np.linspace(50,80,30000)
yi = np.linspace(0,31,32)
# grid the data.
zi = griddata((x, y), z, (xi[None,:], yi[:,None]), method='cubic')

for i in np.arange(shape(zi)[0]):
    for j in np.arange(shape(zi)[1]):
        if zi[i,j]<0:
            zi[i,j]=0

## contour the gridded data, plotting dots at the randomly spaced data points.
#CS = plt.contour(xi,yi,zi,15,linewidths=0.5,colors='k')
plt.figure(figsize=[15,15])
plt.subplot(2, 2, 1)
CS = plt.contourf(xi,yi,zi,cmap=plt.cm.Blues,vmin=0,vmax=z_max,alpha=0.75)
#CS = plt.imshow(xi,yi,zi,15,vmin=100, vmax=5000)
plt.colorbar() # draw colorbar
# plot data points.
#plt.scatter(x,y,marker='o',c='b',s=5)
plt.xlim(55,75)
plt.ylim(0,31)
plt.ylabel('Scan number')
plt.xlabel('Laser frequency detuning (GHz)')
#plt.title('griddata test (%d points)' % npts)
#plt.show()
# Out:
# 223300.0
# 20.0
# 10000.0
# 20.0

# %%
import numpy as np
import matplotlib.pyplot as plt


# plot some profiles / cross-sections for some visualization.  our
# function is a symmetric, upward opening paraboloid z = x**2 + y**2.
# We expect it to be symmetric about and and y, attain a minimum on
# the origin and display minor Gaussian noise.
plt.clf()
plt.ion()   # pyplot interactive mode on

# x vs z cross-section.  notice the noise.
plt.plot(x, z, '.')
plt.title('X vs Z=F(X,Y=constant)')
plt.xlabel('X')
plt.ylabel('Z')

# y vs z cross-section.  notice the noise.
plt.plot(y, z, '.')
plt.title('Y vs Z=F(Y,X=constant)')
plt.xlabel('Y')
plt.ylabel('Z')

# now show the dependent data (x vs y).  we could represent the z data
# as a third axis by either a 3d plot or contour plot, but we need to
# grid it first....
plt.plot(x, y, '.')
plt.title('X vs Y')
plt.xlabel('X')
plt.ylabel('Y')

# enter the gridding.  imagine drawing a symmetrical grid over the
# plot above.  the binsize is the width and height of one of the grid
# cells, or bins in units of x and y.
binsize = 1
grid, bins, binloc = griddata(x, y, z, binsize=binsize)  # see this routine's docstring


# minimum values for colorbar. filter our nans which are in the grid
zmin    = grid[np.where(np.isnan(grid) == False)].min()
zmax    = grid[np.where(np.isnan(grid) == False)].max()

# colorbar stuff
palette = plt.matplotlib.colors.LinearSegmentedColormap('jet3',plt.cm.datad['jet'],2048)
palette.set_under(alpha=0.0)

# plot the results.  first plot is x, y vs z, where z is a filled level plot.
extent = (x.min(), x.max(), y.min(), y.max()) # extent of the plot
plt.subplot(1, 2, 1)
plt.imshow(grid, extent=extent, cmap=palette, origin='lower', vmin=zmin, vmax=zmax, aspect='auto')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Z = F(X, Y)')
plt.colorbar()
'''
# now show the number of points in each bin.  since the independent data are
# Gaussian distributed, we expect a 2D Gaussian.
plt.subplot(1, 2, 2)
plt.imshow(bins, extent=extent, cmap=palette, origin='lower', vmin=0, vmax=bins.max(), aspect='auto', interpolation='bilinear')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('X, Y vs The No. of Pts Per Bin')
plt.colorbar()
'''
# Out:
# "\n# now show the number of points in each bin.  since the independent data are\n# Gaussian distributed, we expect a 2D Gaussian.\nplt.subplot(1, 2, 2)\nplt.imshow(bins, extent=extent, cmap=palette, origin='lower', vmin=0, vmax=bins.max(), aspect='auto', interpolation='bilinear')\nplt.xlabel('X values')\nplt.ylabel('Y values')\nplt.title('X, Y vs The No. of Pts Per Bin')\nplt.colorbar()\n"

# %%
print np.rint(np.array([1.,2.,3.]))
# Out:
# [ 1.  2.  3.]

# %%
np.round?

# %%
if 1<0:
    print 'yes'

# %%
zi[0,3000]>0
# Out:
# False

# %%
plt.contourf?

# %%
execfile (r'D:\measuring\analysis\scripts\magnetometry\oscilloscope_trace.py')
# Out:
# Converged with chi squared  11.0957305589
# degrees of freedom, dof  30137
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0191879218949
# Reduced chisq (i.e. variance of residuals)  0.000368176346646
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.031234 +/-   0.000001
#  1 A              0.260573 +/-   0.000157
#  2 phi           -0.126786 +/-   0.000188
#  3 o              0.015813 +/-   0.000111
#
# correlation matrix:
#                f         A         phi       o
#          f  1.000000
#          A  0.007396  1.000000
#        phi  0.861336  0.003438  1.000000
#          o -0.009666  0.046508 -0.027354  1.000000

# %%
x=np.linspace(0,0.02,100)
y=266.6*exp(-42.38*x)
plt.plot(x,y)

# %%
1/42.
# Out:
# 0.023809523809523808

# %%
1/0.03358
# Out:
# 29.779630732578916

# %%
#time = np.array([0,20,50,70])
#phases = np.array([313.5, 176.4, 154.4, 18.3])
time = np.array([-10,-15,-20])
phases = np.array([-0.0319, -0.18694, -0.349])*360.

time = np.array([70,80,85,90])
phases = np.array([16,131,186,245])
plt.plot(time, phases,'o')

# %%
((186-16)/360.)*1e-6/15e-9
# Out:
# 31.481481481481485
