# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')

# %%
nvlevels.get_ES_ExEy(63.4,68.6)
# Out:
# transitions kw deprecated, use function get_transitions instead
# array([ 58.26444714,  58.45867486,  63.00061287,  68.74642723,
#         68.99493998,  71.90489791])

# %%
ssro.ssrocalib(plot_photon_ms0=True)

# %% [markdown]
# # Standard Spin measurements

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# d:\measuring\data\20141003\092436_PulsarDarkESR_B_stab_nr_91_
# d:\measuring\data\20141002\140951_AdwinSSRO_SSROCalibration_Gretel_sil10
# fitting with 0 splittings
# Converged with chi squared  0.0331920295269
# degrees of freedom, dof  197
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0129802719358
# Reduced chisq (i.e. variance of residuals)  0.000168487459527
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.996795 +/-   0.000958
#  1 A              0.175134 +/-   0.006607
#  2 sigma         -0.000007 +/-   0.000000
#  3 x0             2.845350 +/-   0.000000
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.102569  1.000000
#      sigma -0.175815  0.547335  1.000000
#         x0  0.000000  0.004917  0.004214  1.000000
#
# ############################
# Population left  0.850563954232
# Population middle  -5.97370473032e-06
# Population right  0.149442019473
# #############################
# f0

# %%
execfile(r'D:\measuring\analysis\scripts\espin\electron_rabi_analysis.py')
# Out:
# Converged with chi squared  0.00867753506299
# degrees of freedom, dof  17
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0225929909264
# Reduced chisq (i.e. variance of residuals)  0.000510443238999
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.000046 +/-   0.000001
#  1 A              0.162969 +/-   0.012954
#  2 o              1.010348 +/-   0.012961
#  3 k              0.000001 +/-   0.000008
#
# correlation matrix:
#                f         A         o         k
#          f  1.000000
#          A  0.213958  1.000000
#          o  0.013178  0.904634  1.000000
#          k  0.346983  0.832451  0.693045  1.000000
#
# pi pulse = 10788.34 Pulse durations (ns)

# %% [markdown]
# # MBI Electron spin measurements

# %%
execfile(r'D:\measuring\analysis\scripts\mbi\mbi_dark_esr_analysis.py')
# Out:
# ############################
# Population left  0.0681690140845
# Population middle  0.0805633802817
# Population right  0.851267605634
# #############################
# Non-initialized population:  0.145882912899
# Electron initialization:   1.04485959067

# %%
execfile(r'D:\measuring\analysis\scripts\mbi\mbi_electron_rabi_analysis.py')
# Out:
# Converged with chi squared  0.00809044598836
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0249467833418
# Reduced chisq (i.e. variance of residuals)  0.000622341999105
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.000263 +/-   0.000001
#  1 A              0.413438 +/-   0.009080
#  2 o              0.985910 +/-   0.010189
#
# correlation matrix:
#                f         A         o
#          f  1.000000
#          A -0.019043  1.000000
#          o  0.103396  0.781872  1.000000

# %%
execfile(r'D:\measuring\analysis\scripts\mbi\mbi_electron_ramsey_analysis.py')
# Out:
# fitting with 2 modulation frequencies
# ((2.5e-05, 0.5, 0.0), (0.002188, 0.05, 180.0))
# Converged with chi squared  0.0318104973309
# degrees of freedom, dof  69
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0214714158929
# Reduced chisq (i.e. variance of residuals)  0.000461021700448
#
# fitted parameters at minimum, with 68% C.I.:
#  0 tau        -96131.282148 +/- 2385.960700
#  1 a              0.542579 +/-   0.002474
#  2 f0             0.000030 +/-   0.000000
#  3 A0            -0.440953 +/-   0.009272
#  4 phi0          -0.347668 +/-   0.031104
#  5 A1            -0.004314 +/-   0.007870
#  6 phi1         170.477628 +/-   1.805940
#
# correlation matrix:
#                tau       a         f0        A0        phi0      A1        phi1
#        tau  1.000000
#          a  0.015168  1.000000
#         f0 -0.024062  0.067546  1.000000
#         A0 -0.564402 -0.026435  0.042122  1.000000
#       phi0  0.030540 -0.084515 -0.814027 -0.053504  1.000000
#         A1  0.034245 -0.005822  0.032178 -0.067536 -0.034258  1.000000
#       phi1  0.062758 -0.034701 -0.100738 -0.110524  0.126308  0.027810  1.000000

# %% [markdown]
# # import h5py
# import matplotlib.pyplot as plt
# fileName=r'D:\TUD277246\Desktop\153003_scan2d.hdf5'
# f = h5py.File(fileName,  "r")
# f.keys()
#
# a=f['countrate']
# scan=a.value
# fig, ax = plt.subplots()
# p = ax.pcolor(scan)

# %%
print 50000/(sqrt(50**2+2000**2)), 'kHz'
print 0.001/4e-6, 'kHz'
# Out:
# 24.9921911602 kHz
# 250.0 kHz

# %%
print 1000/30.
print 1000/32.16
# Out:
# 33.3333333333
# 31.0945273632

# %%
spctr_data=np.loadtxt(r'D:\measuring\data\20140912\095544_LaserScansGreenRepump_Gretel_SIL10_LT1_Red\095544_LaserScansGreenRepump_Gretel_SIL10_LT1_Red_noheader.dat')

print shape(spctr_data)
print 42583/32.
print spctr_data[:,3]
frq=[]
cnts=[]
j=0


for i in spctr_data[:,3]:
    
    if spctr_data[j,3]==2:
        frq.append(spctr_data[j,1])
        cnts.append(spctr_data[j,2])
    j+=1
plt.plot(frq,cnts)
plt.xlim([57,59])
carray=np.array(cnts)
carray.max()
cnts.index(carray.max())
carray[921]
print frq[cnts.index(carray.max())]
# Out:
# (42583, 5)
# 1330.71875
# [  0.   0.   0. ...,  31.  31.  31.]
# 68.6515884399

# %%
carray=np.array(cnts)
carray.max()
cnts.index(carray.max())
carray[921]
print frq[cnts.index(carray.max())]
# Out:
# 68.7850418091

# %%
j=0
scan_nr=0
plt.clf()
frq=[]
cnts=[]

for i in spctr_data[:,3]:
    
    if spctr_data[j,3]==scan_nr:
        frq.append(spctr_data[j,1])
        if(spctr_data[j,2]>2000):
            cnt_rate=2000
        else:
            cnt_rate=spctr_data[j,2]
        cnts.append(cnt_rate+scan_nr*3000)
    else:
        scan_nr+=1    
        plt.plot(frq,cnts)
        print frq[200:205]
        frq=[]
        cnts=[]
    j+=1

plt.xlim(55,80)
plt.xlabel('Laser frequency detuning (GHz) ')
# Out:
# [49.785312652590001, 49.785312652590001, 49.850280761720001, 49.850280761720001, 49.850280761720001]
# [49.70115661621, 49.70115661621, 49.72728729248, 49.762935638430001, 49.762935638430001]
# [49.648281097409999, 49.648281097409999, 49.68952178955, 49.68952178955, 49.712677001949999]
# [49.566875457759998, 49.566875457759998, 49.606075286870002, 49.629806518549998, 49.650188446039998]
# [49.702304840090001, 49.742782592769998, 49.742782592769998, 49.768077850339999, 49.805381774899999]
# [49.579105377200001, 49.579105377200001, 49.618663787839999, 49.618663787839999, 49.67914199829]
# [49.615650176999999, 49.651054382319998, 49.67705154419, 49.697105407709998, 49.697105407709998]
# [49.734951019290001, 49.734951019290001, 49.797298431400002, 49.797298431400002, 49.819648742680002]
# [49.609741210940001, 49.650562286380001, 49.650562286380001, 49.6909866333, 49.71475982666]
# [49.684703826899998, 49.706535339360002, 49.706535339360002, 49.747741699220001, 49.747741699220001]
# [49.731369018549998, 49.753757476810001, 49.792694091800001, 49.792694091800001, 49.83666229248]
# [49.614212036129999, 49.614212036129999, 49.653587341310001, 49.677013397220001, 49.677013397220001]
# [49.631538391109999, 49.67225265503, 49.695724487299998, 49.695724487299998, 49.735359191889998]
# [49.706554412839999, 49.706554412839999, 49.735843658450001, 49.768032073969998, 49.768032073969998]
# [49.732604980470001, 49.774089813229999, 49.774089813229999, 49.7943649292, 49.835006713870001]
# [49.77448272705, 49.795150756840002, 49.817607879640001, 49.817607879640001, 49.859161376949999]
# [49.62303161621, 49.66216659546, 49.66216659546, 49.683731079099999, 49.724227905269998]
# [49.7144241333, 49.7144241333, 49.753959655759999, 49.774272918699999, 49.774272918699999]
# [49.728275299069999, 49.751945495610002, 49.773902893070002, 49.773902893070002, 49.81067276001]
# [49.771713256840002, 49.771713256840002, 49.806491851810001, 49.83373260498, 49.83373260498]
# [49.767127990719999, 49.806381225590002, 49.806381225590002, 49.828903198239999, 49.87041091919]
# [49.821125030520001, 49.821125030520001, 49.841663360600002, 49.881240844730002, 49.881240844730002]
# [49.675662994379998, 49.705646514889999, 49.720207214360002, 49.720207214360002, 49.75965499878]
# [49.702419281010002, 49.702419281010002, 49.742084503169998, 49.742084503169998, 49.768371582029999]
# [49.694889068599998, 49.735416412349998, 49.765880584720001, 49.78063583374, 49.814800262449999]
# [49.70799255371, 49.70799255371, 49.74118423462, 49.74118423462, 49.77502822876]
# [49.695011138920002, 49.695011138920002, 49.734928131099998, 49.757244110110001, 49.757244110110001]
# [49.760105133060001, 49.79621887207, 49.79621887207, 49.82939529419, 49.858367919919999]
# [49.770755767819999, 49.807628631589999, 49.807628631589999, 49.840106964109999, 49.869617462160001]
# [49.787349700930001, 49.787349700930001, 49.805507659909999, 49.832496643070002, 49.85083770752]
# [49.819847106929998, 49.819847106929998, 49.83794784546, 49.864124298100002, 49.864124298100002]

# %%
j=0
scan_nr=0
plt.clf()
frq=[]
cnts=[]
for i in spctr_data[:,3]:
    
    if spctr_data[j,3]==2:
        frq.append(spctr_data[j,1])
        cnt_rate=spctr_data[j,2]
        cnts.append(cnt_rate)
    j+=1
plt.plot(frq,cnts)
plt.xlim([55,78])
plt.ylim(0,500)
# Out:
# (0, 500)

# %%
fit_result
# Out:
# {'chisq': 1,
#  'cov': None,
#  'dof': 1,
#  'error': [],
#  'error_dict': {},
#  'fitfunc': <function analysis.lib.fitting.esr.fitfunc>,
#  'fitfunc_str': 'a - |A|*sum_i(exp(-((x-x0_i)/sigma)**2))\nsplitting s0 with multiplicity 3',
#  'p0': [<analysis.lib.fitting.fit.Parameter instance at 0x1AF2EAD0>,
#   <analysis.lib.fitting.fit.Parameter instance at 0x1AF2E490>,
#   <analysis.lib.fitting.fit.Parameter instance at 0x1AF2E7D8>,
#   <analysis.lib.fitting.fit.Parameter instance at 0x1AF2E080>,
#   <analysis.lib.fitting.fit.Parameter instance at 0x2B98E828>],
#  'params': array([  9.87644452e-01,   3.12960175e-01,   4.53323170e-05,
#           2.84506173e+00,   2.18000000e-03]),
#  'params_dict': {},
#  'reduced_chisq': 1,
#  'residuals_rms': 1.0,
#  'success': False,
#  'x': array([ 2.844859  ,  2.84487567,  2.84489233,  2.844909  ,  2.84492567,
#          2.84494233,  2.844959  ,  2.84497567,  2.84499233,  2.845009  ,
#          2.84502567,  2.84504233,  2.845059  ,  2.84507567,  2.84509233,
#          2.845109  ,  2.84512567,  2.84514233,  2.845159  ,  2.84517567,
#          2.84519233,  2.845209  ,  2.84522567,  2.84524233,  2.845259  ]),
#  'y': array([ 0.98275466,  0.99885031,  0.98390435,  0.97470683,  0.97125776,
#          0.95171304,  0.98620372,  1.00229938,  0.96550931,  0.89882732,
#          0.81030122,  0.73442171,  0.67463785,  0.71947574,  0.77006208,
#          0.86318694,  0.96780869,  1.01724534,  1.00114969,  0.98045528,
#          0.98735341,  0.95401242,  0.98505404,  1.00229938,  0.99885031])}

# %%
execfile (r'D:\measuring\analysis\scripts\magnetometry\magnetometry_calibration.py')
# Out:
# d:\measuring\data\20141002\153534_adptv_estimation_ramsey_sweep_phase10.0ns_
# d:\measuring\data\20141002\140951_AdwinSSRO_SSROCalibration_Gretel_sil10
# x  [   0.   18.   36.   54.   72.   90.  108.  126.  144.  162.  180.  198.
#   216.  234.  252.  270.  288.  306.  324.  342.  360.]
# y [ 0.0155214   0.05018083  0.1149789   0.23553345  0.38622664  0.53842676
#   0.65898131  0.8141953   0.92872212  0.96338156  0.99352019  0.92118746
#   0.85789632  0.73432791  0.64089813  0.45554551  0.33649789  0.22950573
#   0.09840265  0.03812538  0.02606992]
# a <analysis.lib.m2.ssro.sequence.SequenceAnalysis instance at 0x0B71AC88>
# Converged with chi squared
#  0.00798502803109
# degrees of freedom, dof  19
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0205003569046
# Reduced chisq (i.e. variance of residuals)  0.000420264633215
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A              0.491778 +/-   0.003516
#  1 phi          176.577483 +/-   0.755177
#
# correlation matrix:
#                A         phi
#          A  1.000000
#        phi -0.006472  1.000000

# %%
execfile (r'D:\measuring\analysis\scripts\magnetometry\adaptive_magnetometry_analysis.py')
# Out:
# d:\measuring\data\20141003\164057_adptv_estimation_det=100.0MHz_M=1_majReps=1_majThr=0_test
#  ---- Set phases -----
# [   8.47058824   19.76470588   31.05882353   42.35294118   62.11764706
#    80.47058824   84.70588235  100.23529412  103.05882353  107.29411765
#   111.52941176  115.76470588  125.64705882  129.88235294  134.11764706
#   136.94117647  138.35294118  139.76470588  142.58823529  144.
#   145.41176471  148.23529412  149.64705882  151.05882353  152.47058824
#   155.29411765  159.52941176  160.94117647  166.58823529  170.82352941
#   172.23529412  173.64705882  175.05882353  183.52941176  190.58823529
#   197.64705882  201.88235294  206.11764706  211.76470588  214.58823529
#   220.23529412  232.94117647  242.82352941  245.64705882  251.29411765
#   268.23529412  278.11764706  289.41176471  312.          313.41176471
#   323.29411765  334.58823529  345.88235294  357.17647059]
#
# ---    Measurement results  - SUMMARY    ---
# --------------------------------------------
# (*) [1 1 1 0 0 0 0]  -  1  times
# (*) [1 0 1 0 1 0 0]  -  27  times
# (*) [1 0 1 0 0 0 1]  -  1  times
# (*) [0 0 0 0 1 0 0]  -  1  times
# (*) [0 0 0 1 0 0 0]  -  1  times
# (*) [0 1 1 0 1 0 0]  -  2  times
# (*) [1 0 1 0 0 1 0]  -  2  times
# (*) [1 0 1 0 0 0 0]  -  4  times
# (*) [0 0 1 1 1 0 0]  -  4  times
# (*) [0 1 0 1 1 1 0]  -  1  times
# (*) [0 0 1 1 0 1 1]  -  1  times
# (*) [1 1 0 0 1 0 0]  -  1  times
# (*) [1 0 0 1 0 0 1]  -  1  times
# (*) [1 1 1 1 1 0 0]  -  1  times
# (*) [1 0 0 0 1 1 0]  -  1  times
# (*) [1 0 0 1 0 1 0]  -  1  times
# --------------------------------------------

# %%
import numpy as np

def griddata(x, y, z, binsize=0.01, retbin=True, retloc=True):
    """
    Place unevenly spaced 2D data on a grid by 2D binning (nearest
    neighbor interpolation).
    
    Parameters
    ----------
    x : ndarray (1D)
        The idependent data x-axis of the grid.
    y : ndarray (1D)
        The idependent data y-axis of the grid.
    z : ndarray (1D)
        The dependent data in the form z = f(x,y).
    binsize : scalar, optional
        The full width and height of each bin on the grid.  If each
        bin is a cube, then this is the x and y dimension.  This is
        the step in both directions, x and y. Defaults to 0.01.
    retbin : boolean, optional
        Function returns `bins` variable (see below for description)
        if set to True.  Defaults to True.
    retloc : boolean, optional
        Function returns `wherebins` variable (see below for description)
        if set to True.  Defaults to True.
   
    Returns
    -------
    grid : ndarray (2D)
        The evenly gridded data.  The value of each cell is the median
        value of the contents of the bin.
    bins : ndarray (2D)
        A grid the same shape as `grid`, except the value of each cell
        is the number of points in that bin.  Returns only if
        `retbin` is set to True.
    wherebin : list (2D)
        A 2D list the same shape as `grid` and `bins` where each cell
        contains the indicies of `z` which contain the values stored
        in the particular bin.

    Revisions
    ---------
    2010-07-11  ccampo  Initial version
    """
    # get extrema values.
    xmin, xmax = x.min(), x.max()
    ymin, ymax = y.min(), y.max()

    # make coordinate arrays.
    xi      = np.arange(xmin, xmax+binsize, binsize)
    yi      = np.arange(ymin, ymax+binsize, binsize)
    xi, yi = np.meshgrid(xi,yi)

    # make the grid.
    grid           = np.zeros(xi.shape, dtype=x.dtype)
    nrow, ncol = grid.shape
    if retbin: bins = np.copy(grid)

    # create list in same shape as grid to store indices
    if retloc:
        wherebin = np.copy(grid)
        wherebin = wherebin.tolist()

    # fill in the grid.
    for row in range(nrow):
        for col in range(ncol):
            xc = xi[row, col]    # x coordinate.
            yc = yi[row, col]    # y coordinate.

            # find the position that xc and yc correspond to.
            posx = np.abs(x - xc)
            posy = np.abs(y - yc)
            ibin = np.logical_and(posx < binsize/2., posy < binsize/2.)
            ind  = np.where(ibin == True)[0]

            # fill the bin.
            bin = z[ibin]
            if retloc: wherebin[row][col] = ind
            if retbin: bins[row, col] = bin.size
            if bin.size != 0:
                binval         = np.median(bin)
                grid[row, col] = binval
            else:
                grid[row, col] = np.nan   # fill empty bins with nans.

    # return the grid
    if retbin:
        if retloc:
            return grid, bins, wherebin
        else:
            return grid, bins
    else:
        if retloc:
            return grid, wherebin
        else:
            return grid

# %%
print type(x)
print type(uniform(-2,2,npts))
# Out:
# <type 'numpy.ndarray'>
# <type 'numpy.ndarray'>

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import numpy.ma as ma
from numpy.random import uniform, seed
# make up some randomly distributed data
spctr_data=np.loadtxt(r'D:\measuring\data\20140912\095544_LaserScansGreenRepump_Gretel_SIL10_LT1_Red\095544_LaserScansGreenRepump_Gretel_SIL10_LT1_Red_noheader.dat')
#spctr_data=np.loadtxt(r'D:\measuring\data\20140913\125708_LaserScansGreenRepump_Gretel_SIL10_LT1_Red_Yellow/125708_LaserScansGreenRepump_Gretel_SIL10_LT1_Red_Yellow_noheader.dat')
seed(1234)
npts = 200
plt.clf()
x = spctr_data[:,1]
y = spctr_data[:,3]
zraw = spctr_data[:,2]
z=np.zeros(len(zraw))
print spctr_data[:,2].max()
print zraw.min()
z_max=10000
j=0
for i in zraw:
    if i > z_max:
        z[j]=z_max
    else:
        z[j]=zraw[j]
    j+=1    

print z.max()
print z.min()
# define grid.
xi = np.linspace(50,80,30000)
yi = np.linspace(0,31,32)
# grid the data.
zi = griddata((x, y), z, (xi[None,:], yi[:,None]), method='cubic')

for i in np.arange(shape(zi)[0]):
    for j in np.arange(shape(zi)[1]):
        if zi[i,j]<0:
            zi[i,j]=0

## contour the gridded data, plotting dots at the randomly spaced data points.
#CS = plt.contour(xi,yi,zi,15,linewidths=0.5,colors='k')
plt.figure(figsize=[15,15])
plt.subplot(2, 2, 1)
CS = plt.contourf(xi,yi,zi,cmap=plt.cm.Blues,vmin=0,vmax=z_max,alpha=0.75)
#CS = plt.imshow(xi,yi,zi,15,vmin=100, vmax=5000)
plt.colorbar() # draw colorbar
# plot data points.
#plt.scatter(x,y,marker='o',c='b',s=5)
plt.xlim(55,75)
plt.ylim(0,31)
plt.ylabel('Scan number')
plt.xlabel('Laser frequency detuning (GHz)')
#plt.title('griddata test (%d points)' % npts)
#plt.show()
# Out:
# 223300.0
# 20.0
# 10000.0
# 20.0

# %%
import numpy as np
import matplotlib.pyplot as plt


# plot some profiles / cross-sections for some visualization.  our
# function is a symmetric, upward opening paraboloid z = x**2 + y**2.
# We expect it to be symmetric about and and y, attain a minimum on
# the origin and display minor Gaussian noise.
plt.clf()
plt.ion()   # pyplot interactive mode on

# x vs z cross-section.  notice the noise.
plt.plot(x, z, '.')
plt.title('X vs Z=F(X,Y=constant)')
plt.xlabel('X')
plt.ylabel('Z')

# y vs z cross-section.  notice the noise.
plt.plot(y, z, '.')
plt.title('Y vs Z=F(Y,X=constant)')
plt.xlabel('Y')
plt.ylabel('Z')

# now show the dependent data (x vs y).  we could represent the z data
# as a third axis by either a 3d plot or contour plot, but we need to
# grid it first....
plt.plot(x, y, '.')
plt.title('X vs Y')
plt.xlabel('X')
plt.ylabel('Y')

# enter the gridding.  imagine drawing a symmetrical grid over the
# plot above.  the binsize is the width and height of one of the grid
# cells, or bins in units of x and y.
binsize = 1
grid, bins, binloc = griddata(x, y, z, binsize=binsize)  # see this routine's docstring


# minimum values for colorbar. filter our nans which are in the grid
zmin    = grid[np.where(np.isnan(grid) == False)].min()
zmax    = grid[np.where(np.isnan(grid) == False)].max()

# colorbar stuff
palette = plt.matplotlib.colors.LinearSegmentedColormap('jet3',plt.cm.datad['jet'],2048)
palette.set_under(alpha=0.0)

# plot the results.  first plot is x, y vs z, where z is a filled level plot.
extent = (x.min(), x.max(), y.min(), y.max()) # extent of the plot
plt.subplot(1, 2, 1)
plt.imshow(grid, extent=extent, cmap=palette, origin='lower', vmin=zmin, vmax=zmax, aspect='auto')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Z = F(X, Y)')
plt.colorbar()
'''
# now show the number of points in each bin.  since the independent data are
# Gaussian distributed, we expect a 2D Gaussian.
plt.subplot(1, 2, 2)
plt.imshow(bins, extent=extent, cmap=palette, origin='lower', vmin=0, vmax=bins.max(), aspect='auto', interpolation='bilinear')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('X, Y vs The No. of Pts Per Bin')
plt.colorbar()
'''
# Out:
# "\n# now show the number of points in each bin.  since the independent data are\n# Gaussian distributed, we expect a 2D Gaussian.\nplt.subplot(1, 2, 2)\nplt.imshow(bins, extent=extent, cmap=palette, origin='lower', vmin=0, vmax=bins.max(), aspect='auto', interpolation='bilinear')\nplt.xlabel('X values')\nplt.ylabel('Y values')\nplt.title('X, Y vs The No. of Pts Per Bin')\nplt.colorbar()\n"

# %%
plt.contourf?

# %%
shape(zi)[1]
# Out:
# 30000

# %%
if 1<0:
    print 'yes'

# %%
zi[0,3000]>0
# Out:
# False

# %%
plt.contourf?

# %%
execfile (r'D:\measuring\analysis\scripts\magnetometry\oscilloscope_trace.py')
# Out:
# Converged with chi squared  11.0957305589
# degrees of freedom, dof  30137
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0191879218949
# Reduced chisq (i.e. variance of residuals)  0.000368176346646
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.031234 +/-   0.000001
#  1 A              0.260573 +/-   0.000157
#  2 phi           -0.126786 +/-   0.000188
#  3 o              0.015813 +/-   0.000111
#
# correlation matrix:
#                f         A         phi       o
#          f  1.000000
#          A  0.007396  1.000000
#        phi  0.861336  0.003438  1.000000
#          o -0.009666  0.046508 -0.027354  1.000000

# %%
x=np.linspace(0,0.02,100)
y=266.6*exp(-42.38*x)
plt.plot(x,y)

# %%
1/42.
# Out:
# 0.023809523809523808

# %%
1/0.03358
# Out:
# 29.779630732578916

# %%
#time = np.array([0,20,50,70])
#phases = np.array([313.5, 176.4, 154.4, 18.3])
time = np.array([-10,-15,-20])
phases = np.array([-0.0319, -0.18694, -0.349])*360.

time = np.array([70,80,85,90])
phases = np.array([16,131,186,245])
plt.plot(time, phases,'o')

# %%
((186-16)/360.)*1e-6/15e-9
# Out:
# 31.481481481481485
