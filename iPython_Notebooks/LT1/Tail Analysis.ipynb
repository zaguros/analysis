# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
folder=tb.latest_data('Bell')
#folder=tb.data_from_time('20140530141457')
#folder=r'D:\measuring\data\20140521\113406_Bell_lt1_tail_Pippin_SIL1_SM'
name = 'ssro'
a = pqsequence.TailAnalysis(folder, hdf5_mode='r', pq_folder = 'bs_remote')
#a.fix_sweep_pts('Pulse Amplitude', 'eom_pulse_amplitude')
a.get_sweep_pts()
a.get_sweep_idxs(noof_syncs_per_sweep_pt=250)
#a.sweep_pts=np.sqrt(a.sweep_pts)
a.get_readout_results(name)
a.get_tail_vs_sweep(0,5370.05,50, pq_binsize_ns=1e-3, hist_binsize_ns=1.,verbose=True)
# Out:
# X:\data\20140609\135713_Bell_BS_test_BS_lt1_tail_dac3_m1500_Ey\135713_Bell_BS_test_BS_lt1_tail_dac3_m1500_Ey.hdf5
# total_photons in channel 0 : 10995
# total_photons in window: 7316
# total_sweeps in window: 7316
# total ph in window with sweep element 0: 473
# div factor: 1516125

# %%
save=True
a.plot_tail_cts_vs_sweep(save=save)
a.plot_tail_hists_vs_sweep(save=save)
a.plot_tail_hist_integated(save=save, log_plot=True)
a.plot_tail_hist_all(save=save, log_plot=False, offset=0, indices=[0])
