# %%
import os, sys
msmtpath = r'D:\measuring'
if not msmtpath in sys.path:
    sys.path.append(msmtpath)
    
from measurement.lib.tools import toolbox as tb
from analysis.lib.m2.ssro import ssro, mbi, sequence
from analysis.scripts.teleportation import BSM_calibrations
reload(BSM_calibrations)
# Out:
# <module 'analysis.scripts.teleportation.BSM_calibrations' from 'D:\measuring\analysis\scripts\teleportation\BSM_calibrations.pyc'>

# %% [markdown]
# # STAGE 0.0 SSRO

# %%
ssro.ssrocalib()

# %% [markdown]
# ### (STAGE 0.3: Rabi to find good pi pulse length)

# %%
execfile('D:/measuring/analysis/scripts/espin/electron_rabi_analysis.py')
# Out:
# Converged with chi squared  0.000723280367946
# degrees of freedom, dof  16
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00672346807805
# Reduced chisq (i.e. variance of residuals)  4.52050229966e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.006711 +/-   0.000012
#  1 A              0.472295 +/-   0.003828
#  2 phi            0.029841 +/-   0.001506
#  3 o              0.998164 +/-   0.004078
#  4 k              0.000116 +/-   0.000076
#
# correlation matrix:
#                f         A         phi       o         k
#          f  1.000000
#          A -0.125340  1.000000
#        phi  0.876361 -0.131373  1.000000
#          o -0.144819  0.925446 -0.189681  1.000000
#          k -0.127070  0.826845 -0.132226  0.807385  1.000000

# %% [markdown]
# # STAGE 0.5 DARK ESR

# %%
execfile('D:/measuring/analysis/scripts/espin/dark_esr_analysis.py')
# Out:
# fitting with 1 splittings
# Converged with chi squared  0.050955257851
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0180154317875
# Reduced chisq (i.e. variance of residuals)  0.00032455578249
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.984232 +/-   0.001752
#  1 A              0.200869 +/-   0.008471
#  2 sigma          0.000216 +/-   0.000008
#  3 x0             2.828040 +/-   0.000010
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.317573  1.000000
#      sigma  0.200180 -0.604586  1.000000
#         x0  0.239507  0.750375 -0.451713  1.000000

# %% [markdown]
# # STAGE 1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# Slow pi pulse for MBI
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.0047622950428
# degrees of freedom, dof  7
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0260830953542
# Reduced chisq (i.e. variance of residuals)  0.000680327863256
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f             27.658152 +/-   1.039724
#  1 A              0.335598 +/-   0.017852
#  2 x0            -0.000973 +/-   0.000692
#  3 k             -8.250000 +/-   4.918823
#
# correlation matrix:
#                f         A         x0        k
#          f  1.000000
#          A  0.886752  1.000000
#         x0  0.972332  0.847558  1.000000
#          k  0.852422  0.926964  0.809043  1.000000

# %% [markdown]
# # STAGE 2

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# fast pi pulse
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00216323229454
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.016443966578
# Reduced chisq (i.e. variance of residuals)  0.000270404036817
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.975774 +/-   0.007322
#  1 a              6.844684 +/-   1.403469
#  2 x0             0.816497 +/-   0.006651
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.714219  1.000000
#         x0 -0.210711 -0.508593  1.000000
#
# ================================================================================
# fast pi/2 pulse
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.0011155281024
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0111331741626
# Reduced chisq (i.e. variance of residuals)  0.000123947566934
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a             -0.500703 +/-   0.053075
#  1 b              0.925216 +/-   0.042593
#
# correlation matrix:
#                a         b
#          a  1.000000
#          b -0.996890  1.000000
#
# ================================================================================
# CORPSE pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000152536830936
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00436658950062
# Reduced chisq (i.e. variance of residuals)  1.90671038669e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.983746 +/-   0.001988
#  1 a             57.715013 +/-   3.042304
#  2 x0             0.525576 +/-   0.000516
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.749160  1.000000
#         x0 -0.025918 -0.058840  1.000000
#
# ================================================================================
# pi2pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000244761143954
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00553128764342
# Reduced chisq (i.e. variance of residuals)  3.05951429943e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.926508 +/-   0.002446
#  1 a            719.872849 +/-  30.213607
#  2 x0             0.109864 +/-   0.000177
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.702483  1.000000
#         x0 -0.224605 -0.560681  1.000000

# %% [markdown]
# # STAGE 3:

# %%
BSM_calibrations.stage_3_calibrations()
# Out:
# ================================================================================
# Nitrogen Rabi oscillation
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00888518058259
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0261433630092
# Reduced chisq (i.e. variance of residuals)  0.00068347542943
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.010201 +/-   0.000128
#  1 A              0.218052 +/-   0.008727
#  2 x0             0.838784 +/-   1.413437
#  3 o              0.492649 +/-   0.006740
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A -0.033410  1.000000
#         x0  0.882415 -0.037850  1.000000
#          o -0.324688 -0.086085 -0.292397  1.000000

# %%
reload(BSM_calibrations)
BSM_calibrations.N_frq()
# Out:
# Converged with chi squared  0.00544795489104
# degrees of freedom, dof  17
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0179016182164
# Reduced chisq (i.e. variance of residuals)  0.000320467934767
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.629230 +/-   0.005828
#  1 A             -0.369545 +/-   0.011031
#  2 F              0.006828 +/-   0.000175
#  3 x0             7.134560 +/-   0.000128
#
# correlation matrix:
#                a         A         F         x0
#          a  1.000000
#          A -0.597110  1.000000
#          F  0.322789  0.184654  1.000000
#         x0  0.045417 -0.110294 -0.065841  1.000000
# (7.1345603257996428, 0.00012785809116043823)

# %% [markdown]
# # STAGE 4

# %%
def phaseref(frequency, time, offset=0):
    return ((frequency*time + offset/360.) % 1) * 360.

# %%
phaseref(2.19e6,200e-9)
# Out:
# 157.68

# %%
(2.19e6*20000e-9 + 0/360.) %1
# Out:
# 0.8000000000000043

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_4_calibrations()
# Out:
# ================================================================================
# CORPSE pi phase shift (look for the maximum)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000860110680248
# degrees of freedom, dof  5
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0131157209504
# Reduced chisq (i.e. variance of residuals)  0.00017202213605
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.005500 +/-   0.000066
#  1 A              0.494746 +/-   0.005883
#  2 x0            89.745291 +/-   0.384944
#  3 k             -0.000003 +/-   0.000137
#
# correlation matrix:
#                f         A         x0        k
#          f  1.000000
#          A -0.744254  1.000000
#         x0  0.047438 -0.078733  1.000000
#          k -0.350161  0.600752 -0.126096  1.000000

# %% [markdown]
# # STAGE 5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_5_calibrations()
# Out:
# ================================================================================
# UNROT evolution time calibration (look for the maximum)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00272995464733
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0144912563753
# Reduced chisq (i.e. variance of residuals)  0.000209996511333
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              2.197163 +/-   0.007407
#  1 A              0.495640 +/-   0.003716
#  2 x0            50.615254 +/-   0.001153
#  3 k              0.001397 +/-   0.000251
#
# correlation matrix:
#                f         A         x0        k
#          f  1.000000
#          A -0.307078  1.000000
#         x0  0.732433 -0.175975  1.000000
#          k -0.192523  0.528746 -0.179276  1.000000

# %% [markdown]
# # STAGE 6

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_6_calibrations()
# Out:
# ================================================================================
# spin echo (LDE-BSM) calibrations (look for the minimum)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.0182229330458
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0374401399629
# Reduced chisq (i.e. variance of residuals)  0.00140176408044
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.838470 +/-   0.012879
#  1 a              0.000000 +/-   0.000000
#  2 x0          -713.312267 +/- 134.608323
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.542189  1.000000
#         x0  0.173925  0.793804  1.000000

# %% [markdown]
# # STAGE 7

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_7_calibrations()
# Out:
# ================================================================================
# Hadamard phase calibration (aim for 10 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.0012778586458
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00991447522099
# Reduced chisq (i.e. variance of residuals)  9.82968189077e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.002743 +/-   0.000027
#  1 A              0.167404 +/-   0.003561
#  2 x0           -82.144074 +/-   2.759568
#  3 o              0.255196 +/-   0.002428
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.214006  1.000000
#         x0  0.907973  0.187321  1.000000
#          o -0.122810 -0.037935 -0.137912  1.000000

# %% [markdown]
# # STAGE 8

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_8_calibrations()
# Out:
# ================================================================================
# Hadamard evolution time calibration (aim for 01 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00109640208273
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00918360614077
# Reduced chisq (i.e. variance of residuals)  8.43386217488e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f          2174806.284681 +/- 26532.971411
#  1 A              0.168447 +/-   0.003102
#  2 x0             0.000035 +/-   0.000000
#  3 o              0.241451 +/-   0.002659
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.010304  1.000000
#         x0 -0.206823  0.107455  1.000000
#          o  0.525551  0.133311 -0.167382  1.000000
