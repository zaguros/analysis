# %%
execfile(r'D:/measuring/analysis/scripts/setup_analysis.py')
folder = r'D:\tmp\151941_PQPulsarMeasurement_FastSSROCalibration_test'
a = pqsequence.FastSSROAnalysis(folder)
a.get_sweep_pts()
a.get_readout_results('ssro')
a.get_sweep_idxs(noof_syncs_per_sweep_pt=1)
a.get_fastssro_results(channel=0,pq_binsize_ns=1.0, hist_binsize_ns=1000.0)
# Out:
# WARNING last sync number (12745) != noof reps (13243)! Sync error?

# %%
a.plot_fidelity_cpsh_vs_sweep(RO_length_ns=3000)
# Out:
# [  0.           0.           1.11111111   1.11111111   2.22222222
#    2.22222222   3.33333333   3.33333333   4.44444444   4.44444444
#    5.55555556   5.55555556   6.66666667   6.66666667   7.77777778
#    7.77777778   8.88888889   8.88888889  10.          10.        ]
# 10
#  10

# %%
a.ssro_plots(sweep_index = 5)
# Out:
# 100 100
# 10
#  10
# 100
#  100
# 150
#  150

# %%
a.extra_time_ns = 890
a.plot_mean_fidelity(9, plot_points=200,RO_length_ns=5000)

# %%
nvlevels.get_ES_ExEy(74.0,78.1)
# Out:
# transitions kw deprecated, use function get_transitions instead
# array([ 68.83321849,  68.94251501,  74.00036701,  78.09730407,
#         78.77641449,  81.77018092])

# %%
execfile(r'D:/measuring/analysis/scripts/setup_analysis.py')

# %%
from analysis.lib.nv import detection

# %%
detection.get_Ey_SSRO_stats_from_detection_efficiency(1,0.20)
detection.get_Ey_SSRO_stats_from_saturation(2,1450e3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-5ed1e4b40e18> in <module>()
#       1 detection.get_Ey_SSRO_stats_from_detection_efficiency(1,0.20)
# ----> 2 detection.get_Ey_SSRO_stats_from_saturation(2,1450e3)
#
# d:\measuring\analysis\lib\nv\detection.py in get_Ey_SSRO_stats_from_saturation(strain_splitting, saturation_counts)
#       7
#       8         eta=real_countrates*NV_effective_lifetime
# ----> 9         return get_RO_stats_from_detection_efficiency(strain_splitting, eta)
#      10
#      11 def get_Ey_SSRO_stats_from_detection_efficiency(strain_splitting, eta):
#
# NameError: global name 'get_RO_stats_from_detection_efficiency' is not defined

# %%
ssro.ssrocalib(plot_photon_ms0 = False)

# %%
pwd
# Out:
# u'D:\\Analysis'

# %%
execfile(r'D:/measuring/analysis/scripts/laser_scan/plot_simplest_gate_tuning.py')
