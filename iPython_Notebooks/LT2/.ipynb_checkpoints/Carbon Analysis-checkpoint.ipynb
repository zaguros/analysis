# %%
import sys
sys.path.append(r'/Users/Adriaan/Documents/teamdiamond/data')
sys.path.append(r'/Users/Adriaan/Documents/teamdiamond/')
import numpy as np
from analysis.scripts.mbi import mbi_electron_decoupling_analysis
from analysis.scripts.QEC import Carbon_control_analysis_sweep_N as cca; reload(cca)
from analysis.scripts.QEC import carbon_ramsey_phase_analysis as cr_ph
from analysis.scripts.QEC import carbon_ramsey_analysis as cr
# %matplotlib inline

# %% [markdown]
# #### Carbon 1

# %%
reload(cr)
fr =cr.Carbon_Ramsey(timestamp='20140519_141514',ssro_calib_timestamp= '20140519_093902',frequency = 200, offset = 0.5, amplitude = 0.5,  decay_constant = .008 ,phase =0, plot_fit = True, do_print = False, show_guess =False)
# Out:
# /Users/Adriaan/Documents/teamdiamond/data/20140519/093902_AdwinSSRO_SSROCalibration_Hans_sil1
# Converged with chi squared
#  0.00699162724357
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0197084686304
# Reduced chisq (i.e. variance of residuals)  0.000388423735754
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.483614 +/-   0.004109
#  1 A              0.463994 +/-   0.018867
#  2 T              0.009852 +/-   0.000387
#  3 n              1.827876 +/-   0.190524
#  4 f            202.895927 +/-   1.149855
#  5 phi            9.781373 +/-   2.078183
#
# correlation matrix:
#                a         A         T         n         f         phi
#          a  1.000000
#          A  0.081772  1.000000
#          T -0.043045 -0.743055  1.000000
#          n -0.077673 -0.721812  0.532200  1.000000
#          f -0.162600 -0.188199  0.138684  0.140514  1.000000
#        phi  0.196625  0.234844 -0.172639 -0.176529 -0.798605  1.000000
#
# ...

# %% [markdown]
# #### Carbon 2

# %%
reload(cr)
fr =cr.Carbon_Ramsey(timestamp='20140520_102218',ssro_calib_timestamp= '20140520_085319',frequency = 100, offset = 0.5, amplitude = 0.5,  decay_constant = .008 ,phase =0, plot_fit = True, do_print = False, show_guess = False)
# Out:
# /Users/Adriaan/Documents/teamdiamond/data/20140520/085319_AdwinSSRO_SSROCalibration_Hans_sil1
# Converged with chi squared
#  0.00239532629368
# degrees of freedom, dof  7
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0184983639959
# Reduced chisq (i.e. variance of residuals)  0.000342189470526
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.495032 +/-   0.005360
#  1 A              0.428921 +/-   0.024933
#  2 T              0.010539 +/-   0.000717
#  3 n              1.505520 +/-   0.210094
#  4 f            124.864165 +/-   1.583697
#  5 phi           28.622594 +/-   3.251206
#
# correlation matrix:
#                a         A         T         n         f         phi
#          a  1.000000
#          A -0.002329  1.000000
#          T -0.002791 -0.755092  1.000000
#          n  0.087816 -0.681605  0.565613  1.000000
#          f -0.198588 -0.356639  0.279614  0.249473  1.000000
#        phi  0.232677  0.437947 -0.343068 -0.314631 -0.785856  1.000000
#
# ...

# %% [markdown]
# #### Carbon 3

# %%
reload(cr)
fr =cr.Carbon_Ramsey(timestamp='20140520_134826',ssro_calib_timestamp= '20140520_085319',frequency = 200, offset = 0.5, amplitude = 0.5,  decay_constant = .008 ,phase =0, plot_fit = True, do_print = False, show_guess = False)
# Out:
# /Users/Adriaan/Documents/teamdiamond/data/20140520/085319_AdwinSSRO_SSROCalibration_Hans_sil1
# Converged with chi squared
#  0.00313426587186
# degrees of freedom, dof  11
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0168799662641
# Reduced chisq (i.e. variance of residuals)  0.000284933261078
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.484711 +/-   0.004176
#  1 A              0.389144 +/-   0.012250
#  2 T              0.009938 +/-   0.000294
#  3 n              2.487297 +/-   0.284345
#  4 f            204.177866 +/-   1.370155
#  5 phi          -34.655573 +/-   2.458530
#
# correlation matrix:
#                a         A         T         n         f         phi
#          a  1.000000
#          A -0.107403  1.000000
#          T  0.088766 -0.535913  1.000000
#          n  0.034926 -0.601135  0.209321  1.000000
#          f -0.141548  0.019993 -0.021229  0.000806  1.000000
#        phi  0.161268 -0.022052  0.021195  0.002294 -0.844071  1.000000
#
# ...

# %% [markdown]
# #### Carbon 4

# %%
reload(cr)
fr =cr.Carbon_Ramsey(timestamp='20140519_183105',ssro_calib_timestamp= '20140519_093902',frequency = 500, offset = 0.5, amplitude = 0.5,  decay_constant = .008 ,phase =0, plot_fit = True, do_print = False, show_guess = False)
# Out:
# /Users/Adriaan/Documents/teamdiamond/data/20140519/093902_AdwinSSRO_SSROCalibration_Hans_sil1
# Converged with chi squared
#  0.0085445167904
# degrees of freedom, dof  17
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0224191577614
# Reduced chisq (i.e. variance of residuals)  0.000502618634729
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.481690 +/-   0.004705
#  1 A              0.414049 +/-   0.014092
#  2 T              0.006679 +/-   0.000223
#  3 n              2.307635 +/-   0.307874
#  4 f            504.764332 +/-   1.968100
#  5 phi            1.211373 +/-   2.290412
#
# correlation matrix:
#                a         A         T         n         f         phi
#          a  1.000000
#          A -0.063502  1.000000
#          T  0.011420 -0.467453  1.000000
#          n  0.051424 -0.629924  0.064094  1.000000
#          f -0.050596 -0.043138  0.000418  0.045330  1.000000
#        phi  0.083498  0.045452 -0.009394 -0.040270 -0.816991  1.000000
#
# ...

# %%
f_msp1_cntr = 3.730069e9 
zfs = 2.877480e9
g_factor      =   2.8025e6 #Hz/Gauss
g_factor_C13  =       1.0705e3#Hz/Gauss

f_larmor = (f_msp1_cntr-zfs)*g_factor_C13/g_factor
print f_larmor
# Out:
# 325672.265656

# %%
reload(cr)
fr =cr.Carbon_Ramsey(timestamp='20140520_102218',ssro_calib_timestamp= '20140520_085319',frequency = 100, offset = 0.5, amplitude = 0.5,  decay_constant = .008 ,phase =0, plot_fit = True, do_print = False, show_guess = False)
# Out:
# /Users/Adriaan/Documents/teamdiamond/data/20140520/085319_AdwinSSRO_SSROCalibration_Hans_sil1
# Converged with chi squared
#  0.00239532629368
# degrees of freedom, dof  7
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0184983639959
# Reduced chisq (i.e. variance of residuals)  0.000342189470526
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.495032 +/-   0.005360
#  1 A              0.428921 +/-   0.024933
#  2 T              0.010539 +/-   0.000717
#  3 n              1.505520 +/-   0.210094
#  4 f            124.864165 +/-   1.583697
#  5 phi           28.622594 +/-   3.251206
#
# correlation matrix:
#                a         A         T         n         f         phi
#          a  1.000000
#          A -0.002329  1.000000
#          T -0.002791 -0.755092  1.000000
#          n  0.087816 -0.681605  0.565613  1.000000
#          f -0.198588 -0.356639  0.279614  0.249473  1.000000
#        phi  0.232677  0.437947 -0.343068 -0.314631 -0.785856  1.000000
#
# ...

# %%
reload(cr)
fr =cr.Carbon_Ramsey(timestamp='20140520_101755',ssro_calib_timestamp= '20140520_085319',frequency = 100, offset = 0.5, amplitude = 0.5,  decay_constant = .008 ,phase =0, plot_fit = True, do_print = False, show_guess = False)
# Out:
# /Users/Adriaan/Documents/teamdiamond/data/20140520/085319_AdwinSSRO_SSROCalibration_Hans_sil1
# Converged with chi squared
#  0.0130647734937
# degrees of freedom, dof  19
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0262225028851
# Reduced chisq (i.e. variance of residuals)  0.000687619657561
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.494025 +/-   0.006221
#  1 A              0.375748 +/-   0.019224
#  2 T              0.011085 +/-   0.000487
#  3 n              2.413233 +/-   0.551853
#  4 f            132.909217 +/-   1.461620
#  5 phi           17.965704 +/-   2.718543
#
# correlation matrix:
#                a         A         T         n         f         phi
#          a  1.000000
#          A  0.359823  1.000000
#          T  0.221697 -0.199395  1.000000
#          n -0.453659 -0.755731 -0.242431  1.000000
#          f -0.240455 -0.239776  0.055484  0.181221  1.000000
#        phi  0.349761  0.315744 -0.017174 -0.271462 -0.830298  1.000000
#
# ...
