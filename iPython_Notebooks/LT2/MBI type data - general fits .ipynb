# %% [markdown]
# ## General fits for MBI type data

# %%
import sys
import numpy as np

sys.path.append(r'D:/measuring')
sys.path.append(r'D:/measuring/analysis')

from analysis.scripts.mbi import mbi_data_general_fits as fits; reload(fits)
# Out:
# <module 'analysis.scripts.mbi.mbi_data_general_fits' from 'D:/measuring\analysis\scripts\mbi\mbi_data_general_fits.pyc'>

# %%
reload(fits)
Result = fits.exp_sin(timestamp=None, 
                      offset=[1], amplitude = [1], center = [0], decay_constant = [1000], exp_power = [1],
                      frequency = [0], phase =[0], 
                      fixed = [2,5,6],
                      ylim = None,
                      plot_fit = False, do_print = False, show_guess = True)
# Out:
# 1
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-7-be7fa83a7f16> in <module>()
#       5                       fixed = [2,5,6],
#       6                       ylim = None,
# ----> 7                       plot_fit = False, do_print = False, show_guess = True)
#
# D:\measuring\analysis\scripts\mbi\mbi_data_general_fits.pyc in exp_sin(timestamp, measurement_name, offset, amplitude, center, decay_constant, exp_power, frequency, phase, fixed, ylim, plot_fit, do_print, show_guess)
#      67             plot.plot_fit1d(fit_result, np.linspace(x[0],x[-1],201), ax=ax, plot_data=False)
#      68
# ---> 69         fit_results.append(fit_result)
#      70         print folder
#      71         plt.savefig(os.path.join(folder, 'analyzed_result.pdf'),
#
# UnboundLocalError: local variable 'fit_result' referenced before assignment
