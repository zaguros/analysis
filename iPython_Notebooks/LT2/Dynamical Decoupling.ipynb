# %% [markdown]
# # Dynamical Decoupling

# %%
sys.path.append(r'D:/measuring')
from analysis.scripts.mbi import mbi_electron_decoupling_analysis

# %% [markdown]
# ## MBI Decoupling

# %%
reload(mbi_electron_decoupling_analysis)
fit_results = mbi_electron_decoupling_analysis.electron_DD_analysis(power = 4,  T2 = 14e3,amplitude=0.45,
                                                                    timestamp=None, show_guess = False, plot_fit = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-187e7a61560b> in <module>()
#       1 reload(mbi_electron_decoupling_analysis)
#       2 fit_results = mbi_electron_decoupling_analysis.electron_DD_analysis(power = 4,  T2 = 14e3,amplitude=0.45,
# ----> 3                                                                     timestamp=None, show_guess = False, plot_fit = True)
#
# D:\measuring\analysis\scripts\mbi\mbi_electron_decoupling_analysis.pyc in electron_DD_analysis(timestamp, measurement_name, offset, amplitude, position, T2, power, plot_fit, do_print, show_guess)
#      43         ## plot data and fit as function of total time
#      44         if plot_fit == True:
# ---> 45             plot.plot_fit1d(fit_result, np.linspace(0,x[-1],201), ax=ax, plot_data=False)
#      46
#      47         fit_results.append(fit_result)
#
# ...

# %%
execfile(r'D:\measuring\analysis\scripts\QEC\DD_analysis_N64.py')
# Out:
# Converged with chi squared  0.36136094264
# degrees of freedom, dof  67
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0734400905846
# Reduced chisq (i.e. variance of residuals)  0.00539344690508
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A              0.416201 +/-   0.026945
#  1 T          16722.190791 +/- 1066.392993
#  2 n              1.778683 +/-   0.314379
#
# correlation matrix:
#                A         T         n
#          A  1.000000
#          T -0.720524  1.000000
#          n -0.722994  0.479732  1.000000
#
# d:\measuring\data\20140405\143754_DecouplingSequence_Hans_sil1_N4

# %%
execfile(r'D:\measuring\analysis\scripts\QEC\DD_analysis_combined.py')
# Out:
# Converged with chi squared  0.0895063528503
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0829765271954
# Reduced chisq (i.e. variance of residuals)  0.00688510406541
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A              0.358142 +/-   0.111974
#  1 T          59888.419242 +/- 20050.550569
#  2 n              1.233881 +/-   0.833036
#
# correlation matrix:
#                A         T         n
#          A  1.000000
#          T -0.884175  1.000000
#          n -0.857221  0.726932  1.000000
#
# Converged with chi squared
#  0.146805312876
# degrees of freedom, dof  47
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0558884361494
# Reduced chisq (i.e. variance of residuals)  0.00312351729523
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A              0.468027 +/-   0.044084
#  1 T          35184.281040 +/- 4181.092563
#  2 n              1.099484 +/-   0.198127
#
# correlation matrix:
#                A         T         n
# ...
