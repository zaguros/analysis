# %%
import sys
import os 
if os.name == 'posix':
    meassdir = r'/Users/'+os.getlogin()+r'/Documents/teamdiamond/'
else:
    meassdir = r'd:/measuring/'

sys.path.append(meassdir)
sys.path.append(meassdir+'analysis')
sys.path.append(meassdir+'analysis/scripts/QEC_data_analysis/fingerprints/')
sys.path.append(meassdir+'analysis/scripts/QEC/MScThesisAdriaan/')

sys.path
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Fingerprint
# Fingerprint data of the ms+1 transition for N=32 pulses in the range 0 to 20us with carbon 1-4 added with lines
#
# Data required:
#
# * SSRO Calibartion: 20140419\\111949_AdwinSSRO_SSROCalibration_Hans_sil1
# * Fingerprint data timestamp: 20140419_233953

# %%
import fingerprint_analysis as FP; reload(FP)
FP.fingerprint(N=32,disp_sim_spin=True,n_spins_to_disp = 4, disp_total_sig=False,
               figsize= (7,1.4),fontsize = 8,showlegend = False,title ='')
# Out:
# tau larmor = 3.07019208227e-06
# Figures saved in: /Users/Adriaan/Documents/teamdiamond/data/20140419/233953_DecouplingSequence_Fingerprint_Hans_sil132

# %% [markdown]
# ##Carbon Ramsey
# Ramsey experiment where two sines are superimposed. This is the ramsey without

# %%
from analysis.scripts.QEC import carbon_ramsey_phase_analysis as cr_ph
# Out:
# None
#
#
# yes
# Converged with chi squared  0.457155891894
# degrees of freedom, dof  63
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0851847564326
# Reduced chisq (i.e. variance of residuals)  0.00725644272847
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f1             0.338646 +/-   0.000252
#  1 A1             1.008008 +/-   0.028596
#  2 f2             0.014341 +/-   0.000376
#  3 A2             0.941004 +/-   0.024317
#
# correlation matrix:
#                f1        A1        f2        A2
#         f1  1.000000
#         A1 -0.020627  1.000000
#         f2  0.023632  0.195609  1.000000
#         A2 -0.010692 -0.446807 -0.377585  1.000000
#
# /Users/Adriaan/Documents/teamdiamond/data/20140521/164658_CarbonRamsey_Hans_sil1
# None
# yes
# Converged with chi squared  2.43428894179
# degrees of freedom, dof  92
# RMS of residuals (i.e. sqrt(chisq/dof))  0.162664262857
# Reduced chisq (i.e. variance of residuals)  0.0264596624108
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f1             0.305382 +/-   0.000332
#  1 A1             0.955282 +/-   0.046067
#  2 f2             0.016006 +/-   0.000332
#  3 A2             0.955768 +/-   0.042278
#
# correlation matrix:
#                f1        A1        f2        A2
#         f1  1.000000
#         A1 -0.047029  1.000000
#         f2  0.005716 -0.167756  1.000000
#         A2  0.015389 -0.335965  0.281783  1.000000
#
# /Users/Adriaan/Documents/teamdiamond/data/20140521/165249_CarbonRamsey_Hans_sil1
# None
# yes
# Converged with chi squared  0.312506831796
# degrees of freedom, dof  49
# RMS of residuals (i.e. sqrt(chisq/dof))  0.079860443555
# Reduced chisq (i.e. variance of residuals)  0.00637769044481
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f1             0.347408 +/-   0.000314
#  1 A1             1.060297 +/-   0.031290
#  2 f2             0.022731 +/-   0.000266
#  3 A2             0.997505 +/-   0.025613
#
# correlation matrix:
#                f1        A1        f2        A2
#         f1  1.000000
#         A1  0.028074  1.000000
#         f2  0.014084 -0.195093  1.000000
#         A2 -0.010702 -0.467713  0.303862  1.000000
#
# /Users/Adriaan/Documents/teamdiamond/data/20140521/170735_CarbonRamsey_Hans_sil1
# None
# yes
# Converged with chi squared  1.03690139839
# degrees of freedom, dof  92
# RMS of residuals (i.e. sqrt(chisq/dof))  0.106163399408
# Reduced chisq (i.e. variance of residuals)  0.0112706673738
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f1             0.343706 +/-   0.000186
#  1 A1             0.976419 +/-   0.025989
#  2 f2             0.019323 +/-   0.000222
#  3 A2             0.999555 +/-   0.028544
#
# correlation matrix:
#                f1        A1        f2        A2
#         f1  1.000000
#         A1 -0.000525  1.000000
#         f2 -0.013867  0.008404  1.000000
#         A2 -0.004476 -0.276243  0.158722  1.000000
#
# /Users/Adriaan/Documents/teamdiamond/data/20140521/162939_CarbonRamsey_Hans_sil1

# %%
reload(cr_ph)
Result=cr_ph.Carbon_Ramsey(timestamp=None,phase =[0], frequency = [200],amplitude= [.35], 
                           decay_constant = [.01],plot_fit=True,show_guess=False)
# Out:
# None
#
#
# yes
# Converged with chi squared  0.457155891894
# degrees of freedom, dof  63
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0851847564326
# Reduced chisq (i.e. variance of residuals)  0.00725644272847
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f1             0.338646 +/-   0.000252
#  1 A1             1.008008 +/-   0.028596
#  2 f2             0.014341 +/-   0.000376
#  3 A2             0.941004 +/-   0.024317
#
# correlation matrix:
#                f1        A1        f2        A2
#         f1  1.000000
#         A1 -0.020627  1.000000
#         f2  0.023632  0.195609  1.000000
#         A2 -0.010692 -0.446807 -0.377585  1.000000
#
# /Users/Adriaan/Documents/teamdiamond/data/20140521/164658_CarbonRamsey_Hans_sil1
# None
# yes
# Converged with chi squared  2.43428894179
# degrees of freedom, dof  92
# RMS of residuals (i.e. sqrt(chisq/dof))  0.162664262857
# Reduced chisq (i.e. variance of residuals)  0.0264596624108
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f1             0.305382 +/-   0.000332
#  1 A1             0.955282 +/-   0.046067
#  2 f2             0.016006 +/-   0.000332
#  3 A2             0.955768 +/-   0.042278
#
# correlation matrix:
#                f1        A1        f2        A2
#         f1  1.000000
#         A1 -0.047029  1.000000
#         f2  0.005716 -0.167756  1.000000
#         A2  0.015389 -0.335965  0.281783  1.000000
#
# /Users/Adriaan/Documents/teamdiamond/data/20140521/165249_CarbonRamsey_Hans_sil1
# None
# yes
# Converged with chi squared  0.312506831796
# degrees of freedom, dof  49
# RMS of residuals (i.e. sqrt(chisq/dof))  0.079860443555
# Reduced chisq (i.e. variance of residuals)  0.00637769044481
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f1             0.347408 +/-   0.000314
#  1 A1             1.060297 +/-   0.031290
#  2 f2             0.022731 +/-   0.000266
#  3 A2             0.997505 +/-   0.025613
#
# correlation matrix:
#                f1        A1        f2        A2
#         f1  1.000000
#         A1  0.028074  1.000000
#         f2  0.014084 -0.195093  1.000000
#         A2 -0.010702 -0.467713  0.303862  1.000000
#
# /Users/Adriaan/Documents/teamdiamond/data/20140521/170735_CarbonRamsey_Hans_sil1
# None
# yes
# Converged with chi squared  1.03690139839
# degrees of freedom, dof  92
# RMS of residuals (i.e. sqrt(chisq/dof))  0.106163399408
# Reduced chisq (i.e. variance of residuals)  0.0112706673738
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f1             0.343706 +/-   0.000186
#  1 A1             0.976419 +/-   0.025989
#  2 f2             0.019323 +/-   0.000222
#  3 A2             0.999555 +/-   0.028544
#
# correlation matrix:
#                f1        A1        f2        A2
#         f1  1.000000
#         A1 -0.000525  1.000000
#         f2 -0.013867  0.008404  1.000000
#         A2 -0.004476 -0.276243  0.158722  1.000000
#
# /Users/Adriaan/Documents/teamdiamond/data/20140521/162939_CarbonRamsey_Hans_sil1
# None
# guessed frequency is 200
# no
# ERROR: Fit did not converge !
# /Users/Adriaan/Documents/teamdiamond/data/20140710/223617_CarbonRamsey_Hans_sil1
