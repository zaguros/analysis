# %%
import sys
sys.path.append(r'D:/measuring')
from analysis.lib.m2.ssro import ssro
reload(ssro)
# Out:
# <module 'analysis.lib.m2.ssro.ssro' from 'D:/measuring\analysis\lib\m2\ssro\ssro.pyc'>

# %% [markdown]
# #### SSRO Calibration

# %%
ssro.ssrocalib()

# %% [markdown]
# #### Dark ESR

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# d:\measuring\data\20141015\104210_PulsarDarkESR_111_1_sil18
# d:\measuring\data\20141015\093014_AdwinSSRO_SSROCalibration_111_1_sil18
# 0.9
# 0.467584480601
# k17
# 81
# guess_ctr= 1.7462585
# test1
# Converged with chi squared  0.0211295402815
# degrees of freedom, dof  74
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0168977610389
# Reduced chisq (i.e. variance of residuals)  0.000285534328128
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A_min1         0.513378 +/-   0.011211
#  1 A_plus1        0.094763 +/-   0.009866
#  2 A_0            0.214158 +/-   0.009993
#  3 sigma          0.000291 +/-   0.000007
#  4 o              0.981963 +/-   0.002286
#  5 x0             1.746688 +/-   0.000010
#  6 Nsplit         0.002180 +/-   0.000010
#
# correlation matrix:
#                A_min1    A_plus1   A_0       sigma     o         x0        Nsplit
#     A_min1  1.000000
#    A_plus1  0.088763  1.000000
#        A_0  0.158439  0.095748  1.000000
#      sigma -0.474947 -0.010255 -0.159202  1.000000
#          o  0.097188  0.287532  0.234011  0.334513  1.000000
#         x0  0.000135  0.000028  0.000063 -0.000119  0.000000  1.000000
#     Nsplit  0.000117  0.000025  0.000055 -0.000102  0.000000  0.864208  1.000000
#
# ############################
# Population left  0.624319895804
# Population middle  0.260438102997
# Population right  0.115242001198
# #############################
# None

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis_single.py')
# Out:
# guess_ctr = 1.74446761741
# fitting with 0 splittings
# Converged with chi squared  0.0119164418835
# degrees of freedom, dof  47
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0159229807721
# Reduced chisq (i.e. variance of residuals)  0.00025354131667
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.942406 +/-   0.075457
#  1 A              0.490096 +/-   0.073240
#  2 sigma          0.000267 +/-   0.000030
#  3 x0             1.744469 +/-   0.000002
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.998683  1.000000
#      sigma  0.992417  0.986968  1.000000
#         x0 -0.012603 -0.012749 -0.011597  1.000000

# %% [markdown]
# #### Electron Rabi

# %%
execfile(r'D:\measuring\analysis\scripts\espin\electron_rabi_analysis.py')
# Out:
# Converged with chi squared  0.132345075594
# degrees of freedom, dof  17
# RMS of residuals (i.e. sqrt(chisq/dof))  0.088232672218
# Reduced chisq (i.e. variance of residuals)  0.00778500444673
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f             10.353693 +/-   0.493552
#  1 A              0.005377 +/-   0.036201
#  2 o              1.721138 +/-   0.040354
#  3 k             -1.550000 +/-   9.782574
#
# correlation matrix:
#                f         A         o         k
#          f  1.000000
#          A  0.142736  1.000000
#          o  0.162176  0.878026  1.000000
#          k  0.202396  0.953085  0.837670  1.000000
#
# pi pulse = 0.048 MW_pulse_amplitudes (V)

# %% [markdown]
# #### MBI Dark ESR

# %%
execfile(r'D:\measuring\analysis\scripts\mbi\mbi_dark_esr_analysis.py')
# Out:
# Converged with chi squared  0.0766842649031
# degrees of freedom, dof  95
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0284113144443
# Reduced chisq (i.e. variance of residuals)  0.000807202788454
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A_min1         0.022907 +/-   0.016585
#  1 A_plus1        0.056830 +/-   0.016573
#  2 A_0            0.761400 +/-   0.019643
#  3 sigma          0.176815 +/-   0.005354
#  4 o              0.992172 +/-   0.003214
#  5 x0          3730.066176 +/-   0.003696
#
# correlation matrix:
#                A_min1    A_plus1   A_0       sigma     o         x0
#     A_min1  1.000000
#    A_plus1  0.071906  1.000000
#        A_0  0.039829  0.056491  1.000000
#      sigma  0.038375  0.007416 -0.536804  1.000000
#          o  0.269493  0.262980  0.104389  0.216358  1.000000
#         x0  0.000009  0.000023  0.000255 -0.000217 -0.000000  1.000000
#
# ############################
# Population left  0.0272331952686
# Population middle  0.905203276432
# Population right  0.0675635282993
# #############################

# %% [markdown]
# #### MBI Rabi

# %%
execfile(r'D:\measuring\analysis\scripts\mbi\mbi_electron_rabi_analysis.py')
# Out:
# Converged with chi squared  0.0123006754076
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0261413629326
# Reduced chisq (i.e. variance of residuals)  0.000683370855975
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.016186 +/-   0.000061
#  1 A              0.388642 +/-   0.007838
#  2 o              1.013275 +/-   0.010101
#
# correlation matrix:
#                f         A         o
#          f  1.000000
#          A  0.049824  1.000000
#          o  0.107051  0.822590  1.000000

# %% [markdown]
# #### MBI Ramsey

# %%
execfile(r'D:\measuring\analysis\scripts\espin\electron_ramsey_analysis.py')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-4ceb9e67e881> in <module>()
# ----> 1 execfile(r'D:\measuring\analysis\scripts\espin\electron_ramsey_analysis.py')
#
# D:\measuring\analysis\scripts\espin\electron_ramsey_analysis.py in <module>()
#      40 a = sequence.SequenceAnalysis(folder)
#      41 a.get_sweep_pts()
# ---> 42 a.get_readout_results(name='ssro')
#      43 a.get_electron_ROC()
#      44 ax = a.plot_result_vs_sweepparam(ret='ax', name='ssro')
#
# D:\measuring\analysis\lib\m2\ssro\sequence.pyc in get_readout_results(self, name)
#      16         self.result_corrected = False
#      17
# ---> 18         adwingrp = self.adwingrp(name)
#      19         self.reps = adwingrp['completed_reps'].value
#      20         self.ssro_results = adwingrp['RO_data'].value
#
# D:\measuring\analysis\lib\m2\m2.pyc in adwingrp(self, name)
#      46                 return False
#      47
# ---> 48         return self.g[adwingrpname]
#      49
#      50     def analysis_h5data(self, name='analysis'):
#
# C:\Canopy\User\lib\site-packages\h5py\_hl\group.pyc in __getitem__(self, name)
#     151                 raise ValueError("Invalid HDF5 object reference")
#     152         else:
# --> 153             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     154
#     155         otype = h5i.get_type(oid)
#
# C:\Canopy\User\lib\site-packages\h5py\h5o.pyd in h5py.h5o.open (h5py\h5o.c:3143)()
#
# KeyError: "unable to open object (Symbol table: Can't open object)"

# %% [markdown]
# #### MBI RO electron flip analysis

# %%
execfile(r'D:\measuring\analysis\scripts\QEC\MBI_DESR_RO_flip_analysis.py')
# Out:
# Average = 0.996867463122

# %%
3000*50e-6
# Out:
# 0.15
