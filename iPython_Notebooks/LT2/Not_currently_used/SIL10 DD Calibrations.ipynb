# %%
sys.path.append(r'D:/measuring')
from analysis.lib.m2.ssro import ssro
from analysis.scripts.teleportation import DD_calibrations

# %% [markdown]
# # Stage0(.25) SSRO (with 7us SP)

# %%
ssro.ssrocalib()

# %% [markdown]
# # Stage 0.5 Dark ESR

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# Center guess?2.828
# fitting with 1 splittings
# Converged with chi squared  0.0801800068158
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0225986875804
# Reduced chisq (i.e. variance of residuals)  0.000510700680355
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.981165 +/-   0.002605
#  1 A              0.122543 +/-   0.006956
#  2 sigma         -0.000377 +/-   0.000024
#  3 x0             2.828744 +/-   0.000019
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.317241  1.000000
#      sigma -0.432054  0.468396  1.000000
#         x0  0.089345  0.610342  0.426063  1.000000

# %% [markdown]
# # Stage 1 Corpse

# %%
reload(DD_calibrations)
DD_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# CORPSE pi
# ================================================================================
# Converged with chi squared  0.0110419241406
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0371515883587
# Reduced chisq (i.e. variance of residuals)  0.00138024051758
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.933259 +/-   0.016498
#  1 a            105.260010 +/-  12.683343
#  2 x0             0.381202 +/-   0.001989
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.709583  1.000000
#         x0  0.218854  0.533072  1.000000

# %% [markdown]
# # Stage 1.5 pi/2 calbration, Cross

# %%
reload(DD_calibrations)
DD_calibrations.stage_1p5_calibrations()
# Out:
# ================================================================================
# CORPSE pi/2
# ================================================================================
# Converged with chi squared
#  0.00251650810877
# degrees of freedom, dof  19
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0115085965781
# Reduced chisq (i.e. variance of residuals)  0.000132447795198
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -2.846157 +/-   0.069124
#  1 x0             0.418192 +/-   0.000883
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0 -0.049697  1.000000

# %% [markdown]
# # stage 2: C13 revival time

# %%
#DD_calibrations.stage_2_calibrations()

# %% [markdown]
# # stage 3: LDE - DD spin echo time

# %%
reload(DD_calibrations)
#DD_calibrations.stage_3_calibrations()
# Out:
# <module 'analysis.scripts.teleportation.DD_calibrations' from 'D:/measuring\analysis\scripts\teleportation\DD_calibrations.pyc'>

# %% [markdown]
# # stage 4: time between pi pulses

# %%
DD_calibrations.stage_4_calibrations()
# Out:
# ================================================================================
# time between pi pulses
# ================================================================================
# Converged with chi squared  0.00094539538344
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00724720399511
# Reduced chisq (i.e. variance of residuals)  5.25219657467e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.965251 +/-   0.002373
#  1 a              0.013446 +/-   0.001210
#  2 x0             0.314702 +/-   0.049161
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.744021  1.000000
#         x0  0.069780  0.156095  1.000000
