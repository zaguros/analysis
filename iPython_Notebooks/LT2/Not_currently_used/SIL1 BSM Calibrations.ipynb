# %%
import os, sys
msmtpath = r'D:\measuring'
if not msmtpath in sys.path:
    sys.path.append(msmtpath)
    
from measurement.lib.tools import toolbox as tb
from analysis.lib.m2.ssro import ssro, mbi, sequence
from analysis.scripts.teleportation import BSM_calibrations
reload(BSM_calibrations)
# Out:
# <module 'analysis.scripts.teleportation.BSM_calibrations' from 'D:\measuring\analysis\scripts\teleportation\BSM_calibrations.pyc'>

# %% [markdown]
# # STAGE 0.0 SSRO

# %%
ssro.ssrocalib()

# %% [markdown]
# ### (STAGE 0.3: Rabi to find good pi pulse length)

# %%
execfile('D:/measuring/analysis/scripts/espin/electron_rabi_analysis.py')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-85c6077d61b8> in <module>()
# ----> 1 execfile('D:/measuring/analysis/scripts/espin/electron_rabi_analysis.py')
#
# D:\measuring\analysis\scripts\espin\electron_rabi_analysis.py in <module>()
#      49     a = sequence.SequenceAnalysis(folder)
#      50     a.get_sweep_pts()
# ---> 51     a.get_readout_results('ssro')
#      52     a.get_electron_ROC()
#      53     ax = a.plot_result_vs_sweepparam(ret='ax')
#
# D:\measuring\analysis\lib\m2\ssro\sequence.pyc in get_readout_results(self, name)
#      16         self.result_corrected = False
#      17
# ---> 18         adwingrp = self.adwingrp(name)
#      19         self.reps = adwingrp['completed_reps'].value
#      20         self.ssro_results = adwingrp['RO_data'].value
#
# D:\measuring\analysis\lib\m2\m2.pyc in adwingrp(self, name)
#      42                 return False
#      43
# ---> 44         return self.g[adwingrpname]
#      45
#      46     def analysis_h5data(self, name='analysis'):
#
# C:\Documents and Settings\localadmin\Local Settings\Application Data\Enthought\Canopy32\User\lib\site-packages\h5py\_hl\group.pyc in __getitem__(self, name)
#     151                 raise ValueError("Invalid HDF5 object reference")
#     152         else:
# --> 153             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     154
#     155         otype = h5i.get_type(oid)
#
# C:\Documents and Settings\localadmin\Local Settings\Application Data\Enthought\Canopy32\User\lib\site-packages\h5py\h5o.pyd in h5py.h5o.open (h5py\h5o.c:2946)()
#
# KeyError: "unable to open object (Symbol table: Can't open object)"

# %% [markdown]
# # STAGE 0.5 DARK ESR

# %%
execfile('D:/measuring/analysis/scripts/espin/dark_esr_analysis.py')
# Out:
# fitting with 1 splittings
# Converged with chi squared  0.0181395287757
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0107488790041
# Reduced chisq (i.e. variance of residuals)  0.000115538399846
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.993832 +/-   0.001056
#  1 A              0.203540 +/-   0.004863
#  2 sigma          0.000232 +/-   0.000005
#  3 x0             2.828112 +/-   0.000006
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.309328  1.000000
#      sigma  0.215168 -0.611379  1.000000
#         x0  0.218604  0.746026 -0.474945  1.000000

# %% [markdown]
# # STAGE 1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# Slow pi pulse for MBI
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00256562112271
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0168839868999
# Reduced chisq (i.e. variance of residuals)  0.000285069013634
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f             30.157090 +/-   0.162418
#  1 A              0.386918 +/-   0.004276
#
# correlation matrix:
#                f         A
#          f  1.000000
#          A  0.243912  1.000000

# %% [markdown]
# # STAGE 2

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# fast pi pulse
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.001205138505
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0122736430258
# Reduced chisq (i.e. variance of residuals)  0.000150642313125
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.979768 +/-   0.005198
#  1 a              4.511252 +/-   1.047538
#  2 x0             0.831439 +/-   0.009765
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.606249  1.000000
#         x0 -0.217833 -0.747617  1.000000
#
# ================================================================================
# CORPSE pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000139331939089
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00417330712817
# Reduced chisq (i.e. variance of residuals)  1.74164923861e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.987100 +/-   0.001820
#  1 a             47.201670 +/-   2.907640
#  2 x0             0.516801 +/-   0.000786
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.676125  1.000000
#         x0  0.239098  0.642638  1.000000
#
# ================================================================================
# pi2pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000415192679207
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00720410194964
# Reduced chisq (i.e. variance of residuals)  5.18990849008e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.936967 +/-   0.003270
#  1 a            819.449751 +/-  39.351038
#  2 x0             0.108305 +/-   0.000172
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.744303  1.000000
#         x0 -0.100770 -0.224670  1.000000
#
# ================================================================================
# pi2pi, m_I=0
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000830671215455
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0101898921453
# Reduced chisq (i.e. variance of residuals)  0.000103833901932
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.926576 +/-   0.004623
#  1 a            747.370387 +/-  55.660349
#  2 x0             0.106654 +/-   0.000268
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.743937  1.000000
#         x0  0.106604  0.235456  1.000000

# %% [markdown]
# # STAGE 2.5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2p5_calibration()
# Out:
# ================================================================================
# fast pi/2 pulse
# ================================================================================
# Converged with chi squared
#  0.00114006300463
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0112549396791
# Reduced chisq (i.e. variance of residuals)  0.000126673667181
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -0.768700 +/-   0.053656
#  1 x0             0.807746 +/-   0.004448
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0  0.121572  1.000000

# %% [markdown]
# # STAGE 3:

# %%
BSM_calibrations.stage_3_calibrations()
# Out:
# ================================================================================
# Nitrogen Rabi oscillation
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00161406952145
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0111426744527
# Reduced chisq (i.e. variance of residuals)  0.000124159193958
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.010392 +/-   0.000025
#  1 A             -0.458663 +/-   0.003726
#  2 x0             0.942130 +/-   0.277185
#  3 o              0.501033 +/-   0.002837
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A -0.007797  1.000000
#         x0  0.878600  0.009294  1.000000
#          o  0.280195 -0.115931  0.259211  1.000000

# %%
reload(BSM_calibrations)
BSM_calibrations.N_frq()
# Out:
# WARNING:root:Cannot find any data folder containing 'NMR_frq_scan'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c0133e218821> in <module>()
#       1 reload(BSM_calibrations)
# ----> 2 BSM_calibrations.N_frq()
#
# D:\measuring\analysis\scripts\teleportation\BSM_calibrations.py in N_frq(ax)
#     494     if ax==None:
#     495         fig,ax = plt.subplots(1,1)
# --> 496     fit_result = fit_population_vs_detuning(folder, ax, 7.135)
#     497
#     498     x0 = fit_result['params_dict']['x0']
#
# D:\measuring\analysis\scripts\teleportation\BSM_calibrations.py in fit_population_vs_detuning(folder, ax, *args)
#     232
#     233 def fit_population_vs_detuning(folder, ax, *args):
# --> 234     a = mbi.MBIAnalysis(folder)
#     235     a.get_sweep_pts()
#     236     a.get_readout_results(name='adwindata')
#
# D:\measuring\analysis\lib\m2\m2.pyc in __init__(self, folder)
#      14     def __init__(self, folder):
#      15         self.folder = folder
# ---> 16         self.load_hdf5data()
#      17
#      18
#
# D:\measuring\analysis\lib\m2\m2.pyc in load_hdf5data(self)
#      18
#      19     def load_hdf5data(self):
# ---> 20         self.h5filepath = toolbox.measurement_filename(self.folder)
#      21         self.f = h5py.File(self.h5filepath, 'r')
#      22         self.name = self.f.keys()[0]
#
# D:\measuring\analysis\lib\tools\toolbox.pyc in measurement_filename(directory, ext)
#     166
#     167 def measurement_filename(directory=os.getcwd(), ext='hdf5'):
# --> 168     dirname = os.path.split(directory)[1]
#     169     fn = dirname+'.'+ext
#     170
#
# C:\Canopy32\App\appdata\canopy-1.0.3.1262.win-x86\lib\ntpath.pyc in split(p)
#     168     Either part may be empty."""
#     169
# --> 170     d, p = splitdrive(p)
#     171     # set i to index beyond p's last slash
#     172     i = len(p)
#
# C:\Canopy32\App\appdata\canopy-1.0.3.1262.win-x86\lib\ntpath.pyc in splitdrive(p)
#     123     """Split a pathname into drive and path specifiers. Returns a 2-tuple
#     124 "(drive,path)";  either part may be empty"""
# --> 125     if p[1:2] == ':':
#     126         return p[0:2], p[2:]
#     127     return '', p
#
# TypeError: 'NoneType' object has no attribute '__getitem__'

# %% [markdown]
# # STAGE 4

# %%
def phaseref(frequency, time, offset=0):
    return ((frequency*time + offset/360.) % 1) * 360.

# %%
phaseref(2.19e6,200e-9)
# Out:
# 157.68

# %%
(2.19e6*20000e-9 + 0/360.) %1
# Out:
# 0.8000000000000043

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_4_calibrations()
# Out:
# ================================================================================
# CORPSE pi phase shift (look for the maximum)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00537254753802
# degrees of freedom, dof  6
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0299236459956
# Reduced chisq (i.e. variance of residuals)  0.00089542458967
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.052587 +/-   0.013411
#  1 a             -0.000188 +/-   0.000017
#  2 x0            86.905974 +/-   2.090422
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.334526  1.000000
#         x0 -0.007211 -0.871102  1.000000

# %% [markdown]
# # STAGE 5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_5_calibrations()
# Out:
# ================================================================================
# UNROT evolution time calibration (look for the maximum)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00497443717464
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0195614164475
# Reduced chisq (i.e. variance of residuals)  0.000382649013434
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              2.198177 +/-   0.010300
#  1 A              0.500787 +/-   0.004982
#  2 x0            52.438642 +/-   0.001097
#  3 k              0.002013 +/-   0.000353
#
# correlation matrix:
#                f         A         x0        k
#          f  1.000000
#          A  0.292180  1.000000
#         x0  0.115306 -0.040960  1.000000
#          k  0.164214  0.594053 -0.114429  1.000000

# %% [markdown]
# # STAGE 6

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_6_calibrations()
# Out:
# ================================================================================
# spin echo (LDE-BSM) calibrations (look for the minimum)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00762559794713
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0242195057231
# Reduced chisq (i.e. variance of residuals)  0.000586584457472
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.937921 +/-   0.008542
#  1 a              0.000000 +/-   0.000000
#  2 x0          -575.769556 +/-  66.841144
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.622346  1.000000
#         x0  0.222833  0.725299  1.000000

# %% [markdown]
# # STAGE 7

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_7_calibrations()
# Out:
# ================================================================================
# Hadamard phase calibration (aim for 10 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00205145713267
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0125620219241
# Reduced chisq (i.e. variance of residuals)  0.000157804394821
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.002812 +/-   0.000051
#  1 A              0.187134 +/-   0.004267
#  2 x0           205.749500 +/-   1.345476
#  3 o              0.221212 +/-   0.004081
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A -0.108611  1.000000
#         x0 -0.125484  0.064495  1.000000
#          o  0.661500 -0.008419 -0.112769  1.000000

# %% [markdown]
# # STAGE 8

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_8_calibrations()
# Out:
# ================================================================================
# Hadamard evolution time calibration (aim for 01 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00270138838745
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0144152386982
# Reduced chisq (i.e. variance of residuals)  0.000207799106727
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              2.224877 +/-   0.023856
#  1 A              0.184303 +/-   0.005284
#  2 x0            35.051522 +/-   0.002124
#  3 o              0.266752 +/-   0.003575
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.079735  1.000000
#         x0  0.488598  0.027005  1.000000
#          o  0.075649  0.045023  0.203274  1.000000
