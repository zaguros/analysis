# %%
sys.path.append(r'D:/measuring')
from analysis.lib.m2.ssro import ssro
from analysis.scripts.teleportation import DD_calibrations

# %% [markdown]
# # Stage0(.25) SSRO (with 7us SP)

# %%
ssro.ssrocalib()

# %% [markdown]
# # Stage 0.5 Dark ESR

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# Center guess?2.828
# fitting with 1 splittings
# Converged with chi squared  0.0853415135465
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0233147275216
# Reduced chisq (i.e. variance of residuals)  0.000543576519404
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.987810 +/-   0.002750
#  1 A              0.130591 +/-   0.006956
#  2 sigma         -0.000393 +/-   0.000024
#  3 x0             2.828777 +/-   0.000018
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.326612  1.000000
#      sigma -0.454914  0.442499  1.000000
#         x0  0.082531  0.593295  0.411747  1.000000

# %% [markdown]
# # Stage 1 Corpse

# %%
reload(DD_calibrations)
DD_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# CORPSE pi
# ================================================================================
# Converged with chi squared  0.00888846026612
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0333325296559
# Reduced chisq (i.e. variance of residuals)  0.00111105753326
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.935351 +/-   0.015063
#  1 a            107.241135 +/-  11.379538
#  2 x0             0.385147 +/-   0.001569
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.737858  1.000000
#         x0  0.145962  0.328263  1.000000

# %% [markdown]
# # Stage 1.5 pi/2 calbration, Cross

# %%
reload(DD_calibrations)
DD_calibrations.stage_1p5_calibrations()
# Out:
# ================================================================================
# CORPSE pi/2
# ================================================================================
# Converged with chi squared
#  0.00173502883189
# degrees of freedom, dof  19
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0095560089442
# Reduced chisq (i.e. variance of residuals)  9.13173069417e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -2.986165 +/-   0.057396
#  1 x0             0.419977 +/-   0.000698
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0 -0.000629  1.000000

# %% [markdown]
# # stage 2: C13 revival time

# %%
DD_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# first C13 revival
# ================================================================================
# Converged with chi squared  0.00257097145028
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0179268355067
# Reduced chisq (i.e. variance of residuals)  0.000321371431285
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.042036 +/-   0.007477
#  1 a             -0.001952 +/-   0.000612
#  2 x0           106.579045 +/-   0.709005
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.557545  1.000000
#         x0  0.186559  0.786618  1.000000

# %% [markdown]
# # stage 3: LDE - DD spin echo time

# %%
reload(DD_calibrations)
DD_calibrations.stage_3_calibrations()
# Out:
# ================================================================================
# LDE-DD spin echo time
# ================================================================================
# Converged with chi squared  0.00160299312556
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00943690487618
# Reduced chisq (i.e. variance of residuals)  8.9055173642e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.988425 +/-   0.003059
#  1 a             24.485726 +/-   1.120125
#  2 x0            -0.083498 +/-   0.001004
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.728742  1.000000
#         x0  0.166039  0.387109  1.000000

# %% [markdown]
# # stage 4: time between pi pulses

# %%
DD_calibrations.stage_4_calibrations()
# Out:
# ================================================================================
# time between pi pulses
# ================================================================================
# Converged with chi squared  0.000387686743988
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00464092150804
# Reduced chisq (i.e. variance of residuals)  2.15381524438e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.964880 +/-   0.001421
#  1 a              0.013323 +/-   0.000775
#  2 x0            -0.189902 +/-   0.046491
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.609742  1.000000
#         x0  0.215553  0.737771  1.000000
