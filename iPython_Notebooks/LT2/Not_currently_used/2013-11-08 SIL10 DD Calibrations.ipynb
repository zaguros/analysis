# %%
sys.path.append(r'D:/measuring')
from analysis.lib.m2.ssro import ssro
from analysis.scripts.teleportation import DD_calibrations

# %% [markdown]
# # Stage0(.25) SSRO (with 7us SP)

# %%
ssro.ssrocalib()

# %% [markdown]
# # Stage 0.5 Dark ESR

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# Center guess?2.829
# fitting with 1 splittings
# Converged with chi squared  0.150296600379
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0309403165324
# Reduced chisq (i.e. variance of residuals)  0.000957303187125
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.992569 +/-   0.003724
#  1 A              0.115060 +/-   0.009007
#  2 sigma          0.000406 +/-   0.000037
#  3 x0             2.828791 +/-   0.000027
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.335446  1.000000
#      sigma  0.474190 -0.419462  1.000000
#         x0  0.077266  0.579018 -0.399562  1.000000

# %% [markdown]
# # Stage 1 Corpse

# %%
reload(DD_calibrations)
DD_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# CORPSE pi
# ================================================================================
# Converged with chi squared  0.00412840639437
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0227167515128
# Reduced chisq (i.e. variance of residuals)  0.000516050799296
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.951471 +/-   0.010271
#  1 a            107.544098 +/-   7.755371
#  2 x0             0.385303 +/-   0.001062
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.738609  1.000000
#         x0  0.142068  0.318828  1.000000

# %% [markdown]
# # Stage 1.5 pi/2 calbration, Cross

# %%
reload(DD_calibrations)
DD_calibrations.stage_1p5_calibrations()
# Out:
# ================================================================================
# CORPSE pi/2
# ================================================================================
# Converged with chi squared
#  0.00169944222297
# degrees of freedom, dof  19
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00945750112475
# Reduced chisq (i.e. variance of residuals)  8.94443275246e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -2.844155 +/-   0.056804
#  1 x0             0.422683 +/-   0.000728
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0  0.073655  1.000000

# %% [markdown]
# # stage 2: C13 revival time

# %%
DD_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# first C13 revival
# ================================================================================
# Converged with chi squared  0.00120224870255
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0122589187051
# Reduced chisq (i.e. variance of residuals)  0.000150281087819
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.036544 +/-   0.005242
#  1 a             -0.002470 +/-   0.000419
#  2 x0           106.237535 +/-   0.339616
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.631856  1.000000
#         x0  0.228893  0.717289  1.000000

# %% [markdown]
# # stage 3: LDE - DD spin echo time

# %%
reload(DD_calibrations)
DD_calibrations.stage_3_calibrations()
# Out:
# ================================================================================
# LDE-DD spin echo time
# ================================================================================
# Converged with chi squared  0.00136878082972
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00872028551302
# Reduced chisq (i.e. variance of residuals)  7.60433794286e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.991514 +/-   0.002837
#  1 a             25.892015 +/-   1.035065
#  2 x0            -0.082134 +/-   0.000858
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.734070  1.000000
#         x0  0.144688  0.332397  1.000000

# %% [markdown]
# # stage 4: time between pi pulses

# %%
DD_calibrations.stage_4_calibrations()
# Out:
# ================================================================================
# time between pi pulses
# ================================================================================
# Converged with chi squared  0.00049960845225
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00526839872494
# Reduced chisq (i.e. variance of residuals)  2.7756025125e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.961414 +/-   0.001727
#  1 a              0.011921 +/-   0.000879
#  2 x0             0.370769 +/-   0.039876
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.746199  1.000000
#         x0  0.024324  0.054077  1.000000
