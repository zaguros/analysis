# %%
import os, sys
msmtpath = r'D:\measuring'
if not msmtpath in sys.path:
    sys.path.append(msmtpath)
    
from measurement.lib.tools import toolbox as tb
from analysis.lib.m2.ssro import ssro, mbi, sequence
from analysis.scripts.teleportation import BSM_calibrations
reload(BSM_calibrations)
# Out:
# <module 'analysis.scripts.teleportation.BSM_calibrations' from 'D:\measuring\analysis\scripts\teleportation\BSM_calibrations.pyc'>

# %% [markdown]
# # STAGE 0.0 SSRO

# %%
ssro.ssrocalib()

# %% [markdown]
# ### (STAGE 0.3: Rabi to find good pi pulse length)

# %%
execfile('D:/measuring/analysis/scripts/espin/electron_rabi_analysis.py')

# %% [markdown]
# # STAGE 0.5 DARK ESR

# %%
execfile('D:/measuring/analysis/scripts/espin/dark_esr_analysis.py')
# Out:
# Center guess?2.828
# fitting with 1 splittings
# Converged with chi squared  0.0304912938491
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0139359988064
# Reduced chisq (i.e. variance of residuals)  0.000194212062733
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.994212 +/-   0.001354
#  1 A              0.207561 +/-   0.006583
#  2 sigma          0.000215 +/-   0.000006
#  3 x0             2.828035 +/-   0.000007
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.318662  1.000000
#      sigma  0.198627 -0.603183  1.000000
#         x0  0.242182  0.750671 -0.447955  1.000000

# %% [markdown]
# # STAGE 1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# Slow pi pulse for MBI
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.0043474073063
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0219782905672
# Reduced chisq (i.e. variance of residuals)  0.000483045256255
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f             30.763116 +/-   0.211049
#  1 A              0.398265 +/-   0.005620
#
# correlation matrix:
#                f         A
#          f  1.000000
#          A  0.243241  1.000000

# %% [markdown]
# # STAGE 2

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# fast pi pulse
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00136392581668
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0130572097741
# Reduced chisq (i.e. variance of residuals)  0.000170490727085
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.976545 +/-   0.005941
#  1 a              4.826848 +/-   1.114414
#  2 x0             0.796538 +/-   0.006497
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.748094  1.000000
#         x0  0.056541  0.123023  1.000000
#
# ================================================================================
# CORPSE pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000763288722399
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00976786006758
# Reduced chisq (i.e. variance of residuals)  9.54110902998e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.986397 +/-   0.004834
#  1 a             39.299965 +/-   6.805495
#  2 x0             0.498379 +/-   0.004911
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a -0.305560  1.000000
#         x0 -0.539073  0.938718  1.000000
#
# ================================================================================
# pi2pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000899897600185
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0106059983039
# Reduced chisq (i.e. variance of residuals)  0.000112487200023
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.941169 +/-   0.004794
#  1 a            890.459022 +/-  57.933250
#  2 x0             0.106303 +/-   0.000240
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.738193  1.000000
#         x0  0.144367  0.324260  1.000000
#
# ================================================================================
# pi2pi, m_I=0
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000897526410384
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0105920159223
# Reduced chisq (i.e. variance of residuals)  0.000112190801298
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.915935 +/-   0.004479
#  1 a            694.461248 +/-  57.856874
#  2 x0             0.103503 +/-   0.000442
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.601621  1.000000
#         x0  0.216346  0.753198  1.000000

# %% [markdown]
# # STAGE 2.5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2p5_calibration()
# Out:
# ================================================================================
# fast pi/2 pulse
# ================================================================================
# Converged with chi squared
#  0.000785247484408
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00934075588428
# Reduced chisq (i.e. variance of residuals)  8.72497204897e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -0.806464 +/-   0.035624
#  1 x0             0.796250 +/-   0.003616
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0  0.259577  1.000000

# %% [markdown]
# # STAGE 3:

# %%
BSM_calibrations.stage_3_calibrations()
# Out:
# ================================================================================
# Nitrogen Rabi oscillation
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.0024692799391
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0137820394246
# Reduced chisq (i.e. variance of residuals)  0.0001899446107
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.010415 +/-   0.000031
#  1 A             -0.464813 +/-   0.004612
#  2 x0             0.944548 +/-   0.336825
#  3 o              0.501728 +/-   0.003503
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A -0.012172  1.000000
#         x0  0.878106  0.006393  1.000000
#          o  0.274135 -0.118818  0.254800  1.000000

# %%
reload(BSM_calibrations)
BSM_calibrations.N_frq()

# %% [markdown]
# # STAGE 4

# %%
def phaseref(frequency, time, offset=0):
    return ((frequency*time + offset/360.) % 1) * 360.

# %%
phaseref(2.19e6,200e-9)

# %%
(2.19e6*20000e-9 + 0/360.) %1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_4_calibrations()

# %% [markdown]
# # STAGE 5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_5_calibrations()

# %% [markdown]
# # STAGE 6

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_6_calibrations()

# %% [markdown]
# # STAGE 7

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_7_calibrations()
# Out:
# ================================================================================
# Hadamard phase calibration (aim for 10 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000806432245922
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00787611894821
# Reduced chisq (i.e. variance of residuals)  6.20332496863e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.002763 +/-   0.000034
#  1 A              0.185752 +/-   0.002702
#  2 x0           204.223988 +/-   0.858231
#  3 o              0.219786 +/-   0.002719
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A -0.171022  1.000000
#         x0 -0.096032  0.054171  1.000000
#          o  0.709628 -0.074741 -0.088505  1.000000

# %% [markdown]
# # STAGE 8

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_8_calibrations()
# Out:
# ================================================================================
# Hadamard evolution time calibration (aim for 01 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00202065254883
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0124673498166
# Reduced chisq (i.e. variance of residuals)  0.000155434811449
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              2.213479 +/-   0.018990
#  1 A              0.200342 +/-   0.004569
#  2 x0            35.050772 +/-   0.001699
#  3 o              0.267382 +/-   0.003089
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.087394  1.000000
#         x0  0.489901  0.031602  1.000000
#          o  0.075993  0.044100  0.199529  1.000000
