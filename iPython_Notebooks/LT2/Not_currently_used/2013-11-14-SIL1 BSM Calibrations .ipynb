# %%
import os, sys
msmtpath = r'D:\measuring'
if not msmtpath in sys.path:
    sys.path.append(msmtpath)
    
from measurement.lib.tools import toolbox as tb
from analysis.lib.m2.ssro import ssro, mbi, sequence
from analysis.scripts.teleportation import BSM_calibrations
reload(BSM_calibrations)
# Out:
# <module 'analysis.scripts.teleportation.BSM_calibrations' from 'D:\measuring\analysis\scripts\teleportation\BSM_calibrations.pyc'>

# %% [markdown]
# # STAGE 0.0 SSRO

# %%
ssro.ssrocalib()

# %% [markdown]
# ### (STAGE 0.3: Rabi to find good pi pulse length)

# %%
execfile('D:/measuring/analysis/scripts/espin/electron_rabi_analysis.py')

# %% [markdown]
# # STAGE 0.5 DARK ESR

# %%
execfile('D:/measuring/analysis/scripts/espin/dark_esr_analysis.py')
# Out:
# Center guess?2.828
# fitting with 1 splittings
# Converged with chi squared  0.0412367607985
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0162066198629
# Reduced chisq (i.e. variance of residuals)  0.000262654527379
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.992802 +/-   0.001576
#  1 A              0.225183 +/-   0.007623
#  2 sigma          0.000216 +/-   0.000007
#  3 x0             2.828095 +/-   0.000008
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.317634  1.000000
#      sigma  0.200100 -0.604513  1.000000
#         x0  0.239649  0.750392 -0.451520  1.000000

# %% [markdown]
# # STAGE 1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# Slow pi pulse for MBI
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00295282662785
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0181133058148
# Reduced chisq (i.e. variance of residuals)  0.000328091847539
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f             30.690594 +/-   0.177855
#  1 A              0.388166 +/-   0.004627
#
# correlation matrix:
#                f         A
#          f  1.000000
#          A  0.243292  1.000000

# %% [markdown]
# # STAGE 2

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# fast pi pulse
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00059233726246
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00860477529094
# Reduced chisq (i.e. variance of residuals)  7.40421578075e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.980230 +/-   0.003850
#  1 a              4.394203 +/-   0.734405
#  2 x0             0.785382 +/-   0.005268
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.722432  1.000000
#         x0  0.197487  0.463729  1.000000
#
# ================================================================================
# CORPSE pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00088273459939
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0105043717053
# Reduced chisq (i.e. variance of residuals)  0.000110341824924
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.984884 +/-   0.004887
#  1 a             49.726818 +/-   7.318640
#  2 x0             0.499926 +/-   0.003961
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a -0.205457  1.000000
#         x0 -0.457766  0.931704  1.000000
#
# ================================================================================
# pi2pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000331536390019
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00643754990291
# Reduced chisq (i.e. variance of residuals)  4.14420487524e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.948267 +/-   0.002860
#  1 a            826.588011 +/-  35.163893
#  2 x0             0.105319 +/-   0.000175
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.710326  1.000000
#         x0  0.218011  0.529777  1.000000
#
# ================================================================================
# pi2pi, m_I=0
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00106397971523
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0115324526621
# Reduced chisq (i.e. variance of residuals)  0.000132997464404
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.922272 +/-   0.004868
#  1 a            753.967356 +/-  62.993831
#  2 x0             0.103447 +/-   0.000447
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.596828  1.000000
#         x0  0.213604  0.757675  1.000000

# %% [markdown]
# # STAGE 2.5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2p5_calibration()
# Out:
# ================================================================================
# fast pi/2 pulse
# ================================================================================
# Converged with chi squared
#  0.00403878142606
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0211838025808
# Reduced chisq (i.e. variance of residuals)  0.000448753491784
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -0.752630 +/-   0.080792
#  1 x0             0.758432 +/-   0.008671
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0 -0.205119  1.000000

# %% [markdown]
# # STAGE 3:

# %%
BSM_calibrations.stage_3_calibrations()

# %%
reload(BSM_calibrations)
BSM_calibrations.N_frq()

# %% [markdown]
# # STAGE 4

# %%
def phaseref(frequency, time, offset=0):
    return ((frequency*time + offset/360.) % 1) * 360.

# %%
phaseref(2.19e6,200e-9)

# %%
(2.19e6*20000e-9 + 0/360.) %1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_4_calibrations()

# %% [markdown]
# # STAGE 5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_5_calibrations()

# %% [markdown]
# # STAGE 6

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_6_calibrations()

# %% [markdown]
# # STAGE 7

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_7_calibrations()
# Out:
# ================================================================================
# Hadamard phase calibration (aim for 10 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00233129380497
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0133914260887
# Reduced chisq (i.e. variance of residuals)  0.00017933029269
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.002700 +/-   0.000069
#  1 A              0.182141 +/-   0.004789
#  2 x0           198.406139 +/-   1.508432
#  3 o              0.212314 +/-   0.005359
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A -0.318614  1.000000
#         x0 -0.044917  0.031744  1.000000
#          o  0.794941 -0.229222 -0.043686  1.000000

# %% [markdown]
# # STAGE 8

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_8_calibrations()
# Out:
# ================================================================================
# Hadamard evolution time calibration (aim for 01 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00166110131622
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.011303849978
# Reduced chisq (i.e. variance of residuals)  0.000127777024325
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              2.190665 +/-   0.017633
#  1 A              0.196872 +/-   0.004136
#  2 x0            35.051444 +/-   0.001579
#  3 o              0.267472 +/-   0.002799
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.101815  1.000000
#         x0  0.483756  0.034623  1.000000
#          o  0.089320  0.048322  0.196747  1.000000
