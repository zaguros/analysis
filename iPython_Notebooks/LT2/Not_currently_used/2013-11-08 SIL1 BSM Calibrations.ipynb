# %%
import os, sys
msmtpath = r'D:\measuring'
if not msmtpath in sys.path:
    sys.path.append(msmtpath)
    
from measurement.lib.tools import toolbox as tb
from analysis.lib.m2.ssro import ssro, mbi, sequence
from analysis.scripts.teleportation import BSM_calibrations
reload(BSM_calibrations)

# %qtconsole

# %% [markdown]
# # STAGE 0.0 SSRO

# %%
ssro.ssrocalib()

# %% [markdown]
# ### (STAGE 0.3: Rabi to find good pi pulse length)

# %%
execfile('D:/measuring/analysis/scripts/espin/electron_rabi_analysis.py')

# %% [markdown]
# # STAGE 0.5 DARK ESR

# %%
execfile('D:/measuring/analysis/scripts/espin/dark_esr_analysis.py')
# Out:
# Center guess?2.828
# fitting with 1 splittings
# Converged with chi squared  0.0328155202356
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0144573874699
# Reduced chisq (i.e. variance of residuals)  0.000209016052456
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.992430 +/-   0.001415
#  1 A              0.217137 +/-   0.006644
#  2 sigma          0.000226 +/-   0.000006
#  3 x0             2.828067 +/-   0.000007
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.312487  1.000000
#      sigma  0.208709 -0.609570  1.000000
#         x0  0.226795  0.748158 -0.467067  1.000000

# %% [markdown]
# # STAGE 1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# Slow pi pulse for MBI
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00396452665163
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0209881624086
# Reduced chisq (i.e. variance of residuals)  0.000440502961292
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f             30.398710 +/-   0.195198
#  1 A              0.404404 +/-   0.005336
#
# correlation matrix:
#                f         A
#          f  1.000000
#          A  0.243580  1.000000

# %% [markdown]
# # STAGE 2

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# fast pi pulse
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000753811308601
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00970702908078
# Reduced chisq (i.e. variance of residuals)  9.42264135752e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.976917 +/-   0.004395
#  1 a              4.969630 +/-   0.828481
#  2 x0             0.808403 +/-   0.004862
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.740625  1.000000
#         x0 -0.128156 -0.288118  1.000000
#
# ================================================================================
# CORPSE pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000565185289153
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00840524604899
# Reduced chisq (i.e. variance of residuals)  7.06481611441e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.989780 +/-   0.003628
#  1 a             57.844694 +/-   5.856130
#  2 x0             0.515754 +/-   0.001362
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.653871  1.000000
#         x0  0.238079  0.687161  1.000000
#
# ================================================================================
# pi2pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000499257843553
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00789982470971
# Reduced chisq (i.e. variance of residuals)  6.24072304441e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.948264 +/-   0.003596
#  1 a            841.700453 +/-  43.151291
#  2 x0             0.107178 +/-   0.000180
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.748746  1.000000
#         x0  0.042478  0.091902  1.000000
#
# ================================================================================
# pi2pi, m_I=0
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00130235815527
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.012759105353
# Reduced chisq (i.e. variance of residuals)  0.000162794769408
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.923101 +/-   0.005773
#  1 a            835.855311 +/-  69.694188
#  2 x0             0.106388 +/-   0.000305
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.739768  1.000000
#         x0  0.135741  0.303520  1.000000

# %% [markdown]
# # STAGE 2.5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2p5_calibration()
# Out:
# ================================================================================
# fast pi/2 pulse
# ================================================================================
# Converged with chi squared
#  0.00144458969781
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0126692527966
# Reduced chisq (i.e. variance of residuals)  0.000160509966423
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -0.802775 +/-   0.060398
#  1 x0             0.805386 +/-   0.004776
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0  0.084846  1.000000

# %% [markdown]
# # STAGE 3:

# %%
BSM_calibrations.stage_3_calibrations()

# %%
reload(BSM_calibrations)
BSM_calibrations.N_frq()

# %% [markdown]
# # STAGE 4

# %%
def phaseref(frequency, time, offset=0):
    return ((frequency*time + offset/360.) % 1) * 360.

# %%
phaseref(2.19e6,200e-9)

# %%
(2.19e6*20000e-9 + 0/360.) %1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_4_calibrations()

# %% [markdown]
# # STAGE 5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_5_calibrations()

# %% [markdown]
# # STAGE 6

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_6_calibrations()

# %% [markdown]
# # STAGE 7

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_7_calibrations()
# Out:
# ================================================================================
# Hadamard phase calibration (aim for 10 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared
#  0.00211264191096
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0127479769465
# Reduced chisq (i.e. variance of residuals)  0.000162510916227
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.002666 +/-   0.000061
#  1 A              0.185757 +/-   0.004539
#  2 x0           203.517138 +/-   1.417322
#  3 o              0.209142 +/-   0.004917
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A -0.289996  1.000000
#         x0 -0.051325  0.028158  1.000000
#          o  0.777427 -0.210432 -0.046328  1.000000

# %% [markdown]
# # STAGE 8

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_8_calibrations()
# Out:
# ================================================================================
# Hadamard evolution time calibration (aim for 01 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00113110055372
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00932779367812
# Reduced chisq (i.e. variance of residuals)  8.70077349016e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              2.189978 +/-   0.013730
#  1 A              0.208788 +/-   0.003412
#  2 x0            35.051677 +/-   0.001229
#  3 o              0.274582 +/-   0.002310
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.102147  1.000000
#         x0  0.482668  0.034092  1.000000
#          o  0.090972  0.049027  0.197126  1.000000

# %%
x = 42

# %%
bas='I already saw that'
