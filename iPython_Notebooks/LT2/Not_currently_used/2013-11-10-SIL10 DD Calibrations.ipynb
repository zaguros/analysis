# %%
sys.path.append(r'D:/measuring')
from analysis.lib.m2.ssro import ssro
from analysis.scripts.teleportation import DD_calibrations

# %% [markdown]
# # Stage0(.25) SSRO (with 7us SP)

# %%
ssro.ssrocalib()

# %% [markdown]
# # Stage 0.5 Dark ESR

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# Center guess?2.828
# fitting with 1 splittings
# Converged with chi squared  0.0987653417823
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0250814395535
# Reduced chisq (i.e. variance of residuals)  0.000629078610078
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.988226 +/-   0.002775
#  1 A              0.125116 +/-   0.008257
#  2 sigma         -0.000347 +/-   0.000025
#  3 x0             2.828752 +/-   0.000020
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.302742  1.000000
#      sigma -0.386904  0.514781  1.000000
#         x0  0.105276  0.643663  0.452664  1.000000

# %% [markdown]
# # Stage 1 Corpse

# %%
reload(DD_calibrations)
DD_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# CORPSE pi
# ================================================================================
# Converged with chi squared  0.00748039016907
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0305785671858
# Reduced chisq (i.e. variance of residuals)  0.000935048771134
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.937398 +/-   0.013452
#  1 a             99.397247 +/-  10.439351
#  2 x0             0.379609 +/-   0.001828
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.692632  1.000000
#         x0  0.233208  0.596983  1.000000

# %% [markdown]
# # Stage 1.5 pi/2 calbration, Cross

# %%
reload(DD_calibrations)
DD_calibrations.stage_1p5_calibrations()
# Out:
# ================================================================================
# CORPSE pi/2
# ================================================================================
# Converged with chi squared
#  0.00237757517447
# degrees of freedom, dof  19
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0111863995771
# Reduced chisq (i.e. variance of residuals)  0.000125135535499
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -2.969965 +/-   0.067188
#  1 x0             0.415780 +/-   0.000827
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0 -0.115369  1.000000

# %% [markdown]
# # stage 2: C13 revival time

# %%
DD_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# first C13 revival
# ================================================================================
# Converged with chi squared  0.000993766162605
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0111454371976
# Reduced chisq (i.e. variance of residuals)  0.000124220770326
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.031701 +/-   0.004786
#  1 a             -0.002636 +/-   0.000380
#  2 x0           106.180604 +/-   0.283475
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.642029  1.000000
#         x0  0.232386  0.703067  1.000000

# %% [markdown]
# # stage 3: LDE - DD spin echo time

# %%
reload(DD_calibrations)
DD_calibrations.stage_3_calibrations()
# Out:
# ================================================================================
# LDE-DD spin echo time
# ================================================================================
# Converged with chi squared  0.00163900664531
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00954232281678
# Reduced chisq (i.e. variance of residuals)  9.10559247396e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.992024 +/-   0.003079
#  1 a             24.695346 +/-   1.132638
#  2 x0            -0.085158 +/-   0.001039
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.720875  1.000000
#         x0  0.188195  0.448532  1.000000

# %% [markdown]
# # stage 4: time between pi pulses

# %%
DD_calibrations.stage_4_calibrations()
# Out:
# ================================================================================
# time between pi pulses
# ================================================================================
# Converged with chi squared  0.00110401389392
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0078316093632
# Reduced chisq (i.e. variance of residuals)  6.13341052178e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.966005 +/-   0.002514
#  1 a              0.013635 +/-   0.001307
#  2 x0             0.087658 +/-   0.059787
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.712027  1.000000
#         x0  0.204856  0.500860  1.000000
