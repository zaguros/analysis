# %%
import os, sys
msmtpath = r'D:\measuring'
if not msmtpath in sys.path:
    sys.path.append(msmtpath)
    
from measurement.lib.tools import toolbox as tb
from analysis.lib.m2.ssro import ssro, mbi, sequence
from analysis.scripts.teleportation import BSM_calibrations
reload(BSM_calibrations)

# %% [markdown]
# # STAGE 0.0 SSRO

# %%
ssro.ssrocalib()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-114a27e656fb> in <module>()
# ----> 1 ssro.ssrocalib()
#
# D:\measuring\analysis\lib\m2\ssro\ssro.pyc in ssrocalib(folder)
#     278         a.spinpumping(a.sp_time, a.sp_counts, a.reps, a.binsize, name=n)
#     279         a.charge_hist(a.cr_counts, name=n)
# --> 280         a.fidelity(a.ro_counts, a.reps, a.binsize, ms, name=n)
#     281
#     282     plt.close('all')
#
# D:\measuring\analysis\lib\m2\ssro\ssro.pyc in fidelity(self, ro_counts, reps, binsize, ms, lastbin, plot, **kw)
#     185
#     186         if save:
# --> 187             f = self.analysis_h5data()
#     188             if not 'fidelity' in f:
#     189                 f.create_group('fidelity')
#
# D:\measuring\analysis\lib\m2\m2.pyc in analysis_h5data(self, name)
#      50             mode = 'r+'
#      51
# ---> 52         return h5py.File(os.path.join(self.folder, name+'.hdf5'), mode)
#      53
#      54     def default_fig(self, **kw):
#
# C:\Documents and Settings\localadmin\Local Settings\Application Data\Enthought\Canopy32\User\lib\site-packages\h5py\_hl\files.pyc in __init__(self, name, mode, driver, libver, userblock_size, **kwds)
#     205
#     206             fapl = make_fapl(driver, libver, **kwds)
# --> 207             fid = make_fid(name, mode, userblock_size, fapl)
#     208
#     209         Group.__init__(self, fid)
#
# C:\Documents and Settings\localadmin\Local Settings\Application Data\Enthought\Canopy32\User\lib\site-packages\h5py\_hl\files.pyc in make_fid(name, mode, userblock_size, fapl, fcpl)
#      79         fid = h5f.open(name, h5f.ACC_RDONLY, fapl=fapl)
#      80     elif mode == 'r+':
# ---> 81         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#      82     elif mode == 'w-':
#      83         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#
# C:\Documents and Settings\localadmin\Local Settings\Application Data\Enthought\Canopy32\User\lib\site-packages\h5py\h5f.pyd in h5py.h5f.open (h5py\h5f.c:1543)()
#
# IOError: unable to open file (File accessibilty: Unable to open file)

# %% [markdown]
# ### (STAGE 0.3: Rabi to find good pi pulse length)

# %%
execfile('D:/measuring/analysis/scripts/espin/electron_rabi_analysis.py')

# %% [markdown]
# # STAGE 0.5 DARK ESR

# %%
execfile('D:/measuring/analysis/scripts/espin/dark_esr_analysis.py')

# %% [markdown]
# # STAGE 1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_1_calibrations()

# %% [markdown]
# # STAGE 2

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2_calibrations()

# %% [markdown]
# # STAGE 2.5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2p5_calibration()

# %% [markdown]
# # STAGE 3:

# %%
BSM_calibrations.stage_3_calibrations()

# %%
reload(BSM_calibrations)
BSM_calibrations.N_frq()

# %% [markdown]
# # STAGE 4

# %%
def phaseref(frequency, time, offset=0):
    return ((frequency*time + offset/360.) % 1) * 360.

# %%
phaseref(2.19e6,200e-9)

# %%
(2.19e6*20000e-9 + 0/360.) %1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_4_calibrations()

# %% [markdown]
# # STAGE 5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_5_calibrations()

# %% [markdown]
# # STAGE 6

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_6_calibrations()
# Out:
# ================================================================================
# spin echo (LDE-BSM) calibrations (look for the minimum)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.14650755198
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.106159369303
# Reduced chisq (i.e. variance of residuals)  0.0112698116907
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.895825 +/-   0.035680
#  1 a              0.000000 +/-   0.000000
#  2 x0          -904.519887 +/- 340.413104
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.383677  1.000000
#         x0  0.045373  0.855906  1.000000

# %% [markdown]
# # STAGE 7

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_7_calibrations()

# %% [markdown]
# # STAGE 8

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_8_calibrations()
# Out:
# ================================================================================
# Hadamard evolution time calibration (aim for 01 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00277189133637
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0146021371891
# Reduced chisq (i.e. variance of residuals)  0.00021322241049
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              2.193733 +/-   0.022334
#  1 A              0.198529 +/-   0.005361
#  2 x0            35.045514 +/-   0.002047
#  3 o              0.265181 +/-   0.003607
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.102043  1.000000
#         x0  0.508942  0.051472  1.000000
#          o  0.053907  0.031584  0.182697  1.000000
