# %%
cd d:/measuring/analysis/scripts/
# Out:
#   File "<ipython-input-3-81bf6c0b4b7d>", line 1
#     cd d:/measuring/analysis/scripts/
#        ^
# SyntaxError: invalid syntax

# %%
import sys
sys.path.append(r'D:/measuring')

# %%
execfile('ssro/ssro_vs_power.py')
# Out:
# Converged with chi squared  810946256.35
# degrees of freedom, dof  36
# RMS of residuals (i.e. sqrt(chisq/dof))  4746.18635313
# Reduced chisq (i.e. variance of residuals)  22526284.8986
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a           2430.207929 +/- 33604.190322
#  1 A          93542.034512 +/- 28181.921698
#  2 tau           49.642851 +/-  30.707038
#
# correlation matrix:
#                a         A         tau
#          a  1.000000
#          A -0.994149  1.000000
#        tau -0.994702  0.978790  1.000000
#
# Converged with chi squared
#  2047054819.7
# degrees of freedom, dof  41
# RMS of residuals (i.e. sqrt(chisq/dof))  7065.98657897
# Reduced chisq (i.e. variance of residuals)  49928166.3342
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a            648.320626 +/- 2127.843984
#  1 A          608060.463478 +/- 10959.749074
#  2 tau            8.963760 +/-   0.225926
#
# correlation matrix:
#                a         A         tau
# ...

# %%
from analysis.lib.m2.ssro import ssro
ssro.ssrocalib()

# %%
from analysis.lib.lde import tail_cts_per_shot_v4 as tail

# %%
tail.tail_cts_per_shot_txt_file(r'D:\measuring\data\20131115','1153000_lt2_tail.txt',93.5,50,50000,250,'LT2_tail_1',tail_mode=0)
# Out:
# a = 0.99
# A = 51.72 pm 1.03 ns
# tau = 9.54 pm 0.40 ns
# Tail counts per shot =  1.74 E-4
