# %%
sys.path.append(r'D:/measuring')
from analysis.lib.m2.ssro import ssro
from analysis.scripts.teleportation import DD_calibrations

# %% [markdown]
# # Stage0(.25) SSRO (with 7us SP)

# %%
ssro.ssrocalib()

# %% [markdown]
# # Stage 0.5 Dark ESR

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# Center guess?2.829
# fitting with 1 splittings
# Converged with chi squared  0.0821945320474
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0228808227837
# Reduced chisq (i.e. variance of residuals)  0.000523532051257
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.995217 +/-   0.002544
#  1 A              0.116855 +/-   0.007464
#  2 sigma          0.000351 +/-   0.000024
#  3 x0             2.828880 +/-   0.000020
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.304245  1.000000
#      sigma  0.392850 -0.509100  1.000000
#         x0  0.102884  0.639419 -0.449465  1.000000

# %% [markdown]
# # Stage 1 Corpse

# %%
reload(DD_calibrations)
DD_calibrations.stage_1_calibrations()
# Out:
# ...
# CORPSE pi
# ...
# Converged with chi squared  0.00528338942438
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0256987096572
# Reduced chisq (i.e. variance of residuals)  0.000660423678047
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.955568 +/-   0.011488
#  1 a            107.410882 +/-   8.773395
#  2 x0             0.382481 +/-   0.001295
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.720780  1.000000
#         x0  0.200956  0.474102  1.000000

# %% [markdown]
# # Stage 1.5 pi/2 calbration, Cross

# %% [markdown]
# # stage 2: C13 revival time

# %% [markdown]
# # stage 3: LDE - DD spin echo time

# %% [markdown]
# # Rabi

# %%
execfile(r'D:\measuring\analysis\scripts\espin\electron_rabi_analysis.py')
# Out:
# Converged with chi squared  0.00173464164228
# degrees of freedom, dof  16
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0104122573269
# Reduced chisq (i.e. variance of residuals)  0.000108415102642
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              1.024667 +/-   0.016574
#  1 A              0.599295 +/-   0.020562
#  2 phi            0.030540 +/-   0.009570
#  3 o              1.012076 +/-   0.006650
#  4 k              0.842125 +/-   0.162794
#
# correlation matrix:
#                f         A         phi       o         k
#          f  1.000000
#          A  0.775683  1.000000
#        phi  0.964359  0.873589  1.000000
#          o  0.122912  0.605997  0.211018  1.000000
#          k  0.817386  0.980062  0.914693  0.469393  1.000000

# %% [markdown]
# # T1 measurements

# %%
from analysis.lib.m2.ssro import sequence
from analysis.lib.tools import plot
from measurement.lib.tools import toolbox

folder = toolbox.latest_data('T1')
a = sequence.SequenceAnalysis(folder)
a.get_sweep_pts()
a.get_readout_results('ssro')
a.get_electron_ROC()
a.plot_result_vs_sweepparam()

# %%
from analysis.lib.m2.ssro import sequence
from analysis.lib.tools import plot
from measurement.lib.tools import toolbox

folder = toolbox.latest_data('T1')
a = sequence.SequenceAnalysis(folder)
a.get_sweep_pts()
a.get_readout_results('ssro')
a.get_electron_ROC()
a.plot_result_vs_sweepparam()

# %%
from analysis.lib.m2.ssro import sequence
from analysis.lib.tools import plot
from measurement.lib.tools import toolbox

folder = toolbox.latest_data('T1')
a = sequence.SequenceAnalysis(folder)
a.get_sweep_pts()
a.get_readout_results('ssro')
a.get_electron_ROC()
a.plot_result_vs_sweepparam()

# %%
from analysis.lib.m2.ssro import sequence
reload(sequence)
from analysis.lib.tools import plot
from measurement.lib.tools import toolbox

timestamp = None

### script
if timestamp != None:
    folder = toolbox.data_from_time(timestamp)
else:
    folder = toolbox.latest_data('T1')

a = sequence.SequenceAnalysis(folder)
for n,ms in zip(['ms0', 'ms1'], [0,1]):
    a.get_sweep_pts()
    a.get_readout_results(n)
    a.get_electron_ROC()
    a.plot_result_vs_sweepparam()

# %%
from analysis.scripts.espin import electron_T1_analysis
reload(electron_T1_analysis)
fit_result = electron_T1_analysis.electron_T1_anal(m='ms0')

# %%
fit.fit1d?
