# %%
sys.path.append(r'D:/measuring')

# %%
from analysis.lib.m2.ssro import ssro

# %%
ssro.ssrocalib()

# %%
cd d:/measuring/analysis/scripts/
# Out:
# d:\measuring\analysis\scripts

# %%
cd espin
# Out:
# d:\measuring\analysis\scripts\espin

# %%
ls
# Out:
#  Volume in drive D is Userdata
#  Volume Serial Number is 687E-D2E7
#
#  Directory of d:\measuring\analysis\scripts\espin
#
# 10/15/2013  06:11 PM    <DIR>          .
# 10/15/2013  06:11 PM    <DIR>          ..
# 09/09/2013  01:43 PM                 0 __init__.py
# 09/25/2013  01:03 PM               135 __init__.pyc
# 10/15/2013  05:05 PM             2,037 dark_esr_analysis.py
# 10/15/2013  06:11 PM             2,537 dark_esr_analysis.pyc
# 10/15/2013  05:13 PM             2,000 electron_rabi_analysis.py
# 09/09/2013  01:43 PM             1,488 electron_ramsey_analysis.py
#                6 File(s)          8,197 bytes
#                2 Dir(s)  30,893,142,016 bytes free

# %%
execfile('dark_esr_analysis.py')
# Out:
# fitting with 1 splittings
# Converged with chi squared  0.0662014172572
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0205344850939
# Reduced chisq (i.e. variance of residuals)  0.000421665078071
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.997293 +/-   0.002096
#  1 A              0.230481 +/-   0.007279
#  2 sigma          0.000357 +/-   0.000012
#  3 x0             2.828778 +/-   0.000010
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.253990  1.000000
#      sigma  0.336057 -0.566542  1.000000
#         x0  0.081569  0.634313 -0.471898  1.000000

# %%
execfile('electron_rabi_analysis.py')
# Out:
# Converged with chi squared  0.00325712366808
# degrees of freedom, dof  16
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0142678039395
# Reduced chisq (i.e. variance of residuals)  0.000203570229255
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.012910 +/-   0.000026
#  1 A              0.496023 +/-   0.008168
#  2 phi           -0.001721 +/-   0.002973
#  3 o              0.999588 +/-   0.008373
#  4 k              0.000109 +/-   0.000140
#
# correlation matrix:
#                f         A         phi       o         k
#          f  1.000000
#          A -0.090275  1.000000
#        phi  0.866639 -0.085894  1.000000
#          o -0.104562  0.925352 -0.123578  1.000000
#          k -0.092625  0.847097 -0.077499  0.757783  1.000000

# %%
from analysis.lib.m2.ssro import sequence as seq
from analysis.lib.tools import toolbox as tb|
# Out:
#   File "<ipython-input-119-fd3e2eb0d026>", line 2
#     from analysis.lib.tools import toolbox as tb|
#                                                 ^
# SyntaxError: invalid syntax

# %%
seq.analyze_sweep(tb.latest_data('Rabi'),name='ssro')

# %%
cd teleportation/
# Out:
# [Error 2] The system cannot find the file specified: u'teleportation/'
# d:\analysis

# %%
ssro.ssrocalib()

# %%
execfile('teleportation/LT2_calibrations.py')
# Out:
# ...
# time between pi pulses
# ...
# Converged with chi squared  0.000829766189456
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00678955975277
# Reduced chisq (i.e. variance of residuals)  4.60981216365e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.953759 +/-   0.002223
#  1 a              0.010836 +/-   0.001133
#  2 x0             0.481021 +/-   0.057084
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.744261  1.000000
#         x0 -0.066377 -0.148445  1.000000

# %%
8*2
# Out:
# 16

# %%
905+47000+2851+828
# Out:
# 51584

# %%
106.898/2.
# Out:
# 53.449

# %%
execfile(r'D:\measuring\analysis\scripts\ssro\ssro_vs_power.py')
# Out:
# Converged with chi squared  491224314.529
# degrees of freedom, dof  91
# RMS of residuals (i.e. sqrt(chisq/dof))  2323.37456955
# Reduced chisq (i.e. variance of residuals)  5398069.39042
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a           1478.900139 +/- 287.837795
#  1 A          866644.285442 +/- 4527.623455
#  2 tau            7.199860 +/-   0.036736
#
# correlation matrix:
#                a         A         tau
#          a  1.000000
#          A  0.204095  1.000000
#        tau -0.425728 -0.877963  1.000000
#
# Converged with chi squared
#  421088121.793
# degrees of freedom, dof  91
# RMS of residuals (i.e. sqrt(chisq/dof))  2151.12575126
# Reduced chisq (i.e. variance of residuals)  4627341.99773
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a           1151.972926 +/- 266.128375
#  1 A          872506.997603 +/- 4228.982727
#  2 tau            7.154445 +/-   0.033756
#
# correlation matrix:
#                a         A         tau
# ...
