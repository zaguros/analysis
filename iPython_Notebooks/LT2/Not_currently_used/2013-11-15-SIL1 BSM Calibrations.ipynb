# %%
import os, sys
msmtpath = r'D:\measuring'
if not msmtpath in sys.path:
    sys.path.append(msmtpath)
    
from measurement.lib.tools import toolbox as tb
from analysis.lib.m2.ssro import ssro, mbi, sequence
from analysis.scripts.teleportation import BSM_calibrations
reload(BSM_calibrations)
# Out:
# <module 'analysis.scripts.teleportation.BSM_calibrations' from 'D:\measuring\analysis\scripts\teleportation\BSM_calibrations.pyc'>

# %% [markdown]
# # STAGE 0.0 SSRO

# %%
ssro.ssrocalib()

# %% [markdown]
# ### (STAGE 0.3: Rabi to find good pi pulse length)

# %%
execfile('D:/measuring/analysis/scripts/espin/electron_rabi_analysis.py')

# %% [markdown]
# # STAGE 0.5 DARK ESR

# %%
execfile('D:/measuring/analysis/scripts/espin/dark_esr_analysis.py')
# Out:
# Center guess?2.828
# fitting with 1 splittings
# Converged with chi squared  0.0340141766058
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0147190626878
# Reduced chisq (i.e. variance of residuals)  0.000216650806407
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              1.000942 +/-   0.001433
#  1 A              0.232288 +/-   0.006898
#  2 sigma          0.000218 +/-   0.000006
#  3 x0             2.828048 +/-   0.000007
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.316802  1.000000
#      sigma  0.201337 -0.605507  1.000000
#         x0  0.237605  0.750128 -0.454269  1.000000

# %% [markdown]
# # STAGE 1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_1_calibrations()

# %% [markdown]
# # STAGE 2

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# fast pi pulse
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000341060826249
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.006529364692
# Reduced chisq (i.e. variance of residuals)  4.26326032812e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.983917 +/-   0.002964
#  1 a              6.822507 +/-   0.557272
#  2 x0             0.793800 +/-   0.002337
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.744842  1.000000
#         x0  0.098357  0.216707  1.000000
#
# ================================================================================
# CORPSE pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00146072598026
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0135126143855
# Reduced chisq (i.e. variance of residuals)  0.000182590747532
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.982896 +/-   0.005795
#  1 a             45.167680 +/-   9.414552
#  2 x0             0.502584 +/-   0.005097
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a -0.018003  1.000000
#         x0 -0.300681  0.916635  1.000000
#
# ================================================================================
# pi2pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000911015433082
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0106713133744
# Reduced chisq (i.e. variance of residuals)  0.000113876929135
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.943951 +/-   0.004810
#  1 a            840.795214 +/-  58.290021
#  2 x0             0.106108 +/-   0.000261
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.734077  1.000000
#         x0  0.163017  0.370419  1.000000
#
# ================================================================================
# pi2pi, m_I=0
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00227931519134
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0168794075405
# Reduced chisq (i.e. variance of residuals)  0.000284914398917
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.929509 +/-   0.007315
#  1 a            740.916733 +/-  92.200556
#  2 x0             0.104340 +/-   0.000586
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.662474  1.000000
#         x0  0.238790  0.671047  1.000000

# %% [markdown]
# # STAGE 2.5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2p5_calibration()
# Out:
# ================================================================================
# fast pi/2 pulse
# ================================================================================
# Converged with chi squared
#  0.000972482180137
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0103948821817
# Reduced chisq (i.e. variance of residuals)  0.000108053575571
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -0.857089 +/-   0.039645
#  1 x0             0.778673 +/-   0.003661
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0  0.046404  1.000000

# %% [markdown]
# # STAGE 3:

# %%
BSM_calibrations.stage_3_calibrations()

# %%
reload(BSM_calibrations)
BSM_calibrations.N_frq()

# %% [markdown]
# # STAGE 4

# %%
def phaseref(frequency, time, offset=0):
    return ((frequency*time + offset/360.) % 1) * 360.

# %%
phaseref(2.19e6,200e-9)

# %%
(2.19e6*20000e-9 + 0/360.) %1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_4_calibrations()

# %% [markdown]
# # STAGE 5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_5_calibrations()

# %% [markdown]
# # STAGE 6

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_6_calibrations()

# %% [markdown]
# # STAGE 7

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_7_calibrations()
# Out:
# ================================================================================
# Hadamard phase calibration (aim for 10 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00141065583495
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0104169087211
# Reduced chisq (i.e. variance of residuals)  0.000108511987304
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.002760 +/-   0.000046
#  1 A              0.187190 +/-   0.003587
#  2 x0           202.467804 +/-   1.127395
#  3 o              0.223741 +/-   0.003688
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A -0.194969  1.000000
#         x0 -0.086305  0.051679  1.000000
#          o  0.726853 -0.096669 -0.080859  1.000000

# %% [markdown]
# # STAGE 8

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_8_calibrations()
# Out:
# ================================================================================
# Hadamard evolution time calibration (aim for 01 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00121998585465
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00968736629547
# Reduced chisq (i.e. variance of residuals)  9.38450657426e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              2.203913 +/-   0.015028
#  1 A              0.197590 +/-   0.003546
#  2 x0            35.051971 +/-   0.001340
#  3 o              0.265978 +/-   0.002401
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.093196  1.000000
#         x0  0.483698  0.030211  1.000000
#          o  0.086684  0.048418  0.200390  1.000000
