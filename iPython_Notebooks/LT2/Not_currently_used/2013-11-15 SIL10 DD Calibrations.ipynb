# %%
sys.path.append(r'D:/measuring')
from analysis.lib.m2.ssro import ssro
from analysis.scripts.teleportation import DD_calibrations

# %% [markdown]
# # Stage0(.25) SSRO (with 7us SP)

# %%
ssro.ssrocalib()

# %% [markdown]
# # Stage 0.5 Dark ESR

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# Center guess?2.829
# fitting with 1 splittings
# Converged with chi squared  0.131714834794
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0289645989498
# Reduced chisq (i.e. variance of residuals)  0.00083894799232
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.988652 +/-   0.003551
#  1 A              0.128888 +/-   0.008266
#  2 sigma          0.000417 +/-   0.000031
#  3 x0             2.828827 +/-   0.000023
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.343710  1.000000
#      sigma  0.490672 -0.398870  1.000000
#         x0  0.073033  0.566795 -0.389070  1.000000

# %% [markdown]
# # Stage 1 Corpse

# %%
reload(DD_calibrations)
DD_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# CORPSE pi
# ================================================================================
# Converged with chi squared  0.00528338942438
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0256987096572
# Reduced chisq (i.e. variance of residuals)  0.000660423678047
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.955568 +/-   0.011488
#  1 a            107.410882 +/-   8.773395
#  2 x0             0.382481 +/-   0.001295
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.720780  1.000000
#         x0  0.200956  0.474102  1.000000

# %% [markdown]
# # Stage 1.5 pi/2 calbration, Cross

# %%
reload(DD_calibrations)
DD_calibrations.stage_1p5_calibrations()
# Out:
# ================================================================================
# CORPSE pi/2
# ================================================================================
# Converged with chi squared
#  0.00559498266209
# degrees of freedom, dof  19
# RMS of residuals (i.e. sqrt(chisq/dof))  0.017160208964
# Reduced chisq (i.e. variance of residuals)  0.000294472771689
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -2.987673 +/-   0.103069
#  1 x0             0.419864 +/-   0.001253
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0 -0.003745  1.000000

# %% [markdown]
# # stage 2: C13 revival time

# %%
DD_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# first C13 revival
# ================================================================================
# Converged with chi squared  0.00257097145028
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0179268355067
# Reduced chisq (i.e. variance of residuals)  0.000321371431285
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.042036 +/-   0.007477
#  1 a             -0.001952 +/-   0.000612
#  2 x0           106.579045 +/-   0.709005
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.557545  1.000000
#         x0  0.186559  0.786618  1.000000

# %% [markdown]
# # stage 3: LDE - DD spin echo time

# %%
reload(DD_calibrations)
DD_calibrations.stage_3_calibrations()
# Out:
# ================================================================================
# LDE-DD spin echo time
# ================================================================================
# Converged with chi squared  0.00160299312556
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00943690487618
# Reduced chisq (i.e. variance of residuals)  8.9055173642e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.988425 +/-   0.003059
#  1 a             24.485726 +/-   1.120125
#  2 x0            -0.083498 +/-   0.001004
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.728742  1.000000
#         x0  0.166039  0.387109  1.000000

# %% [markdown]
# # stage 4: time between pi pulses

# %%
DD_calibrations.stage_4_calibrations()
# Out:
# ================================================================================
# time between pi pulses
# ================================================================================
# Converged with chi squared  0.000632768317584
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00592906362095
# Reduced chisq (i.e. variance of residuals)  3.51537954213e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.966042 +/-   0.001843
#  1 a              0.012931 +/-   0.000990
#  2 x0            -0.110569 +/-   0.056861
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.647658  1.000000
#         x0  0.230039  0.687194  1.000000
