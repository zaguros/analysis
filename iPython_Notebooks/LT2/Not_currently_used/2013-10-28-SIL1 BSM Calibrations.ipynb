# %%
import os, sys
msmtpath = r'D:\measuring'
if not msmtpath in sys.path:
    sys.path.append(msmtpath)
    
from measurement.lib.tools import toolbox as tb
from analysis.lib.m2.ssro import ssro, mbi, sequence
from analysis.scripts.teleportation import BSM_calibrations
reload(BSM_calibrations)
# Out:
# <module 'analysis.scripts.teleportation.BSM_calibrations' from 'D:\measuring\analysis\scripts\teleportation\BSM_calibrations.pyc'>

# %% [markdown]
# # STAGE 0.0 SSRO

# %%
ssro.ssrocalib()

# %% [markdown]
# ### (STAGE 0.3: Rabi to find good pi pulse length)

# %%
execfile('D:/measuring/analysis/scripts/espin/electron_rabi_analysis.py')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-85c6077d61b8> in <module>()
# ----> 1 execfile('D:/measuring/analysis/scripts/espin/electron_rabi_analysis.py')
#
# D:\measuring\analysis\scripts\espin\electron_rabi_analysis.py in <module>()
#      49     a = sequence.SequenceAnalysis(folder)
#      50     a.get_sweep_pts()
# ---> 51     a.get_readout_results('ssro')
#      52     a.get_electron_ROC()
#      53     ax = a.plot_result_vs_sweepparam(ret='ax')
#
# D:\measuring\analysis\lib\m2\ssro\sequence.pyc in get_readout_results(self, name)
#      16         self.result_corrected = False
#      17
# ---> 18         adwingrp = self.adwingrp(name)
#      19         self.reps = adwingrp['completed_reps'].value
#      20         self.ssro_results = adwingrp['RO_data'].value
#
# D:\measuring\analysis\lib\m2\m2.pyc in adwingrp(self, name)
#      42                 return False
#      43
# ---> 44         return self.g[adwingrpname]
#      45
#      46     def analysis_h5data(self, name='analysis'):
#
# C:\Documents and Settings\localadmin\Local Settings\Application Data\Enthought\Canopy32\User\lib\site-packages\h5py\_hl\group.pyc in __getitem__(self, name)
#     151                 raise ValueError("Invalid HDF5 object reference")
#     152         else:
# --> 153             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     154
#     155         otype = h5i.get_type(oid)
#
# C:\Documents and Settings\localadmin\Local Settings\Application Data\Enthought\Canopy32\User\lib\site-packages\h5py\h5o.pyd in h5py.h5o.open (h5py\h5o.c:2946)()
#
# KeyError: "unable to open object (Symbol table: Can't open object)"

# %% [markdown]
# # STAGE 0.5 DARK ESR

# %%
execfile('D:/measuring/analysis/scripts/espin/dark_esr_analysis.py')
# Out:
# fitting with 1 splittings
# Converged with chi squared  0.0155458750907
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00995079457528
# Reduced chisq (i.e. variance of residuals)  9.90183126794e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.990422 +/-   0.000969
#  1 A              0.207511 +/-   0.004662
#  2 sigma          0.000218 +/-   0.000004
#  3 x0             2.828067 +/-   0.000005
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.316729  1.000000
#      sigma  0.201452 -0.605592  1.000000
#         x0  0.237422  0.750103 -0.454510  1.000000

# %% [markdown]
# # STAGE 1

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# Slow pi pulse for MBI
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.517251511046
# degrees of freedom, dof  7
# RMS of residuals (i.e. sqrt(chisq/dof))  0.271832803404
# Reduced chisq (i.e. variance of residuals)  0.0738930730065
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.245692 +/- 6858.122078
#  1 A              0.509733 +/-   0.208103
#  2 x0            -0.000480 +/- 699.861005
#  3 k            202.526542 +/- 1904.574100
#
# correlation matrix:
#                f         A         x0        k
#          f  1.000000
#          A -0.779747  1.000000
#         x0 -0.218954  0.085475  1.000000
#          k -0.386061  0.171565  0.977040  1.000000

# %% [markdown]
# # STAGE 2

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# fast pi pulse
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000578686526726
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00850504649257
# Reduced chisq (i.e. variance of residuals)  7.23358158408e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.978738 +/-   0.003631
#  1 a              7.505787 +/-   0.725894
#  2 x0             0.829307 +/-   0.003915
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.627413  1.000000
#         x0 -0.228023 -0.723929  1.000000
#
# ================================================================================
# fast pi/2 pulse
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00171819368054
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0138170332904
# Reduced chisq (i.e. variance of residuals)  0.000190910408949
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a             -0.362294 +/-   0.065870
#  1 b              0.816026 +/-   0.052861
#
# correlation matrix:
#                a         b
#          a  1.000000
#          b -0.996890  1.000000
#
# ================================================================================
# CORPSE pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.000463345875805
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00761040304292
# Reduced chisq (i.e. variance of residuals)  5.79182344756e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.980284 +/-   0.003454
#  1 a             46.889540 +/-   5.302344
#  2 x0             0.522716 +/-   0.001135
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.744398  1.000000
#         x0  0.103547  0.227502  1.000000
#
# ================================================================================
# pi2pi
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00064085468806
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00895024223178
# Reduced chisq (i.e. variance of residuals)  8.01068360075e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.932787 +/-   0.003991
#  1 a            677.141354 +/-  48.888997
#  2 x0             0.109488 +/-   0.000290
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.716788  1.000000
#         x0 -0.206479 -0.494883  1.000000

# %% [markdown]
# # STAGE 3:

# %%
BSM_calibrations.stage_3_calibrations()
# Out:
# ================================================================================
# Nitrogen Rabi oscillation
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00224889926582
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0131526518701
# Reduced chisq (i.e. variance of residuals)  0.000172992251217
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.009957 +/-   0.000030
#  1 A             -0.462331 +/-   0.004421
#  2 x0             0.598227 +/-   0.346292
#  3 o              0.500997 +/-   0.003438
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.088086  1.000000
#         x0  0.886117  0.077954  1.000000
#          o  0.366205 -0.037823  0.324437  1.000000

# %%
reload(BSM_calibrations)
BSM_calibrations.N_frq()
# Out:
# Converged with chi squared  0.00544795489104
# degrees of freedom, dof  17
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0179016182164
# Reduced chisq (i.e. variance of residuals)  0.000320467934767
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.629230 +/-   0.005828
#  1 A             -0.369545 +/-   0.011031
#  2 F              0.006828 +/-   0.000175
#  3 x0             7.134560 +/-   0.000128
#
# correlation matrix:
#                a         A         F         x0
#          a  1.000000
#          A -0.597110  1.000000
#          F  0.322789  0.184654  1.000000
#         x0  0.045417 -0.110294 -0.065841  1.000000
# (7.1345603257996428, 0.00012785809116043823)

# %% [markdown]
# # STAGE 4

# %%
def phaseref(frequency, time, offset=0):
    return ((frequency*time + offset/360.) % 1) * 360.

# %%
phaseref(2.19e6,200e-9)
# Out:
# 157.68

# %%
(2.19e6*20000e-9 + 0/360.) %1
# Out:
# 0.8000000000000043

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_4_calibrations()
# Out:
# ================================================================================
# CORPSE pi phase shift (look for the maximum)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.125348503729
# degrees of freedom, dof  6
# RMS of residuals (i.e. sqrt(chisq/dof))  0.144538635971
# Reduced chisq (i.e. variance of residuals)  0.0208914172882
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.174177 +/-   0.073047
#  1 a             -0.000114 +/-   0.000016
#  2 x0            89.832838 +/-   3.644897
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.751642  1.000000
#         x0 -0.003094 -0.006558  1.000000

# %% [markdown]
# # STAGE 5

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_5_calibrations()
# Out:
# ================================================================================
# UNROT evolution time calibration (look for the maximum)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00143810991979
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0105177868387
# Reduced chisq (i.e. variance of residuals)  0.000110623839984
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              2.188309 +/-   0.005532
#  1 A              0.490955 +/-   0.002699
#  2 x0            51.071296 +/-   0.000785
#  3 k              0.001794 +/-   0.000184
#
# correlation matrix:
#                f         A         x0        k
#          f  1.000000
#          A -0.307422  1.000000
#         x0 -0.660619  0.260156  1.000000
#          k -0.118280  0.500268  0.033711  1.000000

# %% [markdown]
# # STAGE 6

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_6_calibrations()
# Out:
# ================================================================================
# spin echo (LDE-BSM) calibrations (look for the minimum)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00485685066599
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0193288359035
# Reduced chisq (i.e. variance of residuals)  0.000373603897384
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.890717 +/-   0.006779
#  1 a              0.000000 +/-   0.000000
#  2 x0          -605.508456 +/-  61.160631
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.607176  1.000000
#         x0  0.215508  0.742351  1.000000

# %% [markdown]
# # STAGE 7

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_7_calibrations()
# Out:
# ================================================================================
# Hadamard phase calibration (aim for 10 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.0012778586458
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00991447522099
# Reduced chisq (i.e. variance of residuals)  9.82968189077e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.002743 +/-   0.000027
#  1 A              0.167404 +/-   0.003561
#  2 x0           -82.144074 +/-   2.759568
#  3 o              0.255196 +/-   0.002428
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.214006  1.000000
#         x0  0.907973  0.187321  1.000000
#          o -0.122810 -0.037935 -0.137912  1.000000

# %% [markdown]
# # STAGE 8

# %%
reload(BSM_calibrations)
BSM_calibrations.stage_8_calibrations()
# Out:
# ================================================================================
# Hadamard evolution time calibration (aim for 01 high)
# ================================================================================
# Figure has not been saved.
# Converged with chi squared  0.00109640208273
# degrees of freedom, dof  13
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00918360614077
# Reduced chisq (i.e. variance of residuals)  8.43386217488e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f          2174806.284681 +/- 26532.971411
#  1 A              0.168447 +/-   0.003102
#  2 x0             0.000035 +/-   0.000000
#  3 o              0.241451 +/-   0.002659
#
# correlation matrix:
#                f         A         x0        o
#          f  1.000000
#          A  0.010304  1.000000
#         x0 -0.206823  0.107455  1.000000
#          o  0.525551  0.133311 -0.167382  1.000000
