# %%
sys.path.append(r'D:/measuring')
from analysis.lib.m2.ssro import ssro
from analysis.scripts.teleportation import DD_calibrations

# %% [markdown]
# # Stage0(.25) SSRO (with 7us SP)

# %%
ssro.ssrocalib()

# %% [markdown]
# # Stage 0.5 Dark ESR

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# Center guess?2.828
# fitting with 1 splittings
# Converged with chi squared  0.102610602558
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0255650291791
# Reduced chisq (i.e. variance of residuals)  0.00065357071693
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.983092 +/-   0.002993
#  1 A              0.121471 +/-   0.007702
#  2 sigma         -0.000388 +/-   0.000028
#  3 x0             2.828763 +/-   0.000021
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.323475  1.000000
#      sigma -0.447600  0.450954  1.000000
#         x0  0.084635  0.598750  0.416363  1.000000

# %% [markdown]
# # Stage 1 Corpse

# %%
reload(DD_calibrations)
DD_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# CORPSE pi
# ================================================================================
# Converged with chi squared  0.00962454999246
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.034685281447
# Reduced chisq (i.e. variance of residuals)  0.00120306874906
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.939134 +/-   0.015595
#  1 a            102.210399 +/-  11.841360
#  2 x0             0.383766 +/-   0.001772
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.730025  1.000000
#         x0  0.177336  0.407664  1.000000

# %% [markdown]
# # Stage 1.5 pi/2 calbration, Cross

# %%
reload(DD_calibrations)
DD_calibrations.stage_1p5_calibrations()
# Out:
# ================================================================================
# CORPSE pi/2
# ================================================================================
# Converged with chi squared
#  0.00332865489452
# degrees of freedom, dof  19
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0132360251915
# Reduced chisq (i.e. variance of residuals)  0.000175192362869
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -2.989636 +/-   0.079499
#  1 x0             0.420414 +/-   0.000966
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0  0.011407  1.000000

# %% [markdown]
# # stage 2: C13 revival time

# %%
DD_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# first C13 revival
# ================================================================================
# Converged with chi squared  0.001126284486
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.01186530913
# Reduced chisq (i.e. variance of residuals)  0.000140785560749
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.047914 +/-   0.005200
#  1 a             -0.002195 +/-   0.000405
#  2 x0           105.890323 +/-   0.326998
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.685327  1.000000
#         x0  0.233677  0.615422  1.000000

# %% [markdown]
# # stage 3: LDE - DD spin echo time

# %%
reload(DD_calibrations)
DD_calibrations.stage_3_calibrations()
# Out:
# ================================================================================
# LDE-DD spin echo time
# ================================================================================
# Converged with chi squared  0.000704863141657
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00625772030578
# Reduced chisq (i.e. variance of residuals)  3.91590634254e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.993716 +/-   0.002025
#  1 a             23.501594 +/-   0.742768
#  2 x0            -0.084239 +/-   0.000703
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.725423  1.000000
#         x0  0.176460  0.415226  1.000000

# %% [markdown]
# # stage 4: time between pi pulses

# %%
DD_calibrations.stage_4_calibrations()
# Out:
# ================================================================================
# time between pi pulses
# ================================================================================
# Converged with chi squared  0.00066024991211
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00605644703376
# Reduced chisq (i.e. variance of residuals)  3.66805506728e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.967130 +/-   0.001984
#  1 a              0.012478 +/-   0.001011
#  2 x0             0.469885 +/-   0.044095
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.744832  1.000000
#         x0 -0.057502 -0.128405  1.000000
