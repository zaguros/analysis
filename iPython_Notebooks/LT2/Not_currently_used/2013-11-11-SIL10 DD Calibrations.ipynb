# %%
sys.path.append(r'D:/measuring')
from analysis.lib.m2.ssro import ssro
from analysis.scripts.teleportation import DD_calibrations

# %% [markdown]
# # Stage0(.25) SSRO (with 7us SP)

# %%
ssro.ssrocalib()

# %% [markdown]
# # Stage 0.5 Dark ESR

# %%
execfile(r'D:\measuring\analysis\scripts\espin\dark_esr_analysis.py')
# Out:
# Center guess?2.828
# fitting with 1 splittings
# Converged with chi squared  0.104636408203
# degrees of freedom, dof  157
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0258161565226
# Reduced chisq (i.e. variance of residuals)  0.000666473937601
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.984559 +/-   0.003046
#  1 A              0.115180 +/-   0.007699
#  2 sigma         -0.000393 +/-   0.000030
#  3 x0             2.828760 +/-   0.000023
#
# correlation matrix:
#                a         A         sigma     x0
#          a  1.000000
#          A  0.326787  1.000000
#      sigma -0.455289  0.442052  1.000000
#         x0  0.082440  0.593015  0.411499  1.000000

# %% [markdown]
# # Stage 1 Corpse

# %%
reload(DD_calibrations)
DD_calibrations.stage_1_calibrations()
# Out:
# ================================================================================
# CORPSE pi
# ================================================================================
# Converged with chi squared  0.00962454999246
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.034685281447
# Reduced chisq (i.e. variance of residuals)  0.00120306874906
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.939134 +/-   0.015595
#  1 a            102.210399 +/-  11.841360
#  2 x0             0.383766 +/-   0.001772
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.730025  1.000000
#         x0  0.177336  0.407664  1.000000

# %% [markdown]
# # Stage 1.5 pi/2 calbration, Cross

# %%
reload(DD_calibrations)
DD_calibrations.stage_1p5_calibrations()
# Out:
# ================================================================================
# CORPSE pi/2
# ================================================================================
# Converged with chi squared
#  0.0018148540938
# degrees of freedom, dof  19
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00977336362342
# Reduced chisq (i.e. variance of residuals)  9.55186365156e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 m             -3.019782 +/-   0.058701
#  1 x0             0.414616 +/-   0.000714
#
# correlation matrix:
#                m         x0
#          m  1.000000
#         x0 -0.146591  1.000000

# %% [markdown]
# # stage 2: C13 revival time

# %%
DD_calibrations.stage_2_calibrations()
# Out:
# ================================================================================
# first C13 revival
# ================================================================================
# Converged with chi squared  0.00114221378287
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0119489214098
# Reduced chisq (i.e. variance of residuals)  0.000142776722858
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.027036 +/-   0.005203
#  1 a             -0.003382 +/-   0.000408
#  2 x0           105.986330 +/-   0.220986
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.672511  1.000000
#         x0  0.236357  0.647449  1.000000

# %% [markdown]
# # stage 3: LDE - DD spin echo time

# %%
reload(DD_calibrations)
DD_calibrations.stage_3_calibrations()
# Out:
# ================================================================================
# LDE-DD spin echo time
# ================================================================================
# Converged with chi squared  0.00117940593355
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00809460016701
# Reduced chisq (i.e. variance of residuals)  6.55225518637e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.991038 +/-   0.002615
#  1 a             25.435246 +/-   0.960799
#  2 x0            -0.084769 +/-   0.000849
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.722857  1.000000
#         x0  0.183397  0.434663  1.000000

# %% [markdown]
# # stage 4: time between pi pulses

# %%
DD_calibrations.stage_4_calibrations()
# Out:
# ================================================================================
# time between pi pulses
# ================================================================================
# Converged with chi squared  0.000736501798533
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.00639662149773
# Reduced chisq (i.e. variance of residuals)  4.09167665852e-05
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.969031 +/-   0.002097
#  1 a              0.013651 +/-   0.001068
#  2 x0             0.374641 +/-   0.042262
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.746271  1.000000
#         x0  0.021116  0.046930  1.000000
