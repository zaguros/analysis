# %%
import sys
sys.path.append(r'D:/measuring')
import numpy as np
sys.path.append(r'D:/measuring/analysis')

# %% [markdown]
# # Phase calibration

# %%
from analysis.scripts.QEC import carbon_ramsey_analysis as cr
reload(cr)
Result=cr.Carbon_Ramsey(timestamp=None, frequency =1./360, offset = 0.5, amplitude = 0.5,  x0=0, exponent=0, 
                        decay_constant = 2000,phase =0, plot_fit = True,fixed = [2,3,4], show_guess = False)
# Out:
# Converged with chi squared  0.0179845990137
# degrees of freedom, dof  21
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0292644746552
# Reduced chisq (i.e. variance of residuals)  0.000856409476842
#
# fitted parameters at minimum, with 68% C.I.:
#  0 a              0.529274 +/-   0.006120
#  1 A              0.928899 +/-   0.022315
#  2 f              0.002831 +/-   0.000019
#  3 phi          -38.928038 +/-   2.983684
#
# correlation matrix:
#                a         A         f         phi
#          a  1.000000
#          A -0.057656  1.000000
#          f -0.282374 -0.019045  1.000000
#        phi  0.230755 -0.005205 -0.881723  1.000000
#
# fitfunction: a + A * exp(-((x-x0)/T )**n*cos(2pi *(f*x+phi/360) )

# %% [markdown]
# # Single Qubit Tomography

# %%
from analysis.scripts.QEC import SingleQubitTomography as tomo
reload(tomo)
Result=tomo.OneQubitTomo(timestamp = '20140804_075535',  fixed = [], plot_fit = False, show_guess = False, do_print = True, 
                             frequency =[1./20,1./20,1./20],  offset =[0.5,0.5,0.5], 
                             amplitude = [0.5,0.5,0.5],  phase =[0,90,0])
# Out:
# ************************************************************
# X Tomography
# folder d:\measuring\data\20140804\074534_CarbonRabiInitialised_Crosstalk_Hans_sil1
# 0.05
# Converged with chi squared  0.141408013664
# degrees of freedom, dof  20
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0840856746611
# Reduced chisq (i.e. variance of residuals)  0.00707040068322
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.042354 +/-   0.001016
#  1 a              0.633262 +/-   0.017337
#  2 A             -0.139250 +/-   0.024273
#  3 phi           93.638335 +/-  21.484446
#
# correlation matrix:
#                f         a         A         phi
#          f  1.000000
#          a -0.138939  1.000000
#          A -0.001150  0.016868  1.000000
#        phi -0.885218  0.115493  0.009809  1.000000
#
# Writting to File!
# path joined
# Writing fit results to file (fit_results.txt) at (d:\measuring\data\20140804\074534_CarbonRabiInitialised_Crosstalk_Hans_sil1) succesfull
# ************************************************************
# Y Tomography
# folder d:\measuring\data\20140804\075035_CarbonRabiInitialised_Crosstalk_Hans_sil1
# Figure has not been saved.
# 0.05
# Converged with chi squared  0.324962887965
# degrees of freedom, dof  20
# RMS of residuals (i.e. sqrt(chisq/dof))  0.127468209363
# Reduced chisq (i.e. variance of residuals)  0.0162481443983
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.042853 +/-   0.001391
#  1 a              0.584274 +/-   0.026163
#  2 A             -0.150205 +/-   0.037063
#  3 phi          185.301907 +/-  28.029201
#
# correlation matrix:
#                f         a         A         phi
#          f  1.000000
#          a -0.096951  1.000000
#          A -0.027513  0.023879  1.000000
#        phi -0.867067  0.100327  0.010016  1.000000
#
# Writting to File!
# path joined
# Writing fit results to file (fit_results.txt) at (d:\measuring\data\20140804\075035_CarbonRabiInitialised_Crosstalk_Hans_sil1) succesfull
# ************************************************************
# Z Tomography
# folder d:\measuring\data\20140804\075535_CarbonRabiInitialised_Crosstalk_Hans_sil1
# Figure has not been saved.
# 0.05
# Converged with chi squared  0.0249887714257
# degrees of freedom, dof  20
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0353473983666
# Reduced chisq (i.e. variance of residuals)  0.00124943857129
#
# fitted parameters at minimum, with 68% C.I.:
#  0 f              0.049547 +/-   0.000737
#  1 a              0.831646 +/-   0.007290
#  2 A              0.075737 +/-   0.010443
#  3 phi           -3.965171 +/-  15.305367
#
# correlation matrix:
#                f         a         A         phi
#          f  1.000000
#          a -0.123835  1.000000
#          A -0.012465  0.071111  1.000000
#        phi -0.869068  0.115335  0.020288  1.000000
#
# Writting to File!
# path joined
# Writing fit results to file (fit_results.txt) at (d:\measuring\data\20140804\075535_CarbonRabiInitialised_Crosstalk_Hans_sil1) succesfull
# fitfunction: A * cos(2pi * (f*x + phi/360) ) + a

# %%
from analysis.scripts.QEC import MBI_cosine_sum as csum
reload(csum)
Result =csum.CosineSum_MBI_data(timestamp=None, measurement_name = ['adwindata'], ssro_calib_timestamp =None,
        frequency = [321e3,289e3], offset =0.5, amplitude =[ .5,.5],  phase =[0,0], 
        fixed = [], 
        plot_fit = True, do_print = True, show_guess = True)
# Out:
# Converged with chi squared  0.0375921043476
# degrees of freedom, dof  74
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0225388866207
# Reduced chisq (i.e. variance of residuals)  0.000508001410102
#
# fitted parameters at minimum, with 68% C.I.:
#  0 avg            0.483169 +/-   0.002505
#  1 A             -0.270139 +/-   0.007397
#  2 f_a        325514.118255 +/- 269.802927
#  3 phi_a         -6.140498 +/-   3.430515
#  4 B             -0.325430 +/-   0.007378
#  5 f_b        293888.411030 +/- 223.461131
#  6 phi_b        -10.591093 +/-   2.842780
#
# correlation matrix:
#                avg       A         f_a       phi_a     B         f_b       phi_b
#        avg  1.000000
#          A  0.001809  1.000000
#        f_a  0.004537 -0.017314  1.000000
#      phi_a -0.013520  0.017047 -0.896367  1.000000
#          B  0.001670  0.082826  0.277424 -0.246253  1.000000
#        f_b  0.002722 -0.294686  0.149176 -0.143852 -0.000705  1.000000
#      phi_b -0.007352  0.259961 -0.144304  0.159404 -0.002760 -0.896513  1.000000
#
# Writting to File!
# path joined
# Writing fit results to file (fit_results.txt) at (d:\measuring\data\20140725\143533_CarbonRamsey_Hans_sil1) succesfull

# %% [markdown]
# ## 2 Qubit Tomography

# %%
from analysis.scripts.QEC import Two_Qubit_Tomography as Tomo2
reload(Tomo2)
a = Tomo2.BarPlotTomo(None)#'20140711_183032')
# Out:
# [ 0.08502484  0.08502484 -0.44300923  0.0623137   0.0225692  -0.43165366
#   0.0623137   0.01689141  0.07934705 -0.00581973  0.1815472  -0.0171753
#   0.11909155  0.13044713  0.58466998]
# ['XI' 'YI' 'ZI' 'IX' 'IY' 'IZ' 'XX' 'XY' 'XZ' 'YX' 'YY' 'YZ' 'ZX' 'ZY' 'ZZ']

# %%
from analysis.scripts.QEC import Two_Qubit_Tomography as Tomo2
reload(Tomo2)
## timestamps = [positive_data_timestamp, negative_data_timestamp] 

# a = Tomo2.BarPlotTomoContrast(['20140801_194910','20140801_195555']) ## ZZ init, no parity
# a = Tomo2.BarPlotTomoContrast(['20140801_212726','20140801_213557']) ## ZmZ

# a = Tomo2.BarPlotTomoContrast(['20140801_200221','20140801_201830']) ## ZZ, XX parity
# a = Tomo2.BarPlotTomoContrast(['20140801_214359','20140801_220851']) ## ZmZ, XX parity

### twice repeated parity measurement
    # 00
# a = Tomo2.BarPlotTomoContrast(['20140803_133848','20140803_141334']) ## ZZ, 2*XX parity, 1-qubit values
# a = Tomo2.BarPlotTomoContrast(['20140803_115254','20140803_124338']) ## ZZ, 2*XX parity, 2-qubit correlations

    #01
# a = Tomo2.BarPlotTomoContrast(['20140803_163649','20140803_171420']) ## ZmZ, 2*XX parity, 1-qubit values
# a = Tomo2.BarPlotTomoContrast(['20140803_144642','20140803_154749']) ## ZmZ, 2*XX parity, 2-qubit correlations

### 3x repeated parity measurements
# a = Tomo2.BarPlotTomoContrast(['20140803_174651','20140803_182158']) 


### X intialization experiments
    ## init XX
a = Tomo2.BarPlotTomoContrast(['20140804_093159','20140804_09'])
# Out:
# [ 0.54470451  0.05957247  0.12283416  0.64517279  0.1315122  -0.1060021
#   0.4915672   0.05867113 -0.00874093  0.08214796  0.04418676  0.01565821
#   0.16980879 -0.00297653 -0.01198996]
# Fidelity with ent = 0.431777783368

# %%
a.tolist()
# Out:
# ['IX',
#  'IY',
#  'IZ',
#  'XI',
#  'YI',
#  'ZI',
#  'XX',
#  'XY',
#  'XZ',
#  'YX',
#  'YY',
#  'YZ',
#  'ZX',
#  'ZY',
#  'ZZ']
