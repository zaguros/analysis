# %% [markdown]
# # Nuclear spin environment fingerprinting analysis

# %%
import sys
import os
sys.path.append(r'D:/measuring')
sys.path.append(r'D:/measuring/analysis')
sys.path.append(r'D:/measuring/analysis/scripts/QEC_data_analysis/fingerprints/')

# %% [markdown]
# ## Basic data (still make some nice function)

# %%
import analysis.scripts.mbi.mbi_electron_decoupling_analysis as DD; reload(DD)
fit_results = DD.electron_DD_analysis(timestamp=None, measurement_name = ['measurement0'], show_guess = False, plot_fit = False)
# Out:
# Converged with chi squared  16.4584356089
# degrees of freedom, dof  198
# RMS of residuals (i.e. sqrt(chisq/dof))  0.288311311201
# Reduced chisq (i.e. variance of residuals)  0.0831234121664
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A              0.384657 +/- 4676779.661500
#  1 T              0.008763 +/- 79791.203710
#  2 n              0.537081 +/- 720023.424699
#
# correlation matrix:
#                A         T         n
#          A  1.000000
#          T -0.480857  1.000000
#          n -0.328706  0.983917  1.000000

# %% [markdown]
# ## Fingerprint Data Merged, ms=+1 at ~300 G

# %%
import fingerprint_analysis_N8 as fp8; reload(fp8)
fp8.fingerprint()
# Out:
# tau larmor = 3.07019208227e-06
# d:\measuring\data\20140420\110552_DecouplingSequence_Fingerprint_Hans_sil18

# %%
import fingerprint_analysis_N16 as fp16; reload(fp16)
fp16.fingerprint()
# Out:
# tau larmor = 3.07019208227e-06
# d:\measuring\data\20140419\005744_DecouplingSequence_Fingerprint_Hans_sil116

# %%
import fingerprint_analysis_N32 as fp32; reload(fp32)
fp32.fingerprint()
# Out:
# tau larmor = 3.07019208227e-06
# d:\measuring\data\20140419\233953_DecouplingSequence_Fingerprint_Hans_sil132

# %%
import fingerprint_analysis_N64 as fp64; reload(fp64)
fp64.fingerprint()
# Out:
# tau larmor = 3.07019208227e-06
# d:\measuring\data\20140419\140807_DecouplingSequence_Fingerprint_Hans_sil164

# %% [markdown]
# ## Fingerprint Data Merged, ms=-1 at ~300 G

# %%
import fingerprint_analysis_N16_msm1 as fp16_m1; reload(fp16_m1)
fp16_m1.fingerprint(RO = 'x')
# Out:
# tau larmor = 3.06646134868e-06
# d:\measuring\data\20140730\184039_DecouplingSequence_Fingerprint_msm1_xHans_sil116

# %%
import fingerprint_analysis_N32_msm1 as fp32_m1; reload(fp32_m1)
fp32_m1.fingerprint(disp_sim_spin = True)
# Out:
# tau larmor = 3.06646134868e-06
# d:\measuring\data\20140730\213811_DecouplingSequence_Fingerprint_msm1_xHans_sil132

# %%
import fingerprint_analysis_N64_msm1 as fp64_m1; reload(fp64_m1)
fp64_m1.fingerprint(disp_sim_spin = True)
# Out:
# tau larmor = 3.06646134868e-06
# d:\measuring\data\20140731\010536_DecouplingSequence_Fingerprint_msm1_xHans_sil164
