# %% [markdown]
# # Pulse calibrations

# %%
sys.path.append(r'D:/measuring')
from analysis.scripts.QEC import simple_fingerprint as FP
from analysis.scripts.QEC import Carbon_control_analysis_sweep_N

# %% [markdown]
# ## Pi-pulses

# %%
execfile(r'D:\measuring\analysis\scripts\pulse_calibration\calibrate_pi.py')
# Out:
# Converged with chi squared  0.0257817728963
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0378460132176
# Reduced chisq (i.e. variance of residuals)  0.00143232071646
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.327126 +/-   0.012125
#  1 a            -22.991949 +/-   2.526851
#  2 x0             0.783725 +/-   0.003464
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.708920  1.000000
#         x0 -0.209334 -0.516421  1.000000

# %% [markdown]
# ## Pi2-pulses

# %%
execfile(r'D:\measuring\analysis\scripts\pulse_calibration\calibrate_pi.py')
# Out:
# Converged with chi squared  0.0035302612676
# degrees of freedom, dof  18
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0140044859234
# Reduced chisq (i.e. variance of residuals)  0.000196125625978
#
# fitted parameters at minimum, with 68% C.I.:
#  0 of             0.805760 +/-   0.004578
#  1 a             35.347578 +/-   1.662280
#  2 x0             0.729431 +/-   0.000974
#
# correlation matrix:
#                of        a         x0
#         of  1.000000
#          a  0.741739  1.000000
#         x0 -0.094997 -0.213846  1.000000
