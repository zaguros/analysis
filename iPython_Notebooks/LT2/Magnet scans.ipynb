# %%
import sys
sys.path.append(r'D:/measuring')

# %%
execfile(r'D:\measuring\analysis\scripts\QEC_data_analysis\magnetic_field_scansY.py')
# Out:
# [    0.   200.   400.   600.   800.  1000.   800.   600.   400.   200.
#      0.  -200.  -400.  -600.  -800. -1000.  -800.  -600.  -400.  -200.
#      0.]
