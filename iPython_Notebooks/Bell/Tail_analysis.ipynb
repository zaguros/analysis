# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
folder=tb.latest_data('Bell')
#folder=tb.data_from_time('20140702093910')
#folder=r'D:\measuring\data\20140521\113406_Bell_lt1_tail_Pippin_SIL1_SM'
name = 'ssro'
psb=False
if psb:
    a = pqsequence.TailAnalysis(folder, hdf5_mode='r')
else:
    a = pqsequence.TailAnalysis(folder, hdf5_mode='r', pq_folder = 'bs_remote')
#a.fix_sweep_pts('Pulse Amplitude', 'eom_pulse_amplitude')
a.get_sweep_pts()
a.get_sweep_idxs(noof_syncs_per_sweep_pt=250)
#a.sweep_name='eof off voltage'
#a.sweep_pts=np.append(np.linspace(-0.28,-0.22,11-1),-.5)
a.get_readout_results(name)
if psb:
    a.get_tail_vs_sweep(0,5310.05,80, pq_binsize_ns=1., hist_binsize_ns=1.,verbose=True)
else:
    a.get_tail_vs_sweep(0,5357.2,10, pq_binsize_ns=1e-3, hist_binsize_ns=.1,verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-431f67d70395> in <module>()
#       6 a = pqsequence.TailAnalysis(folder, hdf5_mode='r')#, pq_folder='bs_remote')
#       7 #a.fix_sweep_pts('Pulse Amplitude', 'eom_pulse_amplitude')
# ----> 8 a.get_sweep_pts()
#       9 a.sweep_pts = a.g.attrs['aom_amplitude']
#      10 a.get_sweep_idxs(noof_syncs_per_sweep_pt=250)
#
# d:\measuring\analysis\lib\m2\ssro\sequence.pyc in get_sweep_pts(self)
#     106
#     107     def get_sweep_pts(self):
# --> 108         self.sweep_name = self.g.attrs['sweep_name']
#     109         self.sweep_pts = self.g.attrs['sweep_pts']
#     110
#
# C:\Canopy\User\lib\site-packages\h5py\_hl\attrs.pyc in __getitem__(self, name)
#      46         """ Read the value of an attribute.
#      47         """
# ---> 48         attr = h5a.open(self._id, self._e(name))
#      49
#      50         if attr.get_space().get_simple_extent_type() == h5s.NULL:
#
# C:\Canopy\User\lib\site-packages\h5py\h5a.pyd in h5py.h5a.open (h5py\h5a.c:1840)()
#
# KeyError: "can't open attribute (Attribute: Can't open object)"

# %%
save=False
a.plot_tail_cts_vs_sweep(save=save)
a.plot_tail_hists_vs_sweep(save=save)
a.plot_tail_hist_integated(save=save, log_plot=True)
a.plot_tail_hist_all(save=save, log_plot=False, offset=0, indices=[-1])

# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
folder=tb.latest_data('Bell')
#folder=tb.data_from_time('20140704093748')
#folder=r'D:\measuring\data\20140519\192030_Bell_lt3_tailS_The111no2_SIL1_Ey_+11deg'
name = 'ssro'
a = pqsequence.TailAnalysis(folder, hdf5_mode='r')#, pq_folder='bs_remote')

# %%
mrkr_filter = pq_tools.filter_marker(a.pqf,1)
pq_plots.plot_photon_hist_filter_comparison(a.pqf,mrkr_filter,start = 5.350e6, length = 1e6, hist_binsize = 1e3, save = False)
# Out:
# (<matplotlib.figure.Figure at 0x8394a10>,
#  (<matplotlib.axes.AxesSubplot at 0x8356bf0>,
#   <matplotlib.axes.AxesSubplot at 0xa48ecb0>))

# %%
a.get_cr_results('ssro')

# %%
a.get_sweep_pts()
a.get_readout_results('ssro')
# Out:
# array([ 0.7617])

# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
#folder=tb.latest_data('Bell')
folder=tb.data_from_time('20140609183154')
#folder=r'D:\measuring\data\20140519\192030_Bell_lt3_tailS_The111no2_SIL1_Ey_+11deg'
name = 'ssro'
a = pqsequence.TailAnalysis(folder, hdf5_mode='r', pq_folder='bs_remote')
a.reps=200000
a.plot_histogram(1, start=5379500, length=100000, hist_binsize=100, save=False)
# Out:
# X:\data\20140609\183156_Bell_BS_tpqi_parallel_BS_lt1_tail_dac3_m1500_Ey\183156_Bell_BS_tpqi_parallel_BS_lt1_tail_dac3_m1500_Ey.hdf5
# Total clicks:
#  32306

# %%
from analysis.lib.pq import pq_tools
reload(pq_tools)
# Out:
# <module 'analysis.lib.pq.pq_tools' from 'd:/measuring\analysis\lib\pq\pq_tools.pyc'>

# %%
fltr0=pq_tools.filter_synctimes(a.pqf, 5371.5e3, 5397e3,15,600e3)
fltr1=pq_tools.filter_synctimes(a.pqf, 5374e3, 5399.5e3,15,600e3)
cs=pq_tools.get_coincidences(a.pqf, fltr0, fltr1)
dts_ns = cs[:,0]*1e-3
len(cs)
# Out:
# 6630

# %%
binsize=10
G2_BINEDGES = arange(-19000,19000,binsize)
#G2_BINEDGES = np.hstack((arange(-700,-500,binsize),arange(-100,100,binsize),arange(500,700,binsize)))
#print G2_BINEDGES
figure(figsize=(20,5))
b_=hist(dts_ns, bins=G2_BINEDGES)

# %%
1-(6./150263)/(25./70608)
# Out:
# 0.8872249322853929

# %%
sync_time = a.pqf['/PQ_sync_time-1'].value
fltr=pq_tools.filter_synctimes(a.pqf, 5000e3, 7000e3)
ph0,ph1=pq_tools.get_photons(a.pqf)
print len(sync_time[ph0 & fltr]), len(sync_time[ph0])

# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')
folder=tb.latest_data('125542')
#fp = tb.get_msmt_fp(folder)
#from analysis.lib.pq import pq_tools as pqt
#pqf = pqt.pqf_from_fp(fp)
#fig, (ax0,ax1) = pqt.plot_photon_hist(pqf)
name = 'ssro'
a = pqsequence.TailAnalysis(folder, hdf5_mode='r')
a.reps=200000
a.plot_histogram(0, start = 5300, length = 1000, hist_binsize=1, log_plot=False,save=False)
# Out:
# Total clicks: 2280

# %%
15*250*120*1e-6
# Out:
# 0.44999999999999996
