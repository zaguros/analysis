# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')

# %%
from analysis.lib.pq import pq_tools, pq_plots
reload(pq_tools)
reload(pq_plots)
# Out:
# <module 'analysis.lib.pq.pq_plots' from 'd:/measuring\analysis\lib\pq\pq_plots.py'>

# %%
folder = r'D:\measuring\data\20140701\092540_Bell_BS_tpqi_parallel_BS_Plu_windows'
fp = tb.get_msmt_fp(folder)
pqf = pq_tools.pqf_from_fp(fp)

# %%
pq_plots.plot_photon_hist(pqf, start = 5.350e6, length = 1e5)
# Out:
# (<matplotlib.figure.Figure at 0x2ba05e30>,
#  (<matplotlib.axes.AxesSubplot at 0x2bb4d3d0>,
#   <matplotlib.axes.AxesSubplot at 0x2bb69cb0>))
