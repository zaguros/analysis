# %%
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')

# %%
from analysis.lib.pq import pq_tools, pq_plots
reload(pq_tools)
reload(pq_plots)
# Out:
# <module 'analysis.lib.pq.pq_plots' from 'd:/measuring\analysis\lib\pq\pq_plots.pyc'>

# %%
folder = r'D:\measuring\data\20140701\130648_Bell_BS_tpqi_parallel_BS_PLU_windows_data'
fp = tb.get_msmt_fp(folder)
pqf = pq_tools.pqf_from_fp(fp, rights='r+')

# %%
pq_plots.plot_photon_hist(pqf, start = 4.350e6, length = 60e5)
# Out:
# (<matplotlib.figure.Figure at 0x1324df30>,
#  (<matplotlib.axes.AxesSubplot at 0x2c2d1130>,
#   <matplotlib.axes.AxesSubplot at 0x2c144b30>))

# %%
mrkr_filter = pq_tools.filter_marker(pqf,1)

# %%
pq_plots.plot_photon_hist_filter_comparison(pqf,mrkr_filter,start = 5.365e6, length = 1e6, hist_binsize = 1e3, save = True)
# Out:
# (<matplotlib.figure.Figure at 0x6cc80570>,
#  (<matplotlib.axes.AxesSubplot at 0x6c6d96d0>,
#   <matplotlib.axes.AxesSubplot at 0x6cc99af0>))

# %%
pqf.close()

# %%
np.where(a ==2)
# Out:
# (array([1]),)
