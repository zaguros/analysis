# %%
import numpy as np
import os,sys

sys.path.append("D:/measuring/")
sys.path.append(r'D:/measuring/analysis')
import analysis.lib.fitting.common as fitlib
from analysis.lib.Qmemory import CarbonDephasing as CD
reload(CD)
execfile(r'D:\measuring\analysis\scripts\setup_analysis.py')

# %matplotlib inline
# Out:
# reloaded
# d:\measuring\data
# d:\measuring\data
# reloaded
# d:\measuring\data
# reloaded
# d:\measuring\data

# %% [markdown]
# ## General plotting of positive and negative data

# %%
reload(CD)
fig = plt.figure()
ax = plt.subplot()

older_than = None
x,y1,y_u,f = CD.get_PosNeg_data('_Tomo_Z_C1',older_than = older_than)
CD.plot_data(x,y1,y_u=y_u,fmt='o-')
x,y1,y_u,f = CD.get_PosNeg_data('_Tomo_Z_C2',older_than = older_than)
CD.plot_data(x,y1,y_u=y_u,fmt='o-')
x,y1,y_u,f = CD.get_PosNeg_data('_Tomo_Z_C3',older_than = older_than)
CD.plot_data(x,y1,y_u=y_u,fmt='o-')
x,y1,y_u,f = CD.get_PosNeg_data('_Tomo_Z_C5',older_than = older_than)
CD.plot_data(x,y1,y_u=y_u,fmt='o-')
x,y1,y_u,f = CD.get_PosNeg_data('_Tomo_Z_C6',older_than = older_than)
CD.plot_data(x,y1,y_u=y_u,fmt='o-')
# x,y1,y_u,f = CD.get_PosNeg_data('_statemX_Tomo_ZZ_C12',older_than = '20151023_142159')
# CD.plot_data(x,y1,y_u=y_u,fmt='o-')
# x,y1,y_u,f = CD.get_PosNeg_data('_Tomo_Y_C2')
# CD.plot_data(x,y1,y_u=y_u,fmt='o')
# x,y1,y_u,f = CD.get_PosNeg_data('_statemX_Tomo_XX_C25')
# CD.plot_data(x,y1,y_u=y_u,fmt='o-')

plt.title(CD.get_tstamp_from_folder(f))
plt.xlabel('Repetitions')
plt.ylabel('<Z>')
plt.legend(['C1','C2','C3','C5','C6'],loc=1)#,'logical X C25 YY','logical X C25 XY','logical X C25 YX'])
plt.savefig(os.path.join(f,'Pos_neg_data.png'),format='png')
plt.show()
plt.close('all')
# Out:
# d:\measuring\data
# reloaded

# %% [markdown]
# ## Fit exponential to positive/negative data

# %%
reload(CD)
import colorsys

fig = plt.figure()
ax = plt.subplot()
fit_exp = False

#### get exp decays for all carbon combinations.
i = 0
states = ['X','mX']
carbons = ['26']
N =  len(states)*len(carbons)
HSV_tuples = [(x*1.0/N, 0.7, 1.) for x in range(N)]
RGB_tuples = map(lambda x: colorsys.hsv_to_rgb(*x), HSV_tuples)

for state in states:
    for Cs in carbons:
        f = CD.fit_exp_pos_neg_data('_state'+state+'_Tomo_ZZ_C'+Cs,label = 'C'+Cs+' '+state,ax=ax,color=RGB_tuples[i], fmt='o')
        i+=1

# f = CD.fit_exp_pos_neg_data('_Tomo_Z_C1',label = 'C1',ax=ax, color='b', fmt='o')
# f = CD.fit_exp_pos_neg_data('_Tomo_Z_C2',label = 'C2',ax=ax, color='g', fmt='o')
# f = CD.fit_exp_pos_neg_data('_Tomo_Z_C3',label = 'C3',ax=ax, color='r', fmt='o')
# f = CD.fit_exp_pos_neg_data('_Tomo_Z_C5',label = 'C5',ax=ax, color='y', fmt='o')
# f = CD.fit_exp_pos_neg_data('_Tomo_Z_C6',label = 'C6',ax=ax, color='c', fmt='o')
#print f

#### plotting/formatting saving
plt.title(CD.get_tstamp_from_folder(f)+' 2000 nW')
plt.xlabel('Number of Repetitions')
plt.ylabel('Expectation value')
plt.legend(['C1','fit','C2','fit','C3','fit','C5','fit','C6','fit'],bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)#,'','C3','','C5','','C6'])
plt.savefig(os.path.join(f,'Pos_neg_fit_exponential.png'),format='png')
plt.show()
plt.close('all')
# Out:
# d:\measuring\data
# [1000 1200 1400 1600 1800]
# [  0 200 400 600 800]
# [  0 200 400 600 800]
# d:\measuring\data\20151101\074754_Memory_NoOfRepetitions_positive_stateX_Tomo_ZZ_C26
# Converged with chi squared  0.022325750472
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0528272544147
# Reduced chisq (i.e. variance of residuals)  0.002790718809
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A              0.524140 +/-   0.033982
#  1 tau         3865.683576 +/- 1051.404355
#
# correlation matrix:
#                A         tau
#          A  1.000000
#        tau -0.794675  1.000000
#
# [1000 1200 1400 1600 1800]
# [  0 200 400 600 800]
# [  0 200 400 600 800]
# d:\measuring\data\20151101\081447_Memory_NoOfRepetitions_positive_statemX_Tomo_ZZ_C26
# Converged with chi squared  0.0331674544337
# degrees of freedom, dof  8
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0643889105686
# Reduced chisq (i.e. variance of residuals)  0.00414593180421
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A             -0.513923 +/-   0.040307
#  1 tau         5681.895293 +/- 2614.662423
#
# correlation matrix:
#                A         tau
#          A  1.000000
#        tau  0.810403  1.000000

# %% [markdown]
# ## General plot of Bloch vector length

# %%
### routine gets raw data for 'X' and 'Y' tomography of a carbon and plots it.

reload(CD)
older_than = '20151105_094309'
older_than = None
f_name = 'Memory_Sweep_repump_time_'

CD.Sweep_repetitions(carbon = '1',folder_name = f_name, older_than = None, do_T2correct=False, fit_result=False, return_fits=True, fitGauss=True)
#CD.Sweep_repetitions(carbon = '5',folder_name = 'Memory_Sweep_repump_time_', older_than = None, do_T2correct=False, fit_result=False, return_fits=True, fitGauss=True)
#CD.Sweep_repetitions(carbon = '3',folder_name = 'Memory_Sweep_repump_time_', older_than = older_than)
#folder_name = 'Memory_Sweep_repump_time_'
#CD.Sweep_repetitions(carbon = c,folder_name = folder_name,logicstate = 'X',return_fits=True,plot_result = True, older_than = '20151002_135716' )
#CD.Sweep_repetitions(carbon = c, folder_name = folder_name, logicstate = 'mX', return_fits=True, plot_result = True)#, older_than = '20151002_140212')
# Out:
# d:\measuring\data
# reloaded
# A0
#  0.487614281601  offset  0.125
# Coupling  37038.74
# {'a': 0.033880937032931713, 'A': 0.41011401181649015, 'x0': 0.39351064643580619, 'sigma': 0.79090024420850213} {'a': 0.073767694717290389, 'A': 0.068576183192240278, 'x0': 0.044213311968351404, 'sigma': 0.14250377601566064}

# %%
reload(CD) 
### the sequence length dict is only used when converting to the time axis for the 'on-time' strategy.
#sequence_overhead = 8+0.6-0.45
#sequence_length_dict = {'1' : 26.95+sequence_overhead, '5': 41.6+sequence_overhead}
# CD.Sweep_Rep_List(carbons = ['3','6'],older_than = '20151102_080000', save=True) 
# CD.Sweep_Rep_List(carbons = ['5'],older_than = '20150722_173913') 
#c = '2'
logicstate_list = ['X']*5 # length should be equally long to the carbon list
CD.Sweep_Rep_List(carbons = ['1'],logicstate_list = logicstate_list,fit_results = True,do_T2correct=True)#der_than = '20151029_094838')#,sequence_length = sequence_length_dict[c])
# Out:
# d:\measuring\data
# reloaded
# Converged with chi squared
#  0.0456208060037
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0711967586682
# Reduced chisq (i.e. variance of residuals)  0.00506897844486
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A              0.911842 +/-   0.051256
#  1 tau          208.060708 +/-  22.744097
#
# correlation matrix:
#                A         tau
#          A  1.000000
#        tau -0.703920  1.000000

# %%
RepumpTime=[1.5, 2.5, 45, 5.5, 10, 20]
TotalTime= [5.5,6.5,49, 9.5,14,24]
NoReps=[794, 782, 150, 511, 428, 314]
NoRepsErr=[37, 32, 19, 43, 33, 33]
plt.errorbar(TotalTime, NoReps, yerr=NoRepsErr, fmt = 'o', label = 'fast')

plt.xlabel('Total time(us)')
plt.ylabel('Repetitions (1/e)')
    
#g_a, g_A, g_tau = 0, 800, 20
#p0, fitfunc, fitfunc_str = fitlib.fit_exp_decay_with_offset(g_a, g_A, g_tau)

g_a, g_A, g_x0, g_sigma = 0, 900, 0, 20
p0, fitfunc, fitfunc_str =fitlib.fit_gauss(g_a, g_A, g_x0, g_sigma=g_sigma)

#plot the initial guess

if True: #Show Guess
    plt.plot(np.linspace(0,50,51), fitfunc(np.linspace(0,50,51)), ':', lw=2)
   
    
fit_result = fit.fit1d(np.array(RepumpTime),np.array(NoReps), None, p0=p0, fitfunc=fitfunc, ret=True, do_print=False,fixed=[0,1])

if True: ## plot data and fit
    ax = plt.subplot()
    plot.plot_fit1d(fit_result, np.linspace(0,50,101), ax=ax, plot_data=False)

# %%
reload(CD)
# CD.Osci_period(carbon = '5',older_than = None,freq=0,fixed = [0,1,3])
# CD.Osci_period(carbon = '2',older_than = None)
CD.Osci_period(carbon = '2',older_than = None,fit_results = True)
# Out:
# d:\measuring\data
# Results are saved in  20150901\165345

# %% [markdown]
# ## Coupling strength vs repetition decay

# %%
reload(CD)
reload(fitlib)
fig = plt.figure()
ax = plt.subplot()

update_data = False
do_T2correct = True
LogPlot = True
c_idents = ['1','2','3','5','6','12','13','15','16','23','25','26','35','36','56']#
 #'104343'
older_than = None

    
def update_data_func(c_idents,older_than,do_Z = False):
    
    
    ## get Z decays
    if do_Z:
        Z_fits,Z_fits_u = CD.Z_decay_vs_perp_coupling(c_idents,older_than=older_than,return_vals = True)
    
    ### get bloch vector decay
    x,y,y_u,folder = CD.coupling_vs_repetitions(c_idents,older_than = older_than,
                                                folder_name = 'Memory_NoOfRepetitions_', do_T2correct=do_T2correct)
    
    y = y[np.argsort(x)]
    y_u = y_u[np.argsort(x)]
    
    
    
    print 'update done!!'
    
    if do_Z == False:
        x = np.sort(x*1e-3)
        return x,y,y_u,folder
    
    Z_fits = Z_fits[np.argsort(x)]
    Z_fits_u = Z_fits_u[np.argsort(x)]
    x = np.sort(x*1e-3)
    return x,y,y_u,Z_fits,Z_fits_u,folder

if update_data:
    x,y,y_u,folder = update_data_func(c_idents,older_than = '20151102_080000',do_Z = False) # 2 uW break
    #x,y,y_u,folder = update_data_func(c_idents,older_than = None, do_Z = False)# '20151023_132218',do_Z = False) # 2 uW A1 + A2
    x2,y2,y_u2,folder = update_data_func(c_idents,older_than = '20151026_020000',do_Z = False) # 190 nW A1 + A2
    x3,y3,y_u3,folder = update_data_func(c_idents,older_than = '20151024_131500',do_Z = False) # 50 nW A1 + A2
    x4,y4,y_u4,folder = update_data_func(c_idents,older_than = '20151025_030000',do_Z = False) # 10 nW A1 + A2
    
    #x4,y4,y_u4,Z_fits4,Z_fits_u4,folder = update_data_func(c_idents,older_than = '20151026_080000') # 190 nW A1 + A2
    x5,y5,y_u5,folder = update_data_func(c_idents,older_than = '20151105_050000') # 2000 nW E' circ pol
    
    #other tstamps:
    #older_than = None#'20150902_104343' #linear pol
    #older_than = '20151021_040952'   #circ pol

plt.errorbar(x,y,y_u,fmt = 'ro', label = '26ns')
plt.errorbar(x2,y2,y_u2,fmt = 'ko', label = '61ns')
plt.errorbar(x3,y3,y_u3,fmt = 'go', label = '86ns')
plt.errorbar(x4,y4,y_u4,fmt = 'bo', label = '134ns')
#plt.errorbar(x5,y5,y_u5,fmt = 'yo',label = 'E circ pol : 2000nW')


# plt.errorbar(x,Z_fits,Z_fits_u,fmt='bx')
# plt.errorbar(x2,Z_fits2,Z_fits_u2,fmt='gx')
#plt.errorbar(x3,Z_fits3,Z_fits_u3,fmt='rx')

plt.legend(loc=1)#bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Coupling strength (kHz)')   
plt.ylabel('Fitted decay constant')
if older_than != None:
    plt.title('older_than ' + older_than)
else:
    plt.title(CD.get_tstamp_from_folder(folder))

if LogPlot:
    plt.ylim([10,2000])
    plt.xlim([2,100])
    #ax.set_xscale("log", nonposy='clip')
    ax.set_yscale("log", nonposy='clip')
else:
    plt.ylim([0,1000])
#print x== x4
#print x
#print x4
#print folder
#p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_constant_offset(1,0.0005,0)
#p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_tau(1,0.001,0)
p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_coupl(1,0.0005,0)
#p0,fitfunc,fitfunc_str =fitlib.fit_exp_decay_shifted_with_offset(0,700,40,0) # g_a : offset g_A : initial Amplitude g_tau : decay constant g_x0 : x offse
if False:  # Show Guess
    ax.plot(np.linspace(2,90,201), fitfunc(np.linspace(2,90,201)), ':', lw=2)
    print 'fitfun value ', fitfunc(np.linspace(2,90,21))

#x_fit, y_fit, y_u_fit = numpy.concatenate((x[0:],x_s)), numpy.concatenate((y[0:],y_s)), numpy.concatenate((y_u[0:],y_u_s))

fit_result1 = fit.fit1d(x, y, None, p0 = p0, fitfunc = fitfunc, do_print = True, ret = True, fixed = [0,2])
#p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_constant_offset(1,0.0005,0.08)
p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_coupl(1,0.0005,0)
fit_result2 = fit.fit1d(x2, y2, None, p0 = p0, fitfunc = fitfunc, do_print = True, ret = True, fixed = [0,2])
#p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_constant_offset(1,0.0005,0)
p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_coupl(1,0.0006,0)
fit_result3 = fit.fit1d(x3, y3, None, p0 = p0, fitfunc = fitfunc, do_print = True, ret = True, fixed = [0,2])
#p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_constant_offset(1,0.0005,0)
p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_coupl(1,0.0007,0)
fit_result4 = fit.fit1d(x4, y4, None, p0 = p0, fitfunc = fitfunc, do_print = True, ret = True, fixed = [0,2])
plot.plot_fit1d(fit_result1, np.linspace(3,100,1001), ax=ax, color = 'r', plot_data=False, add_txt = False, lw = 2)
plot.plot_fit1d(fit_result2, np.linspace(3,100,1001), ax=ax, color = 'k', plot_data=False, add_txt = False, lw = 2)
plot.plot_fit1d(fit_result3, np.linspace(3,100,1001), ax=ax, color = 'g', plot_data=False, add_txt = False, lw = 2)
plot.plot_fit1d(fit_result4, np.linspace(3,100,1001), ax=ax, color = 'b', plot_data=False, add_txt = False, lw = 2)


if True:
    print 'saving to ', folder
    plt.savefig(os.path.join(folder,'coupling_vs_repetitions.pdf'),format='pdf')
    plt.savefig(os.path.join(folder,'coupling_vs_repeititons.png'),format='png')
plt.show()
plt.close('all')
# Out:
# d:\measuring\data
# reloaded
# reloaded
# Converged with chi squared
#  3206276.8904
# degrees of freedom, dof  24
# RMS of residuals (i.e. sqrt(chisq/dof))  365.506320647
# Reduced chisq (i.e. variance of residuals)  133594.870433
#
# fitted parameters at minimum, with 68% C.I.:
#  0 tau            0.003385 +/-   0.000536
#
# correlation matrix:
#                tau
#        tau  1.000000
#
# Converged with chi squared  825681.291142
# degrees of freedom, dof  24
# RMS of residuals (i.e. sqrt(chisq/dof))  185.481500778
# Reduced chisq (i.e. variance of residuals)  34403.3871309
#
# fitted parameters at minimum, with 68% C.I.:
#  0 tau            0.004157 +/-   0.000512
#
# correlation matrix:
#                tau
#        tau  1.000000
#
# Converged with chi squared  542846.707076
# degrees of freedom, dof  24
# RMS of residuals (i.e. sqrt(chisq/dof))  150.394856278
# Reduced chisq (i.e. variance of residuals)  22618.6127948
#
# fitted parameters at minimum, with 68% C.I.:
#  0 tau            0.005965 +/-   0.001206
#
# correlation matrix:
#                tau
#        tau  1.000000
#
# Converged with chi squared  134456.47482
# degrees of freedom, dof  24
# RMS of residuals (i.e. sqrt(chisq/dof))  74.8488685118
# Reduced chisq (i.e. variance of residuals)  5602.35311749
#
# fitted parameters at minimum, with 68% C.I.:
#  0 tau            0.007406 +/-   0.001149
#
# correlation matrix:
#                tau
#        tau  1.000000
#
# saving to  d:\measuring\data\20151105\031435_Memory_NoOfRepetitions_positive_statemX_Tomo_XX_C56

# %%
# n = 450
repumping = 290e-9
def f(n,coupling):
    return ((1.+np.exp(-0.5*(2*np.pi*coupling*repumping)**2.))**n)/(2.**n)

fig = plt.figure()
ax = plt.subplot()
x = np.linspace(1,1000,1001)
plt.plot(x,f(x,35e3))
plt.plot(x,f(x,18e3))
plt.show()
plt.close('all')

# %% [markdown]
# ## Initialization values for various carbons (execute script 3Qubit_inits)

# %%
from analysis.scripts.QEC import Two_Qubit_Tomography as Tomo2
reload(Tomo2)
carbon_combinations = [[1,2,3],[1,2,5],[1,2,6],[1,3,5],[1,3,6],[1,5,6],[2,3,5],[2,3,6],[2,5,6],[3,5,6]]
# carbon_combinations = [[1,2,5]]
for kk in carbon_combinations:
    x_label,x,res,res_err = Tomo2.BarPlotTomoContrast(tag = '_'+str(kk[0])+str(kk[1])+str(kk[2])+'_init',
                                                      plot_fit = False, 
                                                      return_data = True,
                                                      save = False)
    print 'Carbons {} {} {}: {} {:.2} +- {:.2} and {} {:.2} +- {:.2}'.format(kk[0],kk[1],kk[2],x_label[0],res[0],res_err[0],x_label[1],res[1],res_err[1])
# Out:
# Carbons 1 2 3: YYY 0.52 +- 0.033 and ZZZ 0.24 +- 0.036
# Carbons 1 2 5: YYY 0.71 +- 0.028 and ZZZ 0.12 +- 0.036
# Carbons 1 2 6: YYY 0.54 +- 0.032 and ZZZ -0.2 +- 0.036
# Carbons 1 3 5: YYY 0.57 +- 0.032 and ZZZ -0.13 +- 0.036
# Carbons 1 3 6: YYY 0.47 +- 0.034 and ZZZ -0.18 +- 0.036
# Carbons 1 5 6: YYY 0.48 +- 0.033 and ZZZ -0.16 +- 0.036
# Carbons 2 3 5: YYY 0.41 +- 0.034 and ZZZ -0.32 +- 0.035
# Carbons 2 3 6: YYY 0.43 +- 0.034 and ZZZ 0.046 +- 0.037
# Carbons 2 5 6: YYY 0.45 +- 0.034 and ZZZ 0.21 +- 0.036
# Carbons 3 5 6: YYY 0.28 +- 0.035 and ZZZ 0.35 +- 0.035

# %% [markdown]
# # Decay with repump power/time

# %%
reload(CD)
reload(fitlib)

fig = plt.figure()
ax = plt.subplot()
plt.xlabel('Pump power (uW))')
plt.ylabel('Fitted decay constant')
#plt.ylim([0,4])

update_data=True
if update_data:
    older_than ='20150903_232308'
    powers=np.array([3.5e-6, 2.7e-6, 2e-6, 1.5e-6, 1e-6, 5e-7, 2e-7, 1e-7, 6e-8, 4e-8, 3e-8])
    x1,y1,y_u1, folder = CD.repump_power_vs_repetitions(c_identifier='1', repump_powers = powers, do_T2correct=True, older_than = '20150904_121025')
    x2,y2,y_u2, folder2 = CD.repump_power_vs_repetitions(c_identifier='2', repump_powers = powers, do_T2correct=True, older_than = '20150903_232308')

plt.errorbar(powers*1e6,y1,y_u1,fmt = 'o',color = 'b', label = 'C1')
plt.errorbar(powers*1e6,y2,y_u2,fmt = 'o',color = 'g', label = 'C2')

if older_than != None:
    plt.title('older_than ' + older_than)
else:
    plt.title(CD.get_tstamp_from_folder(folder))
plt.legend()#bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig(os.path.join(folder,'power_vs_repetitions.pdf'),format='pdf')
plt.savefig(os.path.join(folder,'power_vs_repeititons.png'),format='png')
plt.show()
plt.close('all')
    
######################### GET SHORT AND FAST PUMPING TIMESCALES AND PLOT DATA AS A FUNCTION OF THOSE

if update_data:
    tau, tau_err = CD.repump_speed_doubleExp(older_than='20150904_125052', exclude_first_n_points = 10, 
            offset = 1, amplitude_one = -0.7, amplitude_two = -0, x0 = 0, decay_constant_one = 0.06, 
            decay_constant_two = 1.06, fixed = [3,4], show_guess = True, do_print = False, 
            powers=[3500e-9, 2700e-9, 2000e-9, 1500e-9, 1000e-9, 500e-9, 200e-9, 100e-9, 60e-9, 40e-9, 30e-9], 
            plot_fit = False, plot_results = False)
    #tau = tau+np.array(0.45)

# tau2, tau_err2 = CD.repump_speed_doubleExp(timestamp='20150903_232308',#'20150903_125250',
#         exclude_first_n_points = 10, offset = 1, amplitude_one = -0.7,
#         amplitude_two = -0, x0 = 0, decay_constant_one = 0.06, 
#         decay_constant_two = 1.06, fixed = [3,4], show_guess = False, do_print = False, 
#         powers=[3500e-9, 2700e-9, 2000e-9, 1500e-9, 1000e-9, 500e-9, 200e-9, 100e-9, 60e-9, 40e-9, 30e-9], 
#         plot_fit = False, plot_results = True)

fig = plt.figure()
ax = plt.subplot()

plt.xlabel('Repump time constant (us)')
plt.ylabel('Fitted decay constant')
if False: #Log-Plot
    plt.ylim(10,500)
    ax.set_yscale("log", nonposy='clip')
else:
    plt.ylim(0,500)
plt.errorbar(tau, y1, yerr = y_u1,xerr = tau_err,fmt = 'o',color = 'b', label = 'C1')
plt.errorbar(tau, y2, yerr = y_u2,xerr = tau_err,fmt = 'o',color = 'g', label = 'C2')


p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_constant_offset(1., 55.*(10**(-3)), 0.)
#p0,fitfunc,fitfunc_str =fitlib.fit_hyperbola(1., 55.*(10**(-3)), 0.07)
#p0,fitfunc,fitfunc_str =fitlib.fit_exp_decay_shifted_with_offset(0,200,0.2,0) # g_a : offset g_A : initial Amplitude g_tau : decay constant g_x0 : x offset

if True: #show guess
    ax.plot(np.linspace(0.05,1.1*np.max(tau),201), fitfunc(np.linspace(0.05,1.2,201)), ':', lw=2, color = 'r')

fit_result = fit.fit1d(np.array(tau), np.array(y1), None, p0 = p0, fitfunc = fitfunc, do_print = True, ret = True, fixed = [0])
plot.plot_fit1d(fit_result, np.linspace(0.05,1.1*np.max(tau),1001), ax=ax, plot_data=False, add_txt=False, lw=2, color = 'b')

p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_constant_offset(1., 20.*(10**(-3)), 0.07)
fit_result2 = fit.fit1d(np.array(tau),np.array(y2) ,None, p0 = p0, fitfunc = fitfunc, do_print = False, ret = True,fixed = [0])
print fit_result['params_dict']
print fit_result2['params_dict']
plot.plot_fit1d(fit_result2, np.linspace(0.05,1.1 *np.max(tau),1001), ax=ax, plot_data=False, add_txt=False, lw=2, color = 'g')
if True:
    print 'saving to: ', folder
    plt.savefig(os.path.join(folder,'repumptimescale_vs_repetitions.pdf'),format='pdf')
    plt.savefig(os.path.join(folder,'repumptimescale_vs_repetitions.png'),format='png')
plt.show()
plt.close('all')
# Out:
# d:\measuring\data
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# Bad fit in  d:\measuring\data\20150904\113324_Memory_NoOfRepetitions_positive_Tomo_X_C1_repumpP5e-07 Xi_square is  0.00580732140451
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# Bad fit in  d:\measuring\data\20150904\115254_Memory_NoOfRepetitions_positive_Tomo_X_C1_repumpP6e-08 Xi_square is  0.00550088872407
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# d:\measuring\data\20150904\120548_Memory_NoOfRepetitions_positive_Tomo_X_C1_repumpP3e-08
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# correcting for T2* decay before fitting. Are you sure this is what you want?
# Bad fit in  d:\measuring\data\20150903\153418_Memory_NoOfRepetitions_positive_Tomo_X_C2_repumpP3e-08 Xi_square is  0.00555593893709
# d:\measuring\data\20150903\153418_Memory_NoOfRepetitions_positive_Tomo_X_C2_repumpP3e-08
# Using SSRO timestamp  d:\measuring\data\20150904\105712_AdwinSSRO_SSROCalibration_111_1_sil18
# Converged with chi squared
#  619.418377994
# degrees of freedom, dof  9
# RMS of residuals (i.e. sqrt(chisq/dof))  8.29603906823
# Reduced chisq (i.e. variance of residuals)  68.8242642216
#
# fitted parameters at minimum, with 68% C.I.:
#  0 coup           0.017027 +/-   0.001826
#  1 offs           0.149176 +/-   0.002196
#
# correlation matrix:
#                coup      offs
#       coup  1.000000
#       offs -0.738263  1.000000
#
# {'coup': 0.017026965686964587, 'offs': 0.14917590420680937}
# {'coup': 0.05476948715719402, 'offs': 0.088956124076300019}
# saving to:  d:\measuring\data\20150904\120548_Memory_NoOfRepetitions_positive_Tomo_X_C1_repumpP3e-08

# %%
reload(CD)
fit_result = CD.repump_speed_doubleExp(#older_than='20151118_162037',
        exclude_first_n_points =3,amplitude =0.9,
        decay_constant_one = 80, 
        decay_constant_two = 300, x_offs = 20, offset=0.00, log_plot = True,
        plot_fit = True, do_print = True, fixed = [0], show_guess = False, 
        powers=[2e-6])#, 350e-9, 200e-9, 100e-9, 50e-9, 20e-9])
#print fit_result['params_dict']['tau'], ' +- ', fit_result['error_dict']['tau']
#print fit_result['params_dict']['tau2'], ' +- ', fit_result['error_dict']['tau2']
# Out:
# d:\measuring\data
# reloaded
# folder is  d:\measuring\data\20151118\170110_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW_Eprime
# Converged with chi squared
#  0.0319343545001
# degrees of freedom, dof  233
# RMS of residuals (i.e. sqrt(chisq/dof))  0.0117071480494
# Reduced chisq (i.e. variance of residuals)  0.000137057315451
#
# fitted parameters at minimum, with 68% C.I.:
#  0 A              0.855622 +/-   0.009027
#  1 tau           31.857199 +/-   1.290485
#  2 tau2         398.028550 +/-  25.940589
#  3 offs_x        42.766182 +/-   0.677765
#
# correlation matrix:
#                A         tau       tau2      offs_x
#          A  1.000000
#        tau  0.670680  1.000000
#       tau2  0.856677  0.528922  1.000000
#     offs_x -0.274064 -0.715620 -0.219106  1.000000

# %%
reload(CD)
'''
    x,y,y_u,folder = update_data_func(c_idents,older_than = '20151102_080000',do_Z = False) # 2 uW break
    x2,y2,y_u2,folder = update_data_func(c_idents,older_than = '20151026_020000',do_Z = False) # 190 nW A1 + A2
    x3,y3,y_u3,folder = update_data_func(c_idents,older_than = '20151024_131500',do_Z = False) # 50 nW A1 + A2
    x4,y4,y_u4,folder = update_data_func(c_idents,older_than = '20151025_030000',do_Z = False) # 10 nW A1 + A2
    '''
#tstamps = ['20151030_164714','20151030_165302','20151103_185409'] #'20150826_102333'], #A1 only: '20150902_142407']
start_tstamps = ['20151031_182230','20151024_233353','20151026_020000','20151024_131500']#,'20150902_142407'] #'20150826_102333'], #A1 only: '20150902_142407'],
stop_timestamps = ['20151030_220005','20151024_145547','20151025_110750','20151023_193751']
binwidth_ns = [9,25,25,25]
tau, tau_err = CD.repump_speed_paper_plot(older_than=start_tstamps, newer_than=stop_timestamps, binwidth_ns=binwidth_ns,
        exclude_first_n_points = [8,2,2,2], offset = [0.,0.,0.,0.], amplitude = [0.8,0.8,0.8], x0 = [0.,0.,0.], decay_constant_one = [80,300,150], 
        decay_constant_two = [500.,523.,800.], x_offs=[0,0,0], colors=['r','k','b'],
        plot_fit = True, do_print = False, fixed = [[0],[0],[0]], show_guess = False)
# Out:
# d:\measuring\data
# reloaded
# older than  20151031_182230  and newer_than  20151030_220005
# folder is
#  ['d:\\measuring\\data\\20151031\\002734_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\012545_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\015619_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\025415_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\032432_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\042235_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\052002_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\055024_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\064731_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\074459_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\084029_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\093615_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\103229_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\112917_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\120847_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\124809_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\132749_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\140718_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\144545_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\152403_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\160247_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\164126_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\171522_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\174857_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW', 'd:\\measuring\\data\\20151031\\182229_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_2e-06nW']
# Using SSRO timestamp  d:\measuring\data\20151030\164127_AdwinSSRO_SSROCalibration_111_1_sil18
# {'A': 0.81161206498218186, 'tau': 26.380632206074605, 'offs_x': -0.064292971023993811, 'tau2': 460.91160294136802}
#  {'A': 0.002355394152168803, 'tau': 0.32520703587411809, 'offs_x': 0.16261932858033193, 'tau2': 6.7412686872389216}
# older than  20151024_233353  and newer_than  20151024_145547
# folder is
#  ['d:\\measuring\\data\\20151024\\145549_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW_Eprime', 'd:\\measuring\\data\\20151024\\150148_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW_Eprime', 'd:\\measuring\\data\\20151024\\151449_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW_Eprime', 'd:\\measuring\\data\\20151024\\152507_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW_Eprime', 'd:\\measuring\\data\\20151024\\155913_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\163126_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\170457_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\174030_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\181448_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\184823_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\192106_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\195205_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\202252_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\205546_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\212809_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\215903_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\223007_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\230325_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW', 'd:\\measuring\\data\\20151024\\233352_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1e-08nW']
# Using SSRO timestamp  d:\measuring\data\20151023\173826_AdwinSSRO_SSROCalibration_111_1_sil18
# {'A': 0.74364049916307262, 'tau': 130.59886374751827, 'offs_x': -4.6516871979420982, 'tau2': 1370.278287728162}
#  {'A': 0.0023668205519387321, 'tau': 1.2713193841768349, 'offs_x': 0.57355829767852184, 'tau2': 12.677751528607899}
# older than  20151026_020000  and newer_than  20151025_110750
# folder is  ['d:\\measuring\\data\\20151026\\000854_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1.9e-07nW', 'd:\\measuring\\data\\20151026\\003958_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1.9e-07nW', 'd:\\measuring\\data\\20151026\\011032_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1.9e-07nW', 'd:\\measuring\\data\\20151026\\014136_PulsarMBIElectronRamsey_Dephasing_ElectronRepump_1.9e-07nW']
# Using SSRO timestamp  d:\measuring\data\20151025\082240_AdwinSSRO_SSROCalibration_111_1_sil18
# {'A': 0.81404964694831272, 'tau': 58.391571798605604, 'offs_x': -1.3364380969887033, 'tau2': 1008.9655565111805}
#  {'A': 0.0037955451683064595, 'tau': 1.1341798776813308, 'offs_x': 0.53674378479807838, 'tau2': 23.481747931742845}
# saving to:  D:\measuring\QMem_plots

# %% [markdown]
# ##### Compareregular Pi and BB1 pulses

# %%
execfile(r'D:\measuring\analysis\scripts\Quantum_Memory\LT2_compare_pi_bb1.py')

# %% [markdown]
# ##### First plot of reps vs repump time

# %%
RepumpPower_uW=[1.8, 0.5, 0.1, 0.03, 0.06, 0.04, 1., 0.2, 0.46, 0.5]
RepumpTimes_fast_ns=[74.5, 115, 264, 707, 341, 647, 97.9, 162, 428, 122]
RepumpTimes_fast_us=np.array(RepumpTimes_fast_ns)/1000.
RepumpTimes_fast_Err_ns=[0.5, 10, 34, 86, 53, 69, 0.7, 14, 7, 0.9]
RepumpTimes_fast_Err=np.array(RepumpTimes_fast_Err_ns)/1000.
RepumpTimes_slow_ns=[926, 850, 1393, 2970, 1382, 3347, 1087, 1035, 1778, 1173]
RepumpTimes_slow_Err=[158, 139, 144, 686, 168, 737, 169, 130, 234, 173]
NoReps=[220, 138, 112, 72, 86, 86, 198, 158, 79, 184]
NoRepsErr=[15, 10, 10, 5, 7, 4, 14, 22, 6, 17]
plt.errorbar(RepumpTimes_fast_us, NoReps, xerr=RepumpTimes_fast_Err, yerr=NoRepsErr, fmt = 'o', label = 'fast')
#plt.errorbar(RepumpTimes_slow_ns, NoReps, xerr=RepumpTimes_slow_Err, yerr=NoRepsErr, fmt = 'o', label = 'slow')
plt.xlabel('Short repump timescale (us)')
plt.ylabel('Repetitions (1/e)')
plt.ylim(0.500)
    
g_a, g_A, g_tau = 70, 200, 150
#p0, fitfunc, fitfunc_str = fitlib.fit_exp_decay_with_offset(g_a, g_A, g_tau)
p0,fitfunc,fitfunc_str =fitlib.fit_dephasing_constant_offset(1., 100.*(10**(-3)), 0.)
#plot the initial guess

if True: #Show Guess
    plt.plot(np.linspace(0.1,1,201), fitfunc(np.linspace(0.1,1.,201)), ':', lw=2)
   
    
fit_result = fit.fit1d(np.array(RepumpTimes_fast_us),np.array( NoReps), None, p0=p0, fitfunc=fitfunc, ret=True, do_print=False,fixed=[0])

if True: ## plot data and fit
    ax = plt.subplot()
    plot.plot_fit1d(fit_result, np.linspace(0.05,1.,1001), ax=ax, plot_data=False)

# %% [markdown]
# #### ZZ decay as a function of perp hyperfine strength

# %%
reload(CD)


### get exp decays for all carbon combinations.
carbons = ['12','13','15','16','23','25','26','35','36','56','1','2','3','5','6']
older_than = '20151026_014111' ### 190 nW
CD.Z_decay_vs_perp_coupling(c_idents = carbons, older_than = older_than)

carbons = ['1','2','3','5','6']
older_than = '20151026_014111' ### 190 nW
CD.Z_decay_vs_perp_coupling(c_idents = carbons, older_than = older_than)
# Out:
# d:\measuring\data
# 12
# 13
# 15
# 16
# 23
# 25
# 26
# 35
# 36
# 56
# 1
# 2
# 3
# 5
# 6
# saving to
#  d:\measuring\data\20151025\215707_Memory_NoOfRepetitions_positive_Tomo_Z_C6
# 1
# 2
# 3
# 5
# 6
# saving to
#  d:\measuring\data\20151025\215707_Memory_NoOfRepetitions_positive_Tomo_Z_C6

# %% [markdown]
# #### Laser stability

# %%
from analysis.lib.Qmemory import CheckLaserPower as Laser; reload(Laser)

Laser.CheckPower('NewfocusAOM','ADWIN',nr_of_files=10)
Laser.CheckPower('MatisseAOM','ADWIN',nr_of_files=10)
# Out:
# d:\measuring\data
